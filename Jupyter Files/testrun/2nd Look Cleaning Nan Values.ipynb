# %%
import pandas as pd
import numpy as np
import chunk
import re
from datetime import datetime
import sys

pd.set_option('display.max_columns',26)
pd.set_option('display.max_rows', None)

# %% [markdown]
# ### Disclaimer: any cell following the heading *** indicates the following cell is a condensed group of commands that must be run to simulate work shown beforehand. These are provided to help anyone actively follow along or for my own future use.

# %%
drink=pd.read_csv('C://Users//Owner//DA//Classwork//0 Activities//Final_Project//Final Cuts//Iowa_Liqour_Sales//Iowa_Liquor_Sales.csv')
# Out:
# C:\Users\Owner\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (6) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
drink.head(3)
# Out:
#   Invoice/Item Number        Date  Store Number              Store Name  \
# 0        S29198800001  11/20/2015          2191          Keokuk Spirits
# 1        S29195400002  11/21/2015          2205  Ding's Honk And Holler
# 2        S29050300001  11/16/2015          3549    Quicker Liquor Store
#
#             Address          City Zip Code  \
# 0         1013 MAIN        KEOKUK    52632
# 1  900 E WASHINGTON      CLARINDA    51632
# 2      1414 48TH ST  FORT MADISON    52627
#
#                                       Store Location  County Number County  \
# 0    1013 MAIN\nKEOKUK 52632\n(40.39978, -91.387531)           56.0    Lee
# 1  900 E WASHINGTON\nCLARINDA 51632\n(40.739238, ...           73.0   Page
# 2  1414 48TH ST\nFORT MADISON 52627\n(40.624226, ...           56.0    Lee
#
#    Category Category Name  Vendor Number                  Vendor Name  \
# 0       NaN           NaN          255.0          Wilson Daniels Ltd.
# 1       NaN           NaN          255.0          Wilson Daniels Ltd.
# 2       NaN           NaN          130.0  Disaronno International LLC
#
#    Item Number                               Item Description  Pack  \
# 0          297                          Templeton Rye w/Flask     6
# 1          297                          Templeton Rye w/Flask     6
# 2          249  Disaronno Amaretto Cavalli Mignon 3-50ml Pack    20
#
#    Bottle Volume (ml) State Bottle Cost State Bottle Retail  Bottles Sold  \
# 0                 750            $18.09              $27.14             6
# 1                 750            $18.09              $27.14            12
# 2                 150             $6.40               $9.60             2
#
#   Sale (Dollars)  Volume Sold (Liters)  Volume Sold (Gallons)
# 0        $162.84                   4.5                   1.19
# 1        $325.68                   9.0                   2.38
# 2         $19.20                   0.3                   0.08

# %%
drink.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8796/1353737469.py in <module>
# ----> 1 drink.columns
#
# NameError: name 'drink' is not defined

# %%
drink=drink.drop_duplicates()

# %%
drink.shape
# Out:
# (12591077, 24)

# %%
drink['Category Name']=list(map(lambda x: x.upper(),drink['Category Name']))
drink['Year']=list(map(lambda x:x[-2:],drink['Date']))
drink['Year'].unique()
# Out:
# array(['15', '13', '12', '14', '16', '17'], dtype=object)

# %% [markdown]
# ### Because of its size, the original dataset will be split into 6 pieces by year, and map functions will be run on these smaller portions

# %%
year12 = drink[drink['Year']=='12']
year12.to_csv('year2012.csv')
year12.shape
# Out:
# (2082059, 25)

# %%
year13 = drink[drink['Year']=='13']
year13.to_csv('year2013.csv')
year13.shape
# Out:
# (2063763, 25)

# %%
year14 = drink[drink['Year']=='14']
year14.to_csv('year2014.csv')
year14.shape
# Out:
# (2097796, 25)

# %%
year15 = drink[drink['Year']=='15']
year15.to_csv('year2015.csv')
year15.shape
# Out:
# (2184483, 25)

# %%
year16 = drink[drink['Year']=='16']
year16.to_csv('year2016.csv')
year16.shape
# Out:
# (2279879, 25)

# %%
year17 = drink[drink['Year']=='17']
year17.to_csv('year2017.csv')
year17.shape
# Out:
# (1883097, 25)

# %% [markdown]
# # ***

# %%
y13=pd.read_csv('C://Users//Owner//DA//Classwork//0 Activities//Final_Project//Final Cuts//Des_Moines_Liquor_Store//Jupyter Files//testrun//year2012.csv')
y14=pd.read_csv('C://Users//Owner//DA//Classwork//0 Activities//Final_Project//Final Cuts//Des_Moines_Liquor_Store//Jupyter Files//testrun//year2013.csv')
y15=pd.read_csv('C://Users//Owner//DA//Classwork//0 Activities//Final_Project//Final Cuts//Des_Moines_Liquor_Store//Jupyter Files//testrun//year2014.csv')
y16=pd.read_csv('C://Users//Owner//DA//Classwork//0 Activities//Final_Project//Final Cuts//Des_Moines_Liquor_Store//Jupyter Files//testrun//year2015.csv')
y17=pd.read_csv('C://Users//Owner//DA//Classwork//0 Activities//Final_Project//Final Cuts//Des_Moines_Liquor_Store//Jupyter Files//testrun//year2016.csv')
y12=pd.read_csv('C://Users//Owner//DA//Classwork//0 Activities//Final_Project//Final Cuts//Des_Moines_Liquor_Store//Jupyter Files//testrun//year2017.csv')

# %% [markdown]
# # ***

# %%
#dummy dataframe to use as an example how dictionaries and functions are applied, easier names to call each portion
ytest17=year17
y12=year12
y13=year13
y14=year14
y15=year15
y16=year16
y17=year17

# %% [markdown]
# # Creating Dictionaries to Clean Nan Values

# %% [markdown]
# ### Columns with Nan values include : Address, City, Zip Code, Store Location, County Number, County, Category, Category Name, Vendor Number, Vendor Name

# %%
# Which columns include nan values in raw data?
listof6 = (y12,y13,y14,y15,y16,y17)
for i in listof6:
    print(i.isna().sum())
# Out:
# Invoice/Item Number         0
# Date                        0
# Store Number                0
# Store Name                  0
# Address                     0
# City                        0
# Zip Code                    0
# Store Location              0
# County Number            3599
# County                   3599
# Category                  284
# Category Name             822
# Vendor Number               0
# Vendor Name                 0
# Item Number                 0
# Item Description            0
# Pack                        0
# Bottle Volume (ml)          0
# State Bottle Cost          10
# State Bottle Retail        10
# Bottles Sold                0
# Sale (Dollars)             10
# Volume Sold (Liters)        0
# Volume Sold (Gallons)       0
# Year                        0
# dtype: int64
# Invoice/Item Number         0
# Date                        0
# Store Number                0
# Store Name                  0
# Address                     0
# City                        0
# Zip Code                    0
# Store Location              0
# County Number            2660
# County                   2660
# Category                  298
# Category Name             810
# Vendor Number               0
# Vendor Name                 0
# Item Number                 0
# Item Description            0
# Pack                        0
# Bottle Volume (ml)          0
# State Bottle Cost           0
# State Bottle Retail         0
# Bottles Sold                0
# Sale (Dollars)              0
# Volume Sold (Liters)        0
# Volume Sold (Gallons)       0
# Year                        0
# dtype: int64
# Invoice/Item Number         0
# Date                        0
# Store Number                0
# Store Name                  0
# Address                     0
# City                        0
# Zip Code                    0
# Store Location              0
# County Number            1054
# County                   1054
# Category                  480
# Category Name            1057
# Vendor Number               0
# Vendor Name                 0
# Item Number                 0
# Item Description            0
# Pack                        0
# Bottle Volume (ml)          0
# State Bottle Cost           0
# State Bottle Retail         0
# Bottles Sold                0
# Sale (Dollars)              0
# Volume Sold (Liters)        0
# Volume Sold (Gallons)       0
# Year                        0
# dtype: int64
# Invoice/Item Number         0
# Date                        0
# Store Number                0
# Store Name                  0
# Address                     0
# City                        0
# Zip Code                    0
# Store Location              0
# County Number            1119
# County                   1119
# Category                  773
# Category Name            1462
# Vendor Number               0
# Vendor Name                 0
# Item Number                 0
# Item Description            0
# Pack                        0
# Bottle Volume (ml)          0
# State Bottle Cost           0
# State Bottle Retail         0
# Bottles Sold                0
# Sale (Dollars)              0
# Volume Sold (Liters)        0
# Volume Sold (Gallons)       0
# Year                        0
# dtype: int64
# Invoice/Item Number          0
# Date                         0
# Store Number                 0
# Store Name                   0
# Address                    965
# City                       965
# Zip Code                  1010
# Store Location             965
# County Number            69336
# County                   69336
# Category                   350
# Category Name             6100
# Vendor Number                2
# Vendor Name                  0
# Item Number                  0
# Item Description             0
# Pack                         0
# Bottle Volume (ml)           0
# State Bottle Cost            0
# State Bottle Retail          0
# Bottles Sold                 0
# Sale (Dollars)               0
# Volume Sold (Liters)         0
# Volume Sold (Gallons)        0
# Year                         0
# dtype: int64
# Invoice/Item Number         0
# Date                        0
# Store Number                0
# Store Name                  0
# Address                  1411
# City                     1410
# Zip Code                 1410
# Store Location           1410
# County Number            1410
# County                   1410
# Category                 5835
# Category Name            5835
# Vendor Number               1
# Vendor Name                 1
# Item Number                 0
# Item Description            0
# Pack                        0
# Bottle Volume (ml)          0
# State Bottle Cost           0
# State Bottle Retail         0
# Bottles Sold                0
# Sale (Dollars)              0
# Volume Sold (Liters)        0
# Volume Sold (Gallons)       0
# Year                        0
# dtype: int64

# %% [markdown]
# ### For each of these columns, a dictionary is made with a corresponding column where a 1:1 relationship is present. Therefore, the relationship can be used to fill in rows where the data is missing. The process for the 'Address' column walks through this process.

# %% [markdown]
# ### Address

# %%
#concatenating data from Store Number and Address columns
sall=pd.concat([y17[['Store Number','Address']],y16[['Store Number','Address']],y15[['Store Number','Address']],y14[['Store Number','Address']],y13[['Store Number','Address']],y12[['Store Number','Address']]])
#dropping all nan values from Address (there are no nons in the Store Number column)
sall=sall[sall['Address'].notna()]
#dropping all duplicate store number values 
sall.drop_duplicates(subset=['Store Number'],inplace=True)
#exporting to a file for easy future reference
sall.to_csv('storenumaddress.csv')

# %%
#there are 1884 stores in the entire dataset, checking length to confirm uniqueness of values
len(slall)
# Out:
# 1884

# %%
#create dictionary with 'Store Number' column as keys and 'Address' column as values
salldict={}
for i in sall['Store Number']:
    salldict[i]=sall[sall['Store Number']==i]['Address'].values[0]

# %%
#this function will compare see if the address cell in a row is a nan and, if so, attempt to 
# find the key:value pair in the address dictionary to match the store number in the row and fill in the address
def get_address(x,y):
    storelist=list(salldict.keys())
    if (pd.isna(x)) & (y in storelist):
        return salldict[y]
    else:
        return x

# %%
#a map function is used to apply the get_address function to all rows in a dataset
ytest17['Address']=list(map(get_address,ytest17['Address'],ytest17['Store Number']))
# Out:
# C:\Users\Owner\AppData\Local\Temp/ipykernel_20456/359753998.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ytest17['Address']=list(map(get_address,ytest17['Address'],ytest17['Store Number']))

# %%
ytest17['Address'].isna().sum()
# Out:
# 1

# %%
y17[y17['Address'].isna()]['Store Number']
# Out:
# 11757989    9932
# Name: Store Number, dtype: int64

# %%
#Address column will be dropped later so nan is inconsequential,
#the row would be dropped later anyways as the store is in Dubuque, not Des Moines
y17[y17['Store Number']==9932]
# Out:
#          Unnamed: 0 Invoice/Item Number        Date  Store Number  \
# 1050009    11757989     INV-05674000001  06/22/2017          9932
#
#                      Store Name Address     City  Zip Code  \
# 1050009  3-Oaks Distillery, LLC     NaN  Dubuque   52002.0
#
#                                  Store Location  County Number   County  \
# 1050009  Dubuque 52002\n(42.516027, -90.766335)           31.0  DUBUQUE
#
#           Category     Category Name  Vendor Number             Vendor Name  \
# 1050009  1011100.0  Blended Whiskies          215.0  3-Oaks Distillery, LLC
#
#          Item Number           Item Description  Pack  Bottle Volume (ml)  \
# 1050009        27890  3-Oaks Distillery Whiskey    12                 750
#
#         State Bottle Cost State Bottle Retail  Bottles Sold Sale (Dollars)  \
# 1050009            $21.60              $32.40             1        $388.80
#
#          Volume Sold (Liters)  Volume Sold (Gallons)  Year
# 1050009                  0.75                   0.19    17

# %% [markdown]
# ### Store Location

# %%
slall=pd.concat([y17[['Store Number','Store Location']],y16[['Store Number','Store Location']],y15[['Store Number','Store Location']],y14[['Store Number','Store Location']],y13[['Store Number','Store Location']],y12[['Store Number','Store Location']]])
slall=slall[slall['Store Location'].notna()]
slall.drop_duplicates(subset=['Store Number'],inplace=True)
slall.to_csv('storenumlocation.csv')

# %%
#there are 1884 stores in the entire dataset, checking length to confirm uniqueness of values
len(slall)
# Out:
# 1884

# %%
slalldict={}
for i in slall['Store Number']:
    slalldict[i]=slall[slall['Store Number']==i]['Store Location'].values[0]

# %%
def get_store_location(x,y):
    storelist=list(slalldict.keys())
    if (pd.isna(x)) & (y in storelist):
        return slalldict[y]
    else:
        return x

# %%
ytest17['Store Location'].isna().sum()
# Out:
# 1410

# %%
ytest17['Store Location']=list(map(get_store_location,ytest17['Store Location'],ytest17['Store Number']))
# Out:
# C:\Users\Owner\AppData\Local\Temp/ipykernel_20456/2463105831.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ytest17['Store Location']=list(map(get_store_location,ytest17['Store Location'],ytest17['Store Number']))

# %%
ytest17['Store Location'].isna().sum()
# Out:
# 0

# %% [markdown]
# ### Zip Code

# %%
zipna=pd.concat([y17[['Store Number','Zip Code']],y16[['Store Number','Zip Code']],y15[['Store Number','Zip Code']],y14[['Store Number','Zip Code']],y13[['Store Number','Zip Code']],y12[['Store Number','Zip Code']]])
zipna=zipna[zipna['Zip Code'].notna()]
zipna.drop_duplicates(subset=['Store Number'],inplace=True)
zipna.to_csv('storenumzip.csv')

# %%
len(zipna)
# Out:
# 1884

# %%
zipdict={}
for i in zipna['Store Number']:
    zipdict[i]=zipna[zipna['Store Number']==i]['Zip Code'].values[0]

# %%
def get_zip(x,y):
    storelist=list(zipdict.keys())
    if (pd.isna(x)) and (y in storelist):
        return zipdict[y]
    else:
        return x

# %%
ytest17['Zip Code'].isna().sum()
# Out:
# 1410

# %%
ytest17['Zip Code']=list(map(get_zip,ytest17['Zip Code'],ytest17['Store Number']))
# Out:
# C:\Users\Owner\AppData\Local\Temp/ipykernel_20456/836976134.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ytest17['Zip Code']=list(map(get_zip,ytest17['Zip Code'],ytest17['Store Number']))

# %%
ytest17['Zip Code'].isna().sum()
# Out:
# 0

# %% [markdown]
# ### County

# %%
countyna=pd.concat([y17[['Store Number','County']],y16[['Store Number','County']],y15[['Store Number','County']],y14[['Store Number','County']],y13[['Store Number','County']],y12[['Store Number','County']]])
countyna=countyna[countyna['County'].notna()]
countyna.drop_duplicates(subset=['Store Number'],inplace=True)
#countyna.to_csv('storenumcounty.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5212/3220301470.py in <module>
# ----> 1 countyna=pd.concat([y17[['Store Number','County']],y16[['Store Number','County']],y15[['Store Number','County']],y14[['Store Number','County']],y13[['Store Number','County']],y12[['Store Number','County']]])
#       2 countyna=countyna[countyna['County'].notna()]
#       3 countyna.drop_duplicates(subset=['Store Number'],inplace=True)
#       4 #countyna.to_csv('storenumcounty.csv')
#
# NameError: name 'y16' is not defined

# %%
len(countyna)
# Out:
# 1883

# %%
ytest17[ytest17['City']=='Mason City']['County'].unique()
# Out:
# array(['CERRO GORD'], dtype=object)

# %%
len(ytest17[ytest17['County']=='CERRO GORD'])
# Out:
# 27745

# %%
countydict={}
for i in countyna['Store Number']:
    countydict[i]=countyna[countyna['Store Number']==i]['County'].values[0]

# %%
def get_county(x,y):
    storelist=list(countydict.keys())
    if (pd.isna(x)) and (y in storelist):
        return countydict[y]
    else:
        return x

# %%
ytest17['County'].isna().sum()
# Out:
# 1410

# %%
ytest17['County']=list(map(get_county,ytest17['County'],ytest17['Store Number']))
# Out:
# C:\Users\Owner\AppData\Local\Temp/ipykernel_20456/2542552146.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ytest17['County']=list(map(get_county,ytest17['County'],ytest17['Store Number']))

# %%
ytest17['County'].isna().sum()
# Out:
# 0

# %% [markdown]
# ### County Number

# %%
countynumna=pd.concat([y17[['Store Number','County Number']],y16[['Store Number','County Number']],y15[['Store Number','County Number']],y14[['Store Number','County Number']],y13[['Store Number','County Number']],y12[['Store Number','County Number']]])
countynumna=countynumna[countynumna['County Number'].notna()]
countynumna.drop_duplicates(subset=['Store Number'],inplace=True)
countynumna.to_csv('storenumcountynum.csv')

# %%
len(countynumna)
# Out:
# 1883

# %%
countynumdict={}
for i in countynumna['Store Number']:
    countynumdict[i]=countynumna[countynumna['Store Number']==i]['County Number'].values[0]

# %%
def get_county_number(x,y):
    storelist=list(countynumdict.keys())
    if (pd.isna(x)) and (y in storelist):
        return countynumdict[y]
    else:
        return x

# %%
ytest17['County Number'].isna().sum()
# Out:
# 1410

# %%
ytest17['County Number']=list(map(get_county_number,ytest17['County Number'],ytest17['Store Number']))
# Out:
# C:\Users\Owner\AppData\Local\Temp/ipykernel_20456/2188662252.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ytest17['County Number']=list(map(get_county_number,ytest17['County Number'],ytest17['Store Number']))

# %%
ytest17['County Number'].isna().sum()
# Out:
# 0

# %% [markdown]
# ### City

# %%
cityna=pd.concat([y17[['Store Number','City']],y16[['Store Number','City']],y15[['Store Number','City']],y14[['Store Number','City']],y13[['Store Number','City']],y12[['Store Number','City']]])
cityna=cityna[cityna['City'].notna()]
cityna.drop_duplicates(subset=['Store Number'],inplace=True)
cityna.to_csv('storenumcity.csv')

# %%
len(cityna)
# Out:
# 1884

# %%
citydict={}
for i in cityna['Store Number']:
    citydict[i]=cityna[cityna['Store Number']==i]['City'].values[0]

# %%
def get_city(x,y):
    storelist=list(citydict.keys())
    if (pd.isna(x)) and (y in storelist):
        return citydict[y]
    else:
        return x

# %%
ytest17['City'].isna().sum()
# Out:
# 1410

# %%
ytest17['City']=list(map(get_city,ytest17['City'],ytest17['Store Number']))
# Out:
# C:\Users\Owner\AppData\Local\Temp/ipykernel_20456/825511626.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ytest17['City']=list(map(get_city,ytest17['City'],ytest17['Store Number']))

# %%
ytest17['City'].isna().sum()
# Out:
# 0

# %% [markdown]
# ### Category

# %%
catna=pd.concat([y17[['Item Description','Category']],y16[['Item Description','Category']],y15[['Item Description','Category']],y14[['Item Description','Category']],y13[['Item Description','Category']],y12[['Item Description','Category']]])
catna=catna[catna['Category'].notna()]
catna.drop_duplicates(subset=['Item Description'],inplace=True)
catna.to_csv('idcategory.csv')

# %%
len(catna)
# Out:
# 5795

# %%
catdict={}
for i in catna['Item Description']:
    catdict[i]=catna[catna['Item Description']==i]['Category'].values[0]

# %%
def get_category(x,y):
    storelist=list(catdict.keys())
    if (pd.isna(x)) and (y in storelist):
        return catdict[y]
    else:
        return x

# %%
ytest17['Category'].isna().sum()

ytest17['Category']=list(map(category,ytest17['Category'],ytest17['Item Description']))
ytest17['Category']=list(map(category2,ytest17['Category'],ytest17['Item Description']))
ytest17['Category']=list(map(get_category,ytest17['Category'],ytest17['Item Description']))
# Out:
# 5835

# %%
ytest17['Category']=list(map(get_category,ytest17['Category'],ytest17['Item Description']))
# Out:
# C:\Users\Owner\AppData\Local\Temp/ipykernel_20456/2001454877.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ytest17['Category']=list(map(get_category,ytest17['Category'],ytest17['Item Description']))

# %%
ytest17['Category'].isna().sum()
# Out:
# 827

# %%
ytest17[ytest17['Category'].isna()].head()
# Out:
#          Invoice/Item Number        Date  Store Number  \
# 10709494     INV-02503200001  01/03/2017          2590
# 10924145     INV-03158200002  02/08/2017          4129
# 10924152     INV-03158200009  02/08/2017          4129
# 10938419     INV-03200500002  02/10/2017          4669
# 10938420     INV-03200500003  02/10/2017          4669
#
#                                    Store Name               Address  \
# 10709494  Hy-Vee Food Store #5 / Cedar Rapids  3235 Oakland Road NE
# 10924145                      Cyclone Liquors       626 Lincoln Way
# 10924152                      Cyclone Liquors       626 Lincoln Way
# 10938419                Vom Fass / Des Moines          833, 42nd St
# 10938420                Vom Fass / Des Moines          833, 42nd St
#
#                   City  Zip Code  \
# 10709494  Cedar Rapids   52402.0
# 10924145          Ames   50010.0
# 10924152          Ames   50010.0
# 10938419    Des Moines   50312.0
# 10938420    Des Moines   50312.0
#
#                                              Store Location  County Number  \
# 10709494  3235 Oakland Road NE\nCedar Rapids 52402\n(42....           57.0
# 10924145  626 Lincoln Way\nAmes 50010\n(42.022854, -93.6...           85.0
# 10924152  626 Lincoln Way\nAmes 50010\n(42.022854, -93.6...           85.0
# 10938419  833, 42nd St\nDes Moines 50312\n(41.593431, -9...           77.0
# 10938420  833, 42nd St\nDes Moines 50312\n(41.593431, -9...           77.0
#
#          County  Category Category Name  Vendor Number  \
# 10709494   LINN       NaN           NaN          305.0
# 10924145  STORY       NaN           NaN          363.0
# 10924152  STORY       NaN           NaN          363.0
# 10938419   POLK       NaN           NaN          885.0
# 10938420   POLK       NaN           NaN          885.0
#
#                         Vendor Name  Item Number             Item Description  \
# 10709494                    Mhw LTD       965015         Galliano L'Autentico
# 10924145        Paterno Imports LTD       995509  Bains Cape Mountain Whiskey
# 10924152        Paterno Imports LTD       995508  Don Pancho Origenes 8YR Rum
# 10938419  YAHARA BAY DISTILLERS INC       995214           Barbados Rum 100ml
# 10938420  YAHARA BAY DISTILLERS INC       995218         Barbados Rum 1 Liter
#
#           Pack  Bottle Volume (ml) State Bottle Cost State Bottle Retail  \
# 10709494    12                 750            $19.05              $28.58
# 10924145     6                 750            $18.95              $28.43
# 10924152     6                 750            $20.34              $30.51
# 10938419     1                 100            $38.74              $58.11
# 10938420     1                1000            $23.67              $35.51
#
#           Bottles Sold Sale (Dollars)  Volume Sold (Liters)  \
# 10709494             1        $342.96                  0.75
# 10924145             3        $170.58                  2.25
# 10924152             1        $183.06                  0.75
# 10938419             1         $58.11                  0.10
# 10938420             1         $35.51                  1.00
#
#           Volume Sold (Gallons) Year
# 10709494                   0.19   17
# 10924145                   0.59   17
# 10924152                   0.19   17
# 10938419                   0.02   17
# 10938420                   0.26   17

# %%
#'What' are the unique item descriptions of the rows with these 'Category' nan values
ytest17[ytest17['Category'].isna()]['Item Description'].unique()
# Out:
# array(["Galliano L'Autentico", 'Bains Cape Mountain Whiskey',
#        'Don Pancho Origenes 8YR Rum', 'Barbados Rum 100ml',
#        'Barbados Rum 1 Liter', 'Barbados Rum 200 ml',
#        'Barbados Rum 375ml', 'Barbados Rum 50ml', 'Barbados Rum 750ml',
#        'Spanish Single Malt 100ml', 'Spanish Single Malt 1 Liter',
#        'Spanish Single Malt 375ml', 'Spanish Single Malt 50ml',
#        'Spanish Single Malt 750ml', 'Spanish Single Malt 200ml',
#        'Deep Eddy  Lemon Vodka', 'Diplomatico Reserva Exclusiva',
#        'Grand Teton Vodka', '"Beefeater ""24"""', 'Athena Liq Ouzo Rum',
#        'Glenmorangie Bacalta HA', 'Valentine Vodka', 'Ansac VS  Cognac',
#        'Aalborg Jubilaeums Aquavit', 'Patron Silver 750 Box Tray Pack',
#        'Patron Citronge Mango', 'Lairds Old Apple Brandy 7YR',
#        'Green Absinthe', 'Red Absinthe', 'Deanston Organic 14YR',
#        'Calvados Morin Selection 3YR',
#        'Seven Devils Straight Bourbon Whiskey HA', 'HA Seven Devils',
#        'Don Amado Mezcal Rustico', 'HA Michters US*1 Small Batch',
#        'HA Orphan Barrel Barterhouse', 'HA Orphan Barrel Forged Oak',
#        'Rothman & Winter Orchard Peach',
#        'HA Abraham Bowman Wine Finish Whiskey',
#        'HA Highland Park Ice Edition', 'HA Pikesville Rye 110prf',
#        'HA Johnnie Walker Private Collection 2014 Smoke',
#        'Old Forester 1920', 'Jose Cuervo Especial Silver/Flask',
#        'Jose Cuervo Especial Gold /Flask', 'Ron Abuelo Anejo 7YR',
#        "Aberlour A''bunadh", 'El Mayor Extra Anejo 100% Agave',
#        'Ezra Brooks Bourbon Cream Mini', "Michter's US*1 SB Rye",
#        'Glen Moray Scotch Classic Port Cask w/2 Glasses',
#        'HA Laphroaig 25YR Cask Strength', 'Ron Abuelo 12YR',
#        'Zaya Gran Reserva Rum w/2 Rocks Glasses',
#        'Corralejo Silver w/2 Sangrita Glasses',
#        'Southern Comfort w/2 Rock Glasses',
#        'Crystal Head Vodka w/2 Skull Glasses', 'Hornitos Plata w/Glasses',
#        'Hornitos Reposado w/Glasses',
#        'Glen Moray Classic Chardonnay Cask Finish w/2 Glasses'],
#       dtype=object)

# %%
#The dictionary misses several items in the category column. A large list was compiled by manually 
#identifying the problematic categories for their respective items

def category(x,y):
    if (pd.isna(x)) and (y=='Evan Williams Egg Nog'):
        return '1081200.'
    elif (pd.isna(x)) and (y=="Carolan's Irish Cream w/2 Bowls"):
        return '1701100.'
    elif (pd.isna(x)) and (y=="Wild Turkey American Honey Shot Tap"):
        return '1701100.'
    elif (pd.isna(x)) and (y=="Chambord Liqueur w/2 Glasses"):
        return '1701100.'
    elif (pd.isna(x)) and (y=='Gentleman Jack w/2 Glasses'):
        return '1701100.'
    elif (pd.isna(x)) and (y=='Caravella Limoncello w/Glass'):
        return '1701100.'
    elif (pd.isna(x)) and (y=='Craigellachie'):
        return '1012200.'
    elif (pd.isna(x)) and (y=='Glenfiddich 1963 Replica HA'):
        return '1012210.'
    elif (pd.isna(x)) and (y=='Pinnacle Candy Cane Trial Pack'):
        return '1701200.'
    elif (pd.isna(x)) and (y=='Dry Fly Gin'):
        return '1041100.'
    elif (pd.isna(x)) and (y=="Galliano L'Autentico"):
        return '1082900.'
    elif (pd.isna(x)) and (y=='1800 Reposado'):
        return '1022200.'
    elif (pd.isna(x)) and (y=='Grand Marnier Cuvee 1880 HA'):
        return '1082100.'
    elif (pd.isna(x)) and (y=='Courvoisier Gold'):
        return '1082900.'
    elif (pd.isna(x)) and (y=='Ardbeg Auriverdes HA'):
        return '1012210.'
    elif (pd.isna(x)) and (y=="Galliano L'Autentico"):
            return '1082900.'
    elif (pd.isna(x)) and (y=='Spanish Single Malt 100ml'):
        return '1012210.'
    elif (pd.isna(x)) and (y=='Spanish Single Malt 1 Liter'):
        return  '1012210.'
    elif (pd.isna(x)) and (y=='Spanish Single Malt 375ml'):
        return  '1012210.'
    elif (pd.isna(x)) and (y=='Spanish Single Malt 50ml'):
        return  '1012210.'
    elif (pd.isna(x)) and (y=='Spanish Single Malt 750ml'):
        return  '1012210.'
    elif (pd.isna(x)) and (y=='Spanish Single Malt 200ml'):
        return  '1012210.'
    elif (pd.isna(x)) and (y=='Deep Eddy Lemon Vodka'):
        return '1031200.'
    elif (pd.isna(x)) and (y=='"Beefeater ""24"""'):
        return '1042100.'
    elif (pd.isna(x)) and (y=='Ansac VS  Cognac'):
        return '1052100.'
    elif (pd.isna(x)) and (y=='Aalborg Jubilaeums Aquavit'):
        return '1082100.'
    elif (pd.isna(x)) and (y=='Patron Silver 750 Box Tray Pack'):
        return  '1701100.'
    elif (pd.isna(x)) and (y=='Patron Citronge Mango'):
        return '1022200.'
    elif (pd.isna(x)) and (y=='Deanston Organic 14YR'):
        return '1012210.'
    elif (pd.isna(x)) and (y=='HA Orphan Barrel Barterhouse'):
        return '1011200.'
    elif (pd.isna(x)) and (y=='HA Orphan Barrel Forged Oak'):
        return '1011200.'
    elif (pd.isna(x)) and (y=='Rothman & Winter Orchard Peach'):
        return '1082900.'
    elif (pd.isna(x)) and (y=='HA Pikesville Rye 110prf'):
        return '1011500.'
    elif (pd.isna(x)) and (y=='HA Johnnie Walker Private Collection 2014 Smoke'):
        return '1012200.'
    elif (pd.isna(x)) and (y=='Jose Cuervo Especial Silver/Flask'):
        return '1701100.'
    elif (pd.isna(x)) and (y=='Jose Cuervo Especial Gold /Flask'):
        return '1701100.'
    elif (pd.isna(x)) and (y=="Aberlour A''bunadh"):
        return '1012210.'
    elif (pd.isna(x)) and (y=='El Mayor Extra Anejo 100% Agave'):
        return '1022100.'
    elif (pd.isna(x)) and (y=='Ezra Brooks Bourbon Cream Mini'):
        return '1701100.'
    elif (pd.isna(x)) and (y=="Michter's US*1 SB Rye"):
        return '1011500.'
    elif (pd.isna(x)) and (y=='Glen Moray Scotch Classic Port Cask w/2 Glasses'):
        return '1701100.'
    elif (pd.isna(x)) and (y=='Zaya Gran Reserva Rum w/2 Rocks Glasses'):
        return  '1701100.'
    elif (pd.isna(x)) and (y=='Corralejo Silver w/2 Sangrita Glasses'):
        return '1701100.'
    elif (pd.isna(x)) and (y=='Southern Comfort w/2 Rock Glasses'):
        return '1701100.'
    elif (pd.isna(x)) and (y=='Crystal Head Vodka w/2 Skull Glasses'):
        return '1701100.'
    elif (pd.isna(x)) and (y=='Hornitos Plata w/Glasses'):
        return '1701100.'
    elif (pd.isna(x)) and (y=='Hornitos Reposado w/Glasses'):
        return  '1701100.'
    elif (pd.isna(x)) and (y=='Glen Moray Classic Chardonnay Cask Finish w/2 Glasses'):
        return '1701100.'
    else:
        return x

# %%
ytest17['Category']=list(map(category,ytest17['Category'],ytest17['Item Description']))
# Out:
# C:\Users\Owner\AppData\Local\Temp/ipykernel_20456/2395316346.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ytest17['Category']=list(map(category,ytest17['Category'],ytest17['Item Description']))

# %%
#after applying map function, how many nan values are still in 'Category'
ytest17['Category'].isna().sum()
# Out:
# 128

# %%
#I was not able to identify the Categories of the following:
ytest17[ytest17['Category'].isna()]['Item Description'].unique()
# Out:
# array(['Bains Cape Mountain Whiskey', 'Don Pancho Origenes 8YR Rum',
#        'Barbados Rum 100ml', 'Barbados Rum 1 Liter',
#        'Barbados Rum 200 ml', 'Barbados Rum 375ml', 'Barbados Rum 50ml',
#        'Barbados Rum 750ml', 'Deep Eddy  Lemon Vodka',
#        'Diplomatico Reserva Exclusiva', 'Grand Teton Vodka',
#        'Athena Liq Ouzo Rum', 'Glenmorangie Bacalta HA',
#        'Valentine Vodka', 'Lairds Old Apple Brandy 7YR', 'Green Absinthe',
#        'Red Absinthe', 'Calvados Morin Selection 3YR',
#        'Seven Devils Straight Bourbon Whiskey HA', 'HA Seven Devils',
#        'Don Amado Mezcal Rustico', 'HA Michters US*1 Small Batch',
#        'HA Abraham Bowman Wine Finish Whiskey',
#        'HA Highland Park Ice Edition', 'Old Forester 1920',
#        'Ron Abuelo Anejo 7YR', 'HA Laphroaig 25YR Cask Strength',
#        'Ron Abuelo 12YR'], dtype=object)

# %% [markdown]
# ### Category Name

# %%
catnamena=pd.concat([y17[['Item Description','Category Name']],y16[['Item Description','Category Name']],y15[['Item Description','Category Name']],y14[['Item Description','Category Name']],y13[['Item Description','Category Name']],y12[['Item Description','Category Name']]])
catnamena=catnamena[catnamena['Category Name'].notna()]
catnamena.drop_duplicates(subset=['Item Description'],inplace=True)
catnamena.to_csv('idcategoryname.csv')

# %%
len(catnamena)
# Out:
# 5758

# %%
catnamedict={}
for i in catnamena['Item Description']:
    catnamedict[i]=catnamena[catnamena['Item Description']==i]['Category Name'].values[0]

# %%
def get_category_name(x,y):
    storelist=list(catnamedict.keys())
    if (pd.isna(x)) and (y in storelist):
        return catnamedict[y]
    else:
        return x

# %%
#no na values after function is applied (perfect!)
ytest17['Category Name'].isna().sum()
# Out:
# 5835

# %%
ytest17['Category Name']=list(map(get_category_name,ytest17['Category Name'],ytest17['Item Description']))
# Out:
# C:\Users\Owner\AppData\Local\Temp/ipykernel_20456/1951155326.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ytest17['Category Name']=list(map(get_category_name,ytest17['Category Name'],ytest17['Item Description']))

# %%
#no na values after function is applied (perfect!)
ytest17['Category Name'].isna().sum()
# Out:
# 827

# %%
# As Category and Category Name are related and cleaned with the same approach, the category name dictionary 
#also misses several items in the Category Name column. A large list was also compiled for this column by manually 
#identifying the problematic Category Names for their respective items

def category_name(x,y):
    if (pd.isna(x)) and (y=='Herradura Gold Reposado 6pak'):
        return 'TEQUILA'
    elif (pd.isna(x)) and (y=='Evan Williams Egg Nog'):
        return 'CREAM LIQUEURS'
    elif (pd.isna(x)) and (y=="Carolan's Irish Cream w/2 Bowls"):
        return 'DECANTERS & SPECIALTY PACKAGES'
    elif (pd.isna(x)) and (y=='Rogue Dark Rum'):
        return 'AGED DARK RUM'
    elif (pd.isna(x)) and (y=='Ultimat Vodka'):
        return 'IMPORTED VODKA'
    elif (pd.isna(x)) and (y=='Herradura Anejo Tequila'):
        return 'TEQUILA'
    elif (pd.isna(x)) and (y=="Whaler's Original Dark Rum"):
        return 'SPECIAL ORDER ITEMS'
    elif (pd.isna(x)) and (y=="Wild Turkey American Honey Shot Tap"):
        return 'DECANTERS & SPECIALTY PACKAGES'
    elif (pd.isna(x)) and (y=="Chambord Liqueur w/2 Glasses"):
        return 'DECANTERS & SPECIALTY PACKAGES'
    elif (pd.isna(x)) and (y=='Gentleman Jack w/2 Glasses'):
        return 'DECANTERS & SPECIALTY PACKAGES'
    elif (pd.isna(x)) and (y=='Caravella Limoncello w/Glass'):
        return 'DECANTERS & SPECIALTY PACKAGES'
    elif (pd.isna(x)) and (y=='Craigellachie'):
        return 'SCOTCH WHISKIES'
    elif (pd.isna(x)) and (y=='Glenfiddich 1963 Replica HA'):
        return 'SINGLE MALT SCOTCH'
    elif (pd.isna(x)) and (y=='Pinnacle Candy Cane Trial Pack'):
        return 'Holiday VAP'
    elif (pd.isna(x)) and (y=='Dry Fly Gin'):
        return 'AMERICAN DRY GINS'
    elif (pd.isna(x)) and (y=="Galliano L'Autentico"):
        return 'MISC. IMPORTED CORDIALS & LIQUEURS'
    elif (pd.isna(x)) and (y=='1800 Reposado'):
        return 'TEQUILA'
    elif (pd.isna(x)) and (y=='Grand Marnier Cuvee 1880 HA'):
        return 'Imported Cordials & Liqueur'
    elif (pd.isna(x)) and (y=='Courvoisier Gold'):
        return 'MISC. IMPORTED CORDIALS & LIQUEURS'
    elif (pd.isna(x)) and (y=='Ardbeg Auriverdes HA'):
        return 'SINGLE MALT SCOTCH'
    elif (pd.isna(x)) and (y=="Galliano L'Autentico"):
        return 'MISC. IMPORTED CORDIALS & LIQUEURS'
    elif (pd.isna(x)) and (y=='Spanish Single Malt 100ml'):
        return 'SINGLE MALT SCOTCH'
    elif (pd.isna(x)) and (y=='Spanish Single Malt 1 Liter'):
        return 'SINGLE MALT SCOTCH'
    elif (pd.isna(x)) and (y=='Spanish Single Malt 375ml'):
        return 'SINGLE MALT SCOTCH'
    elif (pd.isna(x)) and (y=='Spanish Single Malt 50ml'):
        return 'SINGLE MALT SCOTCH'
    elif (pd.isna(x)) and (y=='Spanish Single Malt 750ml'):
        return 'SINGLE MALT SCOTCH'
    elif (pd.isna(x)) and (y=='Spanish Single Malt 200ml'):
        return 'SINGLE MALT SCOTCH'
    elif (pd.isna(x)) and (y=='Deep Eddy  Lemon Vodka'):
        return 'VODKA FLAVORED'
    elif (pd.isna(x)) and (y=='"Beefeater ""24"""'):
        return 'IMPORTED DRY GINS'
    elif (pd.isna(x)) and (y=='Ansac VS  Cognac'):
        return 'Imported Brandies'
    elif (pd.isna(x)) and (y=='Aalborg Jubilaeums Aquavit'):
        return 'Imported Cordials & Liqueur'
    elif (pd.isna(x)) and (y=='Patron Silver 750 Box Tray Pack'):
        return 'DECANTERS & SPECIALTY PACKAGES'
    elif (pd.isna(x)) and (y=='Patron Citronge Mango'):
        return '100% Agave Tequila'
    elif (pd.isna(x)) and (y=='Deanston Organic 14YR'):
        return 'SINGLE MALT SCOTCH'
    elif (pd.isna(x)) and (y=='HA Orphan Barrel Barterhouse'):
        return 'STRAIGHT BOURBON WHISKIES'
    elif (pd.isna(x)) and (y=='HA Orphan Barrel Forged Oak'):
        return 'STRAIGHT BOURBON WHISKIES'
    elif (pd.isna(x)) and (y=='Rothman & Winter Orchard Peach'):
        return 'MISC. IMPORTED CORDIALS & LIQUEURS'
    elif (pd.isna(x)) and (y=='HA Pikesville Rye 110prf'):
        return 'STRAIGHT RYE WHISKIES'
    elif (pd.isna(x)) and (y=='HA Johnnie Walker Private Collection 2014 Smoke'):
        return 'SCOTCH WHISKIES'
    elif (pd.isna(x)) and (y=='Jose Cuervo Especial Silver/Flask'):
        return 'DECANTERS & SPECIALTY PACKAGES'
    elif (pd.isna(x)) and (y=='Jose Cuervo Especial Gold /Flask'):
        return  'DECANTERS & SPECIALTY PACKAGES'
    elif (pd.isna(x)) and (y=="Aberlour A''bunadh"):
        return 'SINGLE MALT SCOTCH'
    elif (pd.isna(x)) and (y=='El Mayor Extra Anejo 100% Agave'):
        return 'TEQUILA'
    elif (pd.isna(x)) and (y=='Ezra Brooks Bourbon Cream Mini'):
        return 'Temporary & Specialty Packages'
    elif (pd.isna(x)) and (y=="Michter's US*1 SB Rye"):
        return 'STRAIGHT RYE WHISKIES'
    elif (pd.isna(x)) and (y=='Glen Moray Scotch Classic Port Cask w/2 Glasses'):
        return  'DECANTERS & SPECIALTY PACKAGES'
    elif (pd.isna(x)) and (y=='Zaya Gran Reserva Rum w/2 Rocks Glasses'):
        return   'DECANTERS & SPECIALTY PACKAGES'
    elif (pd.isna(x)) and (y=='Corralejo Silver w/2 Sangrita Glasses'):
        return  'DECANTERS & SPECIALTY PACKAGES'
    elif (pd.isna(x)) and (y=='Southern Comfort w/2 Rock Glasses'):
        return  'DECANTERS & SPECIALTY PACKAGES'
    elif (pd.isna(x)) and (y=='Crystal Head Vodka w/2 Skull Glasses'):
        return  'DECANTERS & SPECIALTY PACKAGES'
    elif (pd.isna(x)) and (y=='Hornitos Plata w/Glasses'):
        return  'DECANTERS & SPECIALTY PACKAGES'
    elif (pd.isna(x)) and (y=='Hornitos Reposado w/Glasses'):
        return   'DECANTERS & SPECIALTY PACKAGES'
    elif (pd.isna(x)) and (y=='Glen Moray Classic Chardonnay Cask Finish w/2 Glasses'):
        return  'DECANTERS & SPECIALTY PACKAGES'
    else:
        return x

# %%
ytest17['Category Name']=list(map(category_name,ytest17['Category Name'],ytest17['Item Description']))
# Out:
# C:\Users\Owner\AppData\Local\Temp/ipykernel_20456/669116045.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ytest17['Category Name']=list(map(category_name,ytest17['Category Name'],ytest17['Item Description']))

# %%
ytest17['Category Name'].isna().sum()
# Out:
# 126

# %%
#I was not able to identify the Category Names of the following:
ytest17[ytest17['Category Name'].isna()]['Item Description'].unique()
# Out:
# array(['Bains Cape Mountain Whiskey', 'Don Pancho Origenes 8YR Rum',
#        'Barbados Rum 100ml', 'Barbados Rum 1 Liter',
#        'Barbados Rum 200 ml', 'Barbados Rum 375ml', 'Barbados Rum 50ml',
#        'Barbados Rum 750ml', 'Diplomatico Reserva Exclusiva',
#        'Grand Teton Vodka', 'Athena Liq Ouzo Rum',
#        'Glenmorangie Bacalta HA', 'Valentine Vodka',
#        'Lairds Old Apple Brandy 7YR', 'Green Absinthe', 'Red Absinthe',
#        'Calvados Morin Selection 3YR',
#        'Seven Devils Straight Bourbon Whiskey HA', 'HA Seven Devils',
#        'Don Amado Mezcal Rustico', 'HA Michters US*1 Small Batch',
#        'HA Abraham Bowman Wine Finish Whiskey',
#        'HA Highland Park Ice Edition', 'Old Forester 1920',
#        'Ron Abuelo Anejo 7YR', 'HA Laphroaig 25YR Cask Strength',
#        'Ron Abuelo 12YR'], dtype=object)

# %% [markdown]
# ### Vendor Name

# %%
vennumna=pd.concat([y17[['Item Description','Vendor Name']],y16[['Item Description','Vendor Name']],y15[['Item Description','Vendor Name']],y14[['Item Description','Vendor Name']],y13[['Item Description','Vendor Name']],y12[['Item Description','Vendor Name']]])
vennumna=vennumna[vennumna['Vendor Name'].notna()]
vennumna.drop_duplicates(subset=['Item Description'],inplace=True)
vennumna.to_csv('storenumvendorname.csv')

# %%
len(vennumna)
# Out:
# 5865

# %%
vennumnadict={}
for i in vennumna['Item Description']:
    vennumnadict[i]=vennumna[vennumna['Item Description']==i]['Vendor Name'].values[0]

# %%
def get_vendor_name(x,y):
    storelist=list(vennumnadict.keys())
    if (pd.isna(x)) and (y in storelist):
        return vennumnadict[y]
    else:
        return x

# %%
ytest17['Vendor Name'].isna().sum()
# Out:
# 1

# %%
ytest17['Vendor Name']=list(map(get_vendor_name,ytest17['Vendor Name'],ytest17['Item Description']))
# Out:
# C:\Users\Owner\AppData\Local\Temp/ipykernel_20456/1169516977.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ytest17['Vendor Name']=list(map(get_vendor_name,ytest17['Vendor Name'],ytest17['Item Description']))

# %%
ytest17['Vendor Name'].isna().sum()
# Out:
# 0

# %% [markdown]
# ### Vendor Number

# %%
vennum=pd.concat([y17[['Item Description','Vendor Number']],y16[['Item Description','Vendor Number']],y15[['Item Description','Vendor Number']],y14[['Item Description','Vendor Number']],y13[['Item Description','Vendor Number']],y12[['Item Description','Vendor Number']]])
vennum=vennum[vennum['Vendor Number'].notna()]
vennum.drop_duplicates(subset=['Item Description'],inplace=True)
vennum.to_csv('storenumvendornumber.csv')

# %%
len(vennum)
# Out:
# 5863

# %%
vennumdict={}
for i in vennum['Item Description']:
    vennumdict[i]=vennum[vennum['Item Description']==i]['Vendor Number'].values[0]

# %%
def get_vendor_number(x,y):
    storelist=list(vennumdict.keys())
    if (pd.isna(x)) and (y in storelist):
        return vennumdict[y]
    else:
        return x

# %%
ytest17['Vendor Number'].isna().sum()
# Out:
# 1

# %%
ytest17['Vendor Number']=list(map(get_vendor_number,ytest17['Vendor Number'],ytest17['Item Description']))
# Out:
# C:\Users\Owner\AppData\Local\Temp/ipykernel_20456/1628091444.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ytest17['Vendor Number']=list(map(get_vendor_number,ytest17['Vendor Number'],ytest17['Item Description']))

# %%
ytest17['Vendor Name'].isna().sum()
# Out:
# 0

# %% [markdown]
# ## After all functions are applied, we see the nan values extremely reduced in test dataframe

# %%
ytest17.isna().sum()
# Out:
# Invoice/Item Number        0
# Date                       0
# Store Number               0
# Store Name                 0
# Address                    1
# City                       0
# Zip Code                   0
# Store Location             0
# County Number              0
# County                     0
# Category                 128
# Category Name            126
# Vendor Number              0
# Vendor Name                0
# Item Number                0
# Item Description           0
# Pack                       0
# Bottle Volume (ml)         0
# State Bottle Cost          0
# State Bottle Retail        0
# Bottles Sold               0
# Sale (Dollars)             0
# Volume Sold (Liters)       0
# Volume Sold (Gallons)      0
# Year                       0
# dtype: int64

# %% [markdown]
# # Summary of all functions and dictionaries made above to apply to datasets quickly later on

# %% [markdown]
# # ***

# %%
sall=pd.concat([y17[['Store Number','Address']],y16[['Store Number','Address']],y15[['Store Number','Address']],y14[['Store Number','Address']],y13[['Store Number','Address']],y12[['Store Number','Address']]])
sall=sall[sall['Address'].notna()]
sall.drop_duplicates(subset=['Store Number'],inplace=True)
slall=pd.concat([y17[['Store Number','Store Location']],y16[['Store Number','Store Location']],y15[['Store Number','Store Location']],y14[['Store Number','Store Location']],y13[['Store Number','Store Location']],y12[['Store Number','Store Location']]])
slall=slall[slall['Store Location'].notna()]
slall.drop_duplicates(subset=['Store Number'],inplace=True)
zipna=pd.concat([y17[['Store Number','Zip Code']],y16[['Store Number','Zip Code']],y15[['Store Number','Zip Code']],y14[['Store Number','Zip Code']],y13[['Store Number','Zip Code']],y12[['Store Number','Zip Code']]])
zipna=zipna[zipna['Zip Code'].notna()]
zipna.drop_duplicates(subset=['Store Number'],inplace=True)
countyna=pd.concat([y17[['Store Number','County']],y16[['Store Number','County']],y15[['Store Number','County']],y14[['Store Number','County']],y13[['Store Number','County']],y12[['Store Number','County']]])
countyna=countyna[countyna['County'].notna()]
countyna.drop_duplicates(subset=['Store Number'],inplace=True)
countynumna=pd.concat([y17[['Store Number','County Number']],y16[['Store Number','County Number']],y15[['Store Number','County Number']],y14[['Store Number','County Number']],y13[['Store Number','County Number']],y12[['Store Number','County Number']]])
countynumna=countynumna[countynumna['County Number'].notna()]
countynumna.drop_duplicates(subset=['Store Number'],inplace=True)
cityna=pd.concat([y17[['Store Number','City']],y16[['Store Number','City']],y15[['Store Number','City']],y14[['Store Number','City']],y13[['Store Number','City']],y12[['Store Number','City']]])
cityna=cityna[cityna['City'].notna()]
cityna.drop_duplicates(subset=['Store Number'],inplace=True)
catna=pd.concat([y17[['Item Description','Category']],y16[['Item Description','Category']],y15[['Item Description','Category']],y14[['Item Description','Category']],y13[['Item Description','Category']],y12[['Item Description','Category']]])
catna=catna[catna['Category'].notna()]
catna.drop_duplicates(subset=['Item Description'],inplace=True)
catnamena=pd.concat([y17[['Item Description','Category Name']],y16[['Item Description','Category Name']],y15[['Item Description','Category Name']],y14[['Item Description','Category Name']],y13[['Item Description','Category Name']],y12[['Item Description','Category Name']]])
catnamena=catnamena[catnamena['Category Name'].notna()]
catnamena.drop_duplicates(subset=['Item Description'],inplace=True)
vennumna=pd.concat([y17[['Item Description','Vendor Name']],y16[['Item Description','Vendor Name']],y15[['Item Description','Vendor Name']],y14[['Item Description','Vendor Name']],y13[['Item Description','Vendor Name']],y12[['Item Description','Vendor Name']]])
vennumna=vennumna[vennumna['Vendor Name'].notna()]
vennumna.drop_duplicates(subset=['Item Description'],inplace=True)
vennum=pd.concat([y17[['Item Description','Vendor Number']],y16[['Item Description','Vendor Number']],y15[['Item Description','Vendor Number']],y14[['Item Description','Vendor Number']],y13[['Item Description','Vendor Number']],y12[['Item Description','Vendor Number']]])
vennum=vennum[vennum['Vendor Number'].notna()]
vennum.drop_duplicates(subset=['Item Description'],inplace=True)

# %% [markdown]
# # ***

# %%
sall.to_csv('storenumaddress.csv')
slall.to_csv('storenumlocation.csv')
zipna.to_csv('storenumzip.csv')
countyna.to_csv('storenumcounty.csv')
countynumna.to_csv('storenumcountynum.csv')
cityna.to_csv('storenumcity.csv')
catna.to_csv('idcategory.csv')
catnamena.to_csv('idcategoryname.csv')
vennumna.to_csv('storenumvendorname.csv')
vennum.to_csv('storenumvendornumber.csv')

# %% [markdown]
# # ***

# %%
vennumdict={}
for i in vennum['Item Description']:
    vennumdict[i]=vennum[vennum['Item Description']==i]['Vendor Number'].values[0]
vennumnadict={}
for i in vennumna['Item Description']:
    vennumnadict[i]=vennumna[vennumna['Item Description']==i]['Vendor Name'].values[0]
catnamedict={}
for i in catnamena['Item Description']:
    catnamedict[i]=catnamena[catnamena['Item Description']==i]['Category Name'].values[0]
catdict={}
for i in catna['Item Description']:
    catdict[i]=catna[catna['Item Description']==i]['Category'].values[0]
citydict={}
for i in cityna['Store Number']:
    citydict[i]=cityna[cityna['Store Number']==i]['City'].values[0]
countynumdict={}
for i in countynumna['Store Number']:
    countynumdict[i]=countynumna[countynumna['Store Number']==i]['County Number'].values[0]
slalldict={}
for i in slall['Store Number']:
    slalldict[i]=slall[slall['Store Number']==i]['Store Location'].values[0]
salldict={}
for i in sall['Store Number']:
    salldict[i]=sall[sall['Store Number']==i]['Address'].values[0]
zipdict={}
for i in zipna['Store Number']:
    zipdict[i]=zipna[zipna['Store Number']==i]['Zip Code'].values[0]
countydict={}
for i in countyna['Store Number']:
    countydict[i]=countyna[countyna['Store Number']==i]['County'].values[0]

# %%
#import all saved dictionaries (if needed)
saddy=pd.read_csv('C://Users//Matthew//DA//Activities//Final_Project//Final Cuts//storenumaddress.csv')
scity=pd.read_csv('C://Users//Matthew//DA//Activities//Final_Project//Final Cuts//storenumcity.csv')
sco=pd.read_csv('C://Users//Matthew//DA//Activities//Final_Project//Final Cuts//storenumcounty.csv')
sconum=pd.read_csv('C://Users//Matthew//DA//Activities//Final_Project//Final Cuts//storenumcountynum.csv')
sloc=pd.read_csv('C://Users//Matthew//DA//Activities//Final_Project//Final Cuts//storenumlocation.csv')
szip=pd.read_csv('C://Users//Matthew//DA//Activities//Final_Project//Final Cuts//storenumzip.csv')
venname=pd.read_csv('C://Users//Matthew//DA//Activities//Final_Project//Final Cuts//storenumvendorname.csv')
vennum=pd.read_csv('C://Users//Matthew//DA//Activities//Final_Project//Final Cuts//storenumvendornumber.csv')
cat=pd.read_csv('C://Users//Matthew//DA//Activities//Final_Project//Final Cuts//idcategory.csv')
catname=pd.read_csv('C://Users//Matthew//DA//Activities//Final_Project//Final Cuts//idcategoryname.csv')

# %% [markdown]
# # ***

# %%
def get_category_name(x,y):
    storelist=list(catnamedict.keys())
    if (pd.isna(x)) and (y in storelist):
        return catnamedict[y]
    else:
        return x
def get_category(x,y):
    storelist=list(catdict.keys())
    if (pd.isna(x)) and (y in storelist):
        return catdict[y]
    else:
        return x
def get_address(x,y):
    storelist=list(salldict.keys())
    if (pd.isna(x)) & (y in storelist):
        return salldict[y]
    else:
        return x
def get_store_location(x,y):
    storelist=list(slalldict.keys())
    if (pd.isna(x)) & (y in storelist):
        return slalldict[y]
    else:
        return x
def get_zip(x,y):
    storelist=list(zipdict.keys())
    if (pd.isna(x)) and (y in storelist):
        return zipdict[y]
    else:
        return x
def get_county(x,y):
    storelist=list(countydict.keys())
    if (pd.isna(x)) and (y in storelist):
        return countydict[y]
    else:
        return x
def get_county_number(x,y):
    storelist=list(countynumdict.keys())
    if (pd.isna(x)) and (y in storelist):
        return countynumdict[y]
    else:
        return x
def get_city(x,y):
    storelist=list(citydict.keys())
    if (pd.isna(x)) and (y in storelist):
        return citydict[y]
    else:
        return x
def get_vendor_name(x,y):
    storelist=list(vennumnadict.keys())
    if (pd.isna(x)) and (y in storelist):
        return vennumnadict[y]
    else:
        return x
def get_vendor_number(x,y):
    storelist=list(vennumdict.keys())
    if (pd.isna(x)) and (y in storelist):
        return vennumdict[y]
    else:
        return x

# %% [markdown]
# # ***

# %%
#get_county uses Store Number in dictionary and misses the county for cities of Guttenberg and Belmond
def county(x,y):
    if (pd.isna(x)) and (y=='GUTTENBERG'):
        return 'Clayton'
    elif (pd.isna(x)) and (y=='BELMOND'):
        return 'Wright'
    else:
        return x

#get_county_number uses Store Number in dictionary and misses the county number for cities of Guttenberg and Belmond
def county_number(x,y):
    if (pd.isna(x)) and (y=='GUTTENBERG'):
        return '22.'
    elif (pd.isna(x)) and (y=='BELMOND'):
        return '99.'
    else:
        return x
    
def category_name(x,y):
    if (pd.isna(x)) and (y=='Herradura Gold Reposado 6pak'):
        return 'TEQUILA'
    elif (pd.isna(x)) and (y=='Evan Williams Egg Nog'):
        return 'CREAM LIQUEURS'
    elif (pd.isna(x)) and (y=="Carolan's Irish Cream w/2 Bowls"):
        return 'DECANTERS & SPECIALTY PACKAGES'
    elif (pd.isna(x)) and (y=='Rogue Dark Rum'):
        return 'AGED DARK RUM'
    elif (pd.isna(x)) and (y=='Ultimat Vodka'):
        return 'IMPORTED VODKA'
    elif (pd.isna(x)) and (y=='Herradura Anejo Tequila'):
        return 'TEQUILA'
    elif (pd.isna(x)) and (y=="Whaler's Original Dark Rum"):
        return 'SPECIAL ORDER ITEMS'
    elif (pd.isna(x)) and (y=="Wild Turkey American Honey Shot Tap"):
        return 'DECANTERS & SPECIALTY PACKAGES'
    elif (pd.isna(x)) and (y=="Chambord Liqueur w/2 Glasses"):
        return 'DECANTERS & SPECIALTY PACKAGES'
    elif (pd.isna(x)) and (y=='Gentleman Jack w/2 Glasses'):
        return 'DECANTERS & SPECIALTY PACKAGES'
    elif (pd.isna(x)) and (y=='Caravella Limoncello w/Glass'):
        return 'DECANTERS & SPECIALTY PACKAGES'
    elif (pd.isna(x)) and (y=='Craigellachie'):
        return 'SCOTCH WHISKIES'
    elif (pd.isna(x)) and (y=='Glenfiddich 1963 Replica HA'):
        return 'SINGLE MALT SCOTCH'
    elif (pd.isna(x)) and (y=='Pinnacle Candy Cane Trial Pack'):
        return 'Holiday VAP'
    elif (pd.isna(x)) and (y=='Dry Fly Gin'):
        return 'AMERICAN DRY GINS'
    elif (pd.isna(x)) and (y=="Galliano L'Autentico"):
        return 'MISC. IMPORTED CORDIALS & LIQUEURS'
    elif (pd.isna(x)) and (y=='1800 Reposado'):
        return 'TEQUILA'
    elif (pd.isna(x)) and (y=='Grand Marnier Cuvee 1880 HA'):
        return 'Imported Cordials & Liqueur'
    elif (pd.isna(x)) and (y=='Courvoisier Gold'):
        return 'MISC. IMPORTED CORDIALS & LIQUEURS'
    elif (pd.isna(x)) and (y=='Ardbeg Auriverdes HA'):
        return 'SINGLE MALT SCOTCH'
    elif (pd.isna(x)) and (y=="Galliano L'Autentico"):
        return 'MISC. IMPORTED CORDIALS & LIQUEURS'
    elif (pd.isna(x)) and (y=='Spanish Single Malt 100ml'):
        return 'SINGLE MALT SCOTCH'
    elif (pd.isna(x)) and (y=='Spanish Single Malt 1 Liter'):
        return 'SINGLE MALT SCOTCH'
    elif (pd.isna(x)) and (y=='Spanish Single Malt 375ml'):
        return 'SINGLE MALT SCOTCH'
    elif (pd.isna(x)) and (y=='Spanish Single Malt 50ml'):
        return 'SINGLE MALT SCOTCH'
    elif (pd.isna(x)) and (y=='Spanish Single Malt 750ml'):
        return 'SINGLE MALT SCOTCH'
    elif (pd.isna(x)) and (y=='Spanish Single Malt 200ml'):
        return 'SINGLE MALT SCOTCH'
    elif (pd.isna(x)) and (y=='Deep Eddy  Lemon Vodka'):
        return 'VODKA FLAVORED'
    elif (pd.isna(x)) and (y=='"Beefeater ""24"""'):
        return 'IMPORTED DRY GINS'
    elif (pd.isna(x)) and (y=='Ansac VS  Cognac'):
        return 'Imported Brandies'
    elif (pd.isna(x)) and (y=='Aalborg Jubilaeums Aquavit'):
        return 'Imported Cordials & Liqueur'
    elif (pd.isna(x)) and (y=='Patron Silver 750 Box Tray Pack'):
        return 'DECANTERS & SPECIALTY PACKAGES'
    elif (pd.isna(x)) and (y=='Patron Citronge Mango'):
        return '100% Agave Tequila'
    elif (pd.isna(x)) and (y=='Deanston Organic 14YR'):
        return 'SINGLE MALT SCOTCH'
    elif (pd.isna(x)) and (y=='HA Orphan Barrel Barterhouse'):
        return 'STRAIGHT BOURBON WHISKIES'
    elif (pd.isna(x)) and (y=='HA Orphan Barrel Forged Oak'):
        return 'STRAIGHT BOURBON WHISKIES'
    elif (pd.isna(x)) and (y=='Rothman & Winter Orchard Peach'):
        return 'MISC. IMPORTED CORDIALS & LIQUEURS'
    elif (pd.isna(x)) and (y=='HA Pikesville Rye 110prf'):
        return 'STRAIGHT RYE WHISKIES'
    elif (pd.isna(x)) and (y=='HA Johnnie Walker Private Collection 2014 Smoke'):
        return 'SCOTCH WHISKIES'
    elif (pd.isna(x)) and (y=='Jose Cuervo Especial Silver/Flask'):
        return 'DECANTERS & SPECIALTY PACKAGES'
    elif (pd.isna(x)) and (y=='Jose Cuervo Especial Gold /Flask'):
        return  'DECANTERS & SPECIALTY PACKAGES'
    elif (pd.isna(x)) and (y=="Aberlour A''bunadh"):
        return 'SINGLE MALT SCOTCH'
    elif (pd.isna(x)) and (y=='El Mayor Extra Anejo 100% Agave'):
        return 'TEQUILA'
    elif (pd.isna(x)) and (y=='Ezra Brooks Bourbon Cream Mini'):
        return 'Temporary & Specialty Packages'
    elif (pd.isna(x)) and (y=="Michter's US*1 SB Rye"):
        return 'STRAIGHT RYE WHISKIES'
    elif (pd.isna(x)) and (y=='Glen Moray Scotch Classic Port Cask w/2 Glasses'):
        return  'DECANTERS & SPECIALTY PACKAGES'
    elif (pd.isna(x)) and (y=='Zaya Gran Reserva Rum w/2 Rocks Glasses'):
        return   'DECANTERS & SPECIALTY PACKAGES'
    elif (pd.isna(x)) and (y=='Corralejo Silver w/2 Sangrita Glasses'):
        return  'DECANTERS & SPECIALTY PACKAGES'
    elif (pd.isna(x)) and (y=='Southern Comfort w/2 Rock Glasses'):
        return  'DECANTERS & SPECIALTY PACKAGES'
    elif (pd.isna(x)) and (y=='Crystal Head Vodka w/2 Skull Glasses'):
        return  'DECANTERS & SPECIALTY PACKAGES'
    elif (pd.isna(x)) and (y=='Hornitos Plata w/Glasses'):
        return  'DECANTERS & SPECIALTY PACKAGES'
    elif (pd.isna(x)) and (y=='Hornitos Reposado w/Glasses'):
        return   'DECANTERS & SPECIALTY PACKAGES'
    elif (pd.isna(x)) and (y=='Glen Moray Classic Chardonnay Cask Finish w/2 Glasses'):
        return  'DECANTERS & SPECIALTY PACKAGES'
    else:
        return x
    
def category(x,y):
    if (pd.isna(x)) and (y=='Evan Williams Egg Nog'):
        return '1081200.'
    elif (pd.isna(x)) and (y=="Carolan's Irish Cream w/2 Bowls"):
        return '1701100.'
    elif (pd.isna(x)) and (y=="Wild Turkey American Honey Shot Tap"):
        return '1701100.'
    elif (pd.isna(x)) and (y=="Chambord Liqueur w/2 Glasses"):
        return '1701100.'
    elif (pd.isna(x)) and (y=='Gentleman Jack w/2 Glasses'):
        return '1701100.'
    elif (pd.isna(x)) and (y=='Caravella Limoncello w/Glass'):
        return '1701100.'
    elif (pd.isna(x)) and (y=='Craigellachie'):
        return '1012200.'
    elif (pd.isna(x)) and (y=='Glenfiddich 1963 Replica HA'):
        return '1012210.'
    elif (pd.isna(x)) and (y=='Pinnacle Candy Cane Trial Pack'):
        return '1701200.'
    elif (pd.isna(x)) and (y=='Dry Fly Gin'):
        return '1041100.'
    elif (pd.isna(x)) and (y=="Galliano L'Autentico"):
        return '1082900.'
    elif (pd.isna(x)) and (y=='1800 Reposado'):
        return '1022200.'
    elif (pd.isna(x)) and (y=='Grand Marnier Cuvee 1880 HA'):
        return '1082100.'
    elif (pd.isna(x)) and (y=='Courvoisier Gold'):
        return '1082900.'
    elif (pd.isna(x)) and (y=='Ardbeg Auriverdes HA'):
        return '1012210.'
    elif (pd.isna(x)) and (y=="Galliano L'Autentico"):
            return '1082900.'
    elif (pd.isna(x)) and (y=='Spanish Single Malt 100ml'):
        return '1012210.'
    elif (pd.isna(x)) and (y=='Spanish Single Malt 1 Liter'):
        return  '1012210.'
    elif (pd.isna(x)) and (y=='Spanish Single Malt 375ml'):
        return  '1012210.'
    elif (pd.isna(x)) and (y=='Spanish Single Malt 50ml'):
        return  '1012210.'
    elif (pd.isna(x)) and (y=='Spanish Single Malt 750ml'):
        return  '1012210.'
    elif (pd.isna(x)) and (y=='Spanish Single Malt 200ml'):
        return  '1012210.'
    elif (pd.isna(x)) and (y=='Deep Eddy Lemon Vodka'):
        return '1031200.'
    elif (pd.isna(x)) and (y=='"Beefeater ""24"""'):
        return '1042100.'
    elif (pd.isna(x)) and (y=='Ansac VS  Cognac'):
        return '1052100.'
    elif (pd.isna(x)) and (y=='Aalborg Jubilaeums Aquavit'):
        return '1082100.'
    elif (pd.isna(x)) and (y=='Patron Silver 750 Box Tray Pack'):
        return  '1701100.'
    elif (pd.isna(x)) and (y=='Patron Citronge Mango'):
        return '1022200.'
    elif (pd.isna(x)) and (y=='Deanston Organic 14YR'):
        return '1012210.'
    elif (pd.isna(x)) and (y=='HA Orphan Barrel Barterhouse'):
        return '1011200.'
    elif (pd.isna(x)) and (y=='HA Orphan Barrel Forged Oak'):
        return '1011200.'
    elif (pd.isna(x)) and (y=='Rothman & Winter Orchard Peach'):
        return '1082900.'
    elif (pd.isna(x)) and (y=='HA Pikesville Rye 110prf'):
        return '1011500.'
    elif (pd.isna(x)) and (y=='HA Johnnie Walker Private Collection 2014 Smoke'):
        return '1012200.'
    elif (pd.isna(x)) and (y=='Jose Cuervo Especial Silver/Flask'):
        return '1701100.'
    elif (pd.isna(x)) and (y=='Jose Cuervo Especial Gold /Flask'):
        return '1701100.'
    elif (pd.isna(x)) and (y=="Aberlour A''bunadh"):
        return '1012210.'
    elif (pd.isna(x)) and (y=='El Mayor Extra Anejo 100% Agave'):
        return '1022100.'
    elif (pd.isna(x)) and (y=='Ezra Brooks Bourbon Cream Mini'):
        return '1701100.'
    elif (pd.isna(x)) and (y=="Michter's US*1 SB Rye"):
        return '1011500.'
    elif (pd.isna(x)) and (y=='Glen Moray Scotch Classic Port Cask w/2 Glasses'):
        return '1701100.'
    elif (pd.isna(x)) and (y=='Zaya Gran Reserva Rum w/2 Rocks Glasses'):
        return  '1701100.'
    elif (pd.isna(x)) and (y=='Corralejo Silver w/2 Sangrita Glasses'):
        return '1701100.'
    elif (pd.isna(x)) and (y=='Southern Comfort w/2 Rock Glasses'):
        return '1701100.'
    elif (pd.isna(x)) and (y=='Crystal Head Vodka w/2 Skull Glasses'):
        return '1701100.'
    elif (pd.isna(x)) and (y=='Hornitos Plata w/Glasses'):
        return '1701100.'
    elif (pd.isna(x)) and (y=='Hornitos Reposado w/Glasses'):
        return  '1701100.'
    elif (pd.isna(x)) and (y=='Glen Moray Classic Chardonnay Cask Finish w/2 Glasses'):
        return '1701100.'
    else:
        return x

# %% [markdown]
# # Applying all dictionaries and functions to each year

# %%
listof6 = (y12,y13,y14,y15,y16,y17)
for i in listof6:
    print(i.isna().sum())
# Out:
# Invoice/Item Number         0
# Date                        0
# Store Number                0
# Store Name                  0
# Address                     0
# City                        0
# Zip Code                    0
# Store Location              0
# County Number            3599
# County                   3599
# Category                  284
# Category Name             822
# Vendor Number               0
# Vendor Name                 0
# Item Number                 0
# Item Description            0
# Pack                        0
# Bottle Volume (ml)          0
# State Bottle Cost          10
# State Bottle Retail        10
# Bottles Sold                0
# Sale (Dollars)             10
# Volume Sold (Liters)        0
# Volume Sold (Gallons)       0
# Year                        0
# dtype: int64
# Invoice/Item Number         0
# Date                        0
# Store Number                0
# Store Name                  0
# Address                     0
# City                        0
# Zip Code                    0
# Store Location              0
# County Number            2660
# County                   2660
# Category                  298
# Category Name             810
# Vendor Number               0
# Vendor Name                 0
# Item Number                 0
# Item Description            0
# Pack                        0
# Bottle Volume (ml)          0
# State Bottle Cost           0
# State Bottle Retail         0
# Bottles Sold                0
# Sale (Dollars)              0
# Volume Sold (Liters)        0
# Volume Sold (Gallons)       0
# Year                        0
# dtype: int64
# Invoice/Item Number         0
# Date                        0
# Store Number                0
# Store Name                  0
# Address                     0
# City                        0
# Zip Code                    0
# Store Location              0
# County Number            1054
# County                   1054
# Category                  480
# Category Name            1057
# Vendor Number               0
# Vendor Name                 0
# Item Number                 0
# Item Description            0
# Pack                        0
# Bottle Volume (ml)          0
# State Bottle Cost           0
# State Bottle Retail         0
# Bottles Sold                0
# Sale (Dollars)              0
# Volume Sold (Liters)        0
# Volume Sold (Gallons)       0
# Year                        0
# dtype: int64
# Invoice/Item Number         0
# Date                        0
# Store Number                0
# Store Name                  0
# Address                     0
# City                        0
# Zip Code                    0
# Store Location              0
# County Number            1119
# County                   1119
# Category                  773
# Category Name            1462
# Vendor Number               0
# Vendor Name                 0
# Item Number                 0
# Item Description            0
# Pack                        0
# Bottle Volume (ml)          0
# State Bottle Cost           0
# State Bottle Retail         0
# Bottles Sold                0
# Sale (Dollars)              0
# Volume Sold (Liters)        0
# Volume Sold (Gallons)       0
# Year                        0
# dtype: int64
# Invoice/Item Number          0
# Date                         0
# Store Number                 0
# Store Name                   0
# Address                    965
# City                       965
# Zip Code                  1010
# Store Location             965
# County Number            69336
# County                   69336
# Category                   350
# Category Name             6100
# Vendor Number                2
# Vendor Name                  0
# Item Number                  0
# Item Description             0
# Pack                         0
# Bottle Volume (ml)           0
# State Bottle Cost            0
# State Bottle Retail          0
# Bottles Sold                 0
# Sale (Dollars)               0
# Volume Sold (Liters)         0
# Volume Sold (Gallons)        0
# Year                         0
# dtype: int64
# Invoice/Item Number         0
# Date                        0
# Store Number                0
# Store Name                  0
# Address                  1411
# City                     1410
# Zip Code                 1410
# Store Location           1410
# County Number            1410
# County                   1410
# Category                 5835
# Category Name            5835
# Vendor Number               1
# Vendor Name                 1
# Item Number                 0
# Item Description            0
# Pack                        0
# Bottle Volume (ml)          0
# State Bottle Cost           0
# State Bottle Retail         0
# Bottles Sold                0
# Sale (Dollars)              0
# Volume Sold (Liters)        0
# Volume Sold (Gallons)       0
# Year                        0
# dtype: int64

# %% [markdown]
# # ***

# %%
#Warning: ~ 1.5 hr. runtime
#This loops through all 6 parts with all maps to reduce nans in all categories
#However, below I more deliberately clean each part to be as accurate as possible
listof6 = (y12,y13,y14,y15,y16,y17)
counter = 12
for i in listof6:
    print(counter)
    i['Address']=list(map(get_address,i['Address'],i['Store Number']))
    i['Store Location']=list(map(get_store_location,i['Store Location'],i['Store Number']))
    i['Zip Code']=list(map(get_zip,i['Zip Code'],i['Store Number']))
    i['City']=list(map(get_city,i['City'],i['Store Number']))
    print(counter+0.25)
    i['County Number']=list(map(get_county_number,i['County Number'],i['Store Number']))
    i['County Number']=list(map(county_number,i['County Number'],i['City']))
    i['County']=list(map(get_county,i['County'],i['Store Number']))
    print(counter+0.5)
    i['County']=list(map(county,i['County'],i['City']))
    i['Category']=list(map(get_category,i['Category'],i['Item Description']))
    i['Category']=list(map(category,i['Category'],i['Item Description']))
    i['Category Name']=list(map(get_category_name,i['Category Name'],i['Item Description']))
    print(counter+0.75)
    i['Category Name']=list(map(category_name,i['Category Name'],i['Item Description']))
    i['Vendor Name']=list(map(get_vendor_name,i['Vendor Name'],i['Item Description']))
    i['Vendor Number']=list(map(get_vendor_number,i['Vendor Number'],i['Item Description']))
    counter+=1
# Out:
# 12
# C:\Users\Owner\AppData\Local\Temp/ipykernel_20532/1301407680.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i['Address']=list(map(get_address,i['Address'],i['Store Number']))
# C:\Users\Owner\AppData\Local\Temp/ipykernel_20532/1301407680.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i['Store Location']=list(map(get_store_location,i['Store Location'],i['Store Number']))
# C:\Users\Owner\AppData\Local\Temp/ipykernel_20532/1301407680.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i['Zip Code']=list(map(get_zip,i['Zip Code'],i['Store Number']))
# C:\Users\Owner\AppData\Local\Temp/ipykernel_20532/1301407680.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i['City']=list(map(get_city,i['City'],i['Store Number']))
# 12.25
# C:\Users\Owner\AppData\Local\Temp/ipykernel_20532/1301407680.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i['County Number']=list(map(get_county_number,i['County Number'],i['Store Number']))
# C:\Users\Owner\AppData\Local\Temp/ipykernel_20532/1301407680.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i['County Number']=list(map(county_number,i['County Number'],i['City']))
# C:\Users\Owner\AppData\Local\Temp/ipykernel_20532/1301407680.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i['County']=list(map(get_county,i['County'],i['Store Number']))
# 12.5
# C:\Users\Owner\AppData\Local\Temp/ipykernel_20532/1301407680.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i['County']=list(map(county,i['County'],i['City']))
# C:\Users\Owner\AppData\Local\Temp/ipykernel_20532/1301407680.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i['Category']=list(map(get_category,i['Category'],i['Item Description']))
# C:\Users\Owner\AppData\Local\Temp/ipykernel_20532/1301407680.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i['Category']=list(map(category,i['Category'],i['Item Description']))
# C:\Users\Owner\AppData\Local\Temp/ipykernel_20532/1301407680.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i['Category Name']=list(map(get_category_name,i['Category Name'],i['Item Description']))
# 12.75
# C:\Users\Owner\AppData\Local\Temp/ipykernel_20532/1301407680.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i['Category Name']=list(map(category_name,i['Category Name'],i['Item Description']))
# C:\Users\Owner\AppData\Local\Temp/ipykernel_20532/1301407680.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i['Vendor Name']=list(map(get_vendor_name,i['Vendor Name'],i['Item Description']))
# C:\Users\Owner\AppData\Local\Temp/ipykernel_20532/1301407680.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i['Vendor Number']=list(map(get_vendor_number,i['Vendor Number'],i['Item Description']))
# 13
# 13.25
# 13.5
# 13.75
# 14
# 14.25
# 14.5
# 14.75
# 15
# 15.25
# 15.5
# 15.75
# 16
# 16.25
# 16.5
# 16.75
# 17
# 17.25
# 17.5
# 17.75

# %% [markdown]
# # ***

# %%
#post loop pre further cleaning checks
y12.to_csv('postloopy12.csv')
y13.to_csv('postloopy13.csv')
y14.to_csv('postloopy14.csv')
y15.to_csv('postloopy15.csv')
y16.to_csv('postloopy16.csv')
y17.to_csv('postloopy17.csv')

# %% [markdown]
# # Dataset Cleaning by Year
# ### There are still hundreds of nans throughout the data that require more inspection, which is soon to come
# ### First, directly below are results from the inspection that were found best to be applied to all 6 datasets as a whole to make it easier to clean them individually after.

# %%
#Checkpoint: read in all postloop files
y12=pd.read_csv('C://Users//Owner//DA//Classwork//0 Activities//Final_Project//Final Cuts//Des_Moines_Liquor_Store//Jupyter Files//testrun//postloopy12.csv')
y13=pd.read_csv('C://Users//Owner//DA//Classwork//0 Activities//Final_Project//Final Cuts//Des_Moines_Liquor_Store//Jupyter Files//testrun//postloopy13.csv')
y14=pd.read_csv('C://Users//Owner//DA//Classwork//0 Activities//Final_Project//Final Cuts//Des_Moines_Liquor_Store//Jupyter Files//testrun//postloopy14.csv')
y15=pd.read_csv('C://Users//Owner//DA//Classwork//0 Activities//Final_Project//Final Cuts//Des_Moines_Liquor_Store//Jupyter Files//testrun//postloopy15.csv')
y16=pd.read_csv('C://Users//Owner//DA//Classwork//0 Activities//Final_Project//Final Cuts//Des_Moines_Liquor_Store//Jupyter Files//testrun//postloopy16.csv')
y17=pd.read_csv('C://Users//Owner//DA//Classwork//0 Activities//Final_Project//Final Cuts//Des_Moines_Liquor_Store//Jupyter Files//testrun//postloopy17.csv')
# Out:
# C:\Users\Owner\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (7) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
#needed for string columns only
def sametext(a):
    if (pd.isna(a)):
        return a
    else:
        return a.lower()

def vodka(a,b):
    if (pd.isna(a)) & (b == 1032100.0):
        return 'imported vodka'
    elif (a =='imported vodkas'):
        return 'imported vodka'
    else: 
        return a

def cnvodka17(a,b):
    if (pd.isna(a)) & (b == 1031200.):
        return 'vodka flavored'
    else: 
        return a
    
def cvodka17(a,b):
    if (pd.isna(a)) & (b == 'vodka flavored'):
        return 1031200.
    else: 
        return a
def cg_county(a,b):
    if (pd.isna(a))&(b=='mason city'):
        return 'cerro gordo'
    else:
        return a
    
def cg_county_number(a,b):
    if(pd.isna(a)) & (b=='mason city'):
        return 17.
    else:
        return a

# %%
listof6 = (y12,y13,y14,y15,y16,y17)
for i in listof6:
    print(i['Category Name'].nunique())
# Out:
# 77
# 78
# 78
# 83
# 125
# 85

# %%
listof6=(y12,y13,y14,y15,y16,y17)
objlist=('Category Name','City','County', 'Vendor Name','Item Description')
for i in listof6:
    for j in objlist:
        i[j]=list(map(sametext,i[j]))

# %%
listof6 = (y12,y13,y14,y15,y16,y17)
for i in listof6:
    print(
# 69                        Wilkie Liquors                724  1ST ST E
# 70               Quick Shop / Clear Lake                 904 N 8TH ST
# 71           Hy-Vee Food Store / Sheldon                 1989 PARK ST
# 72         Fareway Stores #841 / Red Oak                 811 BROADWAY
# 73              Hy-Vee / Windsor Heights          7101 UNIVERSITY AVE
# 74              Iowa Street Market, Inc.                 1256 IOWA ST
# 75               Wal-Mart 2889 / Clinton           2715 SOUTH 25TH ST
# 76      Hartig Drug Company #4 / Dubuque             2225 CENTRAL AVE
# 77         Hy-Vee Food Store #1 / Newton       1501 FIRST AVENUE EAST
# 78           Hy-Vee Food Store / Carroll       905 US HIGHWAY 30 WEST
# 79       Sam's Mainstreet Market / Solon                123 E MAIN ST
# 80        Main Street Spirits / Mapleton                  311 MAIN ST
# 81                        Great Pastimes                228 N MAIN ST
# 82                        John's Grocery           401 EAST MARKET ST
# 83    Target Store T-1771 / Cedar Rapids          3400 EDGEWOOD RD SW
# 84                 Vom Fass / Des Moines                 833, 42ND ST
# 85                   Mmdg Spirits / Ames               126A WELCH AVE
# 86        CVS Pharmacy #8659 / Davenport             1777 DIVISION ST
# 87           Nash Finch / Wholesale Food                807 GRANDVIEW
# 88             Liquor And Tobacco Outlet          515 1/2 BROADWAY ST
# 89              Wine and Spirits Gallery              7690 HICKMAN RD
# 90          Hy-Vee #3 / BDI / Des Moines              3221 SE 14TH ST
# 91             Wal-Mart 2935 / Knoxville               814 W BELL AVE
# 92  Casey's General Store #40 / Scranton                900 LOCUST ST
# 93            Hy-Vee Wine and Spirits #2           3301 W KIMBERLY RD
# 94  Smokin' Joe's #10 Tobacco and Liquor                  480 7TH AVE
# 95               Wal-Mart 2764 / Altoona              3501  8TH ST SW
# 96       CVS Pharmacy #8633 / Bettendorf         2002 SPRUCE HILLS DR
# 97                Sam's Club 6568 / Ames               305 AIRPORT RD
# 98               Wal-Mart 2004 / Dubuque                4200 DODGE ST
# 99      Tobacco Hut #14 / Council Bluffs              1925 W BROADWAY
#
#                City Zip Code  \
# 0    GUTHRIE CENTER    50115
# 1           ANAMOSA    52205
# 2              AMES    50010
# 3       SPIRIT LAKE    51360
# 4           RED OAK    51566
# 5      CEDAR RAPIDS    52405
# 6         DAVENPORT    52807
# 7           DECORAH    52101
# 8            GRIMES    50111
# 9            NEVADA    50201
# 10          DUBUQUE    52001
# 11       DES MOINES    50317
# 12     CEDAR RAPIDS    52404
# 13          ANAMOSA    52205
# 14   COUNCIL BLUFFS    51501
# 15             PALO    52324
# 16          MILFORD    51351
# 17     CEDAR RAPIDS    52405
# 18    NORTH LIBERTY    52317
# 19          TRIPOLI    50676
# 20     MARSHALLTOWN    50158
# 21        MT VERNON    52314
# 22     CEDAR RAPIDS    52405
# 23          DUBUQUE    52002
# 24        MT VERNON    52314
# 25             AMES    50010
# 26         BELLEVUE    52031
# 27       BURLINGTON    52601
# 28   COUNCIL BLUFFS    51501
# 29     CHARLES CITY    50616
# 30          MARENGO    52301
# 31       DES MOINES    50320
# 32       MONTICELLO    52310
# 33        KNOXVILLE    50138
# 34        IOWA CITY    52240
# 35        DAVENPORT    52807
# 36       DES MOINES    50310
# 37          LE MARS    51031
# 38  WEST DES MOINES    50266
# 39       SIOUX CITY    51105
# 40           MONONA    52159
# 41        IOWA CITY    52245
# 42     CEDAR RAPIDS    52405
# 43         HUMBOLDT    50548
# 44          NORWALK    50211
# 45      CEDAR FALLS    50613
# 46           SUMNER    50674
# 47          DUBUQUE    52001
# 48     CEDAR RAPIDS    52402
# 49        MUSCATINE    52761
# 50     CEDAR RAPIDS    52402
# 51           GOWRIE    50543
# 52       SIOUX CITY    51104
# 53        URBANDALE    50322
# 54     CEDAR RAPIDS    52411
# 55       DES MOINES    50310
# 56           ANKENY    50023
# 57     WEST LIBERTY    52776
# 58           ANKENY    50021
# 59     INDEPENDENCE    50644
# 60     CEDAR RAPIDS    52403
# 61    NORTH ENGLISH    52316
# 62      CEDAR FALLS    50613
# 63        IOWA CITY    52240
# 64         WATERLOO    50703
# 65       STORM LAKE    50588
# 66  WEST DES MOINES    50265
# 67        IOWA CITY    52240
# 68           KEOKUK    52632
# 69        MT VERNON    52314
# 70       CLEAR LAKE    50428
# 71          SHELDON    51201
# 72          RED OAK    51566
# 73  WINDSOR HEIGHTS    50311
# 74          DUBUQUE    52001
# 75          CLINTON    52732
# 76          DUBUQUE    52001
# 77           NEWTON    50208
# 78          CARROLL    51401
# 79            SOLON    52333
# 80         MAPLETON    51034
# 81       MONTICELLO    52310
# 82        IOWA CITY    52240
# 83     CEDAR RAPIDS    52404
# 84       DES MOINES    50312
# 85             AMES    50014
# 86        DAVENPORT    52804
# 87        MUSCATINE    52761
# 88         WATERLOO    50703
# 89  WINDSOR HEIGHTS    50322
# 90       DES MOINES    50320
# 91        KNOXVILLE    50138
# 92         SCRANTON    51462
# 93        DAVENPORT    52804
# 94           MARION    52302
# 95          ALTOONA    50009
# 96       BETTENDORF    52722
# 97             AMES    50010
# 98          DUBUQUE    52003
# 99   COUNCIL BLUFFS    51501
#
#                                        Store Location  County Number  \
# 0         200 STATE PO BOX 98\nGUTHRIE CENTER 50115\n           39.0
# 1   402 EAST MAIN\nANAMOSA 52205\n(42.108289, -91....           53.0
# 2   2515 CHAMBERLAIN\nAMES 50010\n(42.02146, -93.6...           85.0
# 3                 HWY 9 &amp; 71\nSPIRIT LAKE 51360\n           30.0
# 4   200 E OAK ST\nRED OAK 51566\n(41.016691, -95.2...           69.0
# 5   225 EDGEWOOD RD\nCEDAR RAPIDS 52405\n(41.97341...           57.0
# 6   5225 ELMORE AVE\nDAVENPORT 52807\n(41.573626, ...           82.0
# 7   915 SHORT ST\nDECORAH 52101\n(43.291013, -91.7...           96.0
# 8   109 EAST 1ST ST STE B\nGRIMES 50111\n(41.6884,...           77.0
# 9   1505 SOUTH B AVE\nNEVADA 50201\n(42.009797, -9...           85.0
# 10  1800 ELM ST\nDUBUQUE 52001\n(42.511105, -90.66...           31.0
# 11  2540 E EUCLID\nDES MOINES 50317\n(41.627842, -...           77.0
# 12  20 MILLER AVE SW\nCEDAR RAPIDS 52404\n(41.9245...           57.0
# 88  515 1/2 BROADWAY ST\nWATERLOO 50703\n(42.51041...            7.0
# 89  7690 HICKMAN RD\nWINDSOR HEIGHTS 50322\n(41.61...           77.0
# 90  3221 SE 14TH ST\nDES MOINES 50320\n(41.554101,...           77.0
# 91                  814 W BELL AVE\nKNOXVILLE 50138\n           63.0
# 92  900 LOCUST ST\nSCRANTON 51462\n(42.022413, -94...           37.0
# 93              3301 W KIMBERLY RD\nDAVENPORT 52804\n           82.0
# 94  480 7TH AVE\nMARION 52302\n(42.033308, -91.60546)           57.0
# 95  3501 8TH ST SW\nALTOONA 50009\n(41.644195, -93...           77.0
# 96  2002 SPRUCE HILLS DR\nBETTENDORF 52722\n(41.55...           82.0
# 97  305 AIRPORT RD\nAMES 50010\n(42.001123, -93.61...           85.0
# 98  4200 DODGE ST\nDUBUQUE 52003\n(42.489025, -90....           31.0
# 99  1925 W BROADWAY\nCOUNCIL BLUFFS 51501\n(41.261...           78.0
#
#            County   Category                               Category Name  \
# 0         Guthrie  1062300.0                            cruzan mango rum
# 1           Jones  1081300.0                   arrow peppermint schnapps
# 2           Story  1081900.0                               kinky liqueur
# 3       Dickinson  1062200.0                    bacardi superior rum pet
# 4      Montgomery  1031200.0                   uv blue (raspberry) vodka
# 5            Linn  1012100.0                                 crown royal
# 6           Scott  1042100.0                               tanqueray gin
# 7      Winneshiek  1701100.0                  hiram walker pumpkin spice
# 8            Polk  1011100.0                    calvert extra bl whiskey
# 9           Story  1041100.0                               paramount gin
# 10        Dubuque  1062310.0              captain morgan original spiced
# 11           Polk  1082900.0                        jagermeister liqueur
# 12           Linn  1032200.0                            absolut ruby red
# 13          Jones  1011200.0                                    jim beam
# 14  Pottawattamie  1032080.0           absolut swedish vodka 80 prf mini
# 15           Linn  1062310.0              captain morgan original spiced
# 16      Dickinson  1011200.0                                    ten high
# 17           Linn  1071100.0               chi-chi's margarita w/tequila
# 18        Johnson  1031080.0                                  skol vodka
# 19         Bremer  1062200.0                        bacardi superior rum
# 20       Marshall  1031100.0                   hawkeye vodka 80 prf mini
# 21           Linn  1011300.0               jack daniels old #7 black lbl
# 22           Linn  1011100.0                               five star pet
# 23        Dubuque  1052010.0                     remy martin vsop cognac
# 24           Linn  1012100.0                 crown royal canadian whisky
# 25          Story  1032080.0                            grey goose vodka
# 26        Jackson  1081600.0                            southern comfort
# 27     Des Moines  1031080.0                               hawkeye vodka
# 28  Pottawattamie  1041100.0                                 hawkeye gin
# 29          Floyd  1012100.0                                black velvet
# 30           Iowa  1041100.0                      paramount gin traveler
# 31           Polk  1012200.0                           j & b rare scotch
# 32          Jones  1012100.0                                black velvet
# 33         Marion  1101100.0                           everclear alcohol
# 34        Johnson  1031080.0                          five o'clock vodka
# 35          Scott  1081200.0  st. brendan's superior irish cream liqueur
# 36           Polk  1062200.0                            bacardi gold rum
# 37       Plymouth  1032080.0                absolut swedish vodka 80 prf
# 38           Polk  1031200.0              pucker vodka wild cherry tease
# 39       Woodbury  1062200.0                           don q cristal rum
# 40        Clayton  1012200.0             johnnie walker red label scotch
# 69          410.0        The Patron Spirits Company        88296
# 70          421.0                 Sazerac Co., Inc.        16518
# 71          260.0                   Diageo Americas        11366
# 72          115.0  Constellation Wine Company, Inc.        11586
# 73          380.0         Phillips Beverage Company        37356
# 74          115.0  Constellation Wine Company, Inc.        34821
# 75          322.0   Prestige Wine and Spirits Group        75210
# 76          259.0                Heaven Hill Brands        43028
# 77          434.0                    Luxco-St Louis        80571
# 78          260.0                   Diageo Americas        41592
# 79          260.0                   Diageo Americas        89175
# 80           85.0          Brown-Forman Corporation        26826
# 81          395.0                           Proximo        89196
# 82           65.0                   Jim Beam Brands        89836
# 83           55.0             Sazerac North America        12408
# 84          885.0        Yahara Bay Distillers, Inc       901167
# 85          260.0                   Diageo Americas        64755
# 86          115.0  Constellation Wine Company, Inc.        34820
# 87           85.0          Brown-Forman Corporation        12478
# 88          395.0                           Proximo        89193
# 89          420.0           Moet Hennessy USA, Inc.        48154
# 90           55.0             Sazerac North America        86390
# 91          421.0                 Sazerac Co., Inc.        83906
# 92          370.0  Pernod Ricard USA/Austin Nichols        34006
# 93          370.0  Pernod Ricard USA/Austin Nichols        33966
# 94          297.0                 Laird And Company        35918
# 95          259.0                Heaven Hill Brands        43028
# 96          434.0                    Luxco-St Louis        45278
# 97          421.0                 Sazerac Co., Inc.        16518
# 98          434.0                    Luxco-St Louis        24158
# 99          300.0      Mccormick Distilling Company        36886
#
#                               Item Description  Pack  Bottle Volume (ml)  \
# 0                             Cruzan Mango Rum    12                 750
# 1                    Arrow Peppermint Schnapps     6                1750
# 2                                Kinky Liqueur     6                 750
# 3                     Bacardi Superior Rum Pet    12                 750
# 4                    Uv Blue (raspberry) Vodka    12                 750
# 5                                  Crown Royal    12                 750
# 6                                Tanqueray Gin    12                 750
# 7                   Hiram Walker Pumpkin Spice    12                 750
# 8                     Calvert Extra Bl Whiskey     6                1750
# 9                                Paramount Gin     6                1750
# 10              Captain Morgan Original Spiced    12                 750
# 11                        Jagermeister Liqueur    12                 750
# 12                            Absolut Ruby Red    12                 750
# 13                                    Jim Beam     6                1750
# 14           Absolut Swedish Vodka 80 Prf Mini    10                 600
# 15              Captain Morgan Original Spiced    12                 750
# 16                                    Ten High    12                 750
# 17               Chi-Chi's Margarita W/tequila     6                1750
# 18                                  Skol Vodka    24                 375
# 19                        Bacardi Superior Rum    12                 750
# 20                   Hawkeye Vodka 80 Prf Mini    12                 500
# 21               Jack Daniels Old #7 Black Lbl    12                1000
# 22                               Five Star Pet    12                 750
# 23                     Remy Martin Vsop Cognac    12                 750
# 24                 Crown Royal Canadian Whisky    12                1000
# 25                            Grey Goose Vodka    12                 750
# 26                            Southern Comfort    12                1000
# 27                               Hawkeye Vodka    12                 750
# 28                                 Hawkeye Gin     6                1750
# 29                                Black Velvet    24                 375
# 30                      Paramount Gin Traveler    12                 750
# 31                           J & B Rare Scotch    12                1000
# 32                                Black Velvet    48                 200
# 33                           Everclear Alcohol    12                 750
# 34                          Five O'clock Vodka    12                1000
# 35  St. Brendan's Superior Irish Cream Liqueur    12                 750
Bottle Cost State Bottle Retail  Bottles Sold Sale (Dollars)  \
# 0              $6.82              $10.24             3         $30.72
# 1              $7.04              $10.56             3         $31.68
# 2             $10.00              $15.00            12        $180.00
# 3              $7.53              $11.30            12        $135.60
# 4              $6.25               $9.49            12        $113.88
# 5             $14.50              $21.74             1         $21.74
# 6             $12.00              $17.99            12        $215.88
# 7              $4.00               $5.99            12         $71.88
# 8             $11.02              $16.53             1         $16.53
# 9              $7.10              $10.65             2         $21.30
# 10             $8.50              $12.74            12        $152.88
# 11            $11.58              $17.37            12        $208.44
# 12            $10.89              $16.33             4         $65.32
# 13            $17.37              $26.55             6        $159.30
# 14             $7.92              $11.88             1         $11.88
# 15             $8.50              $12.74            12        $152.88
# 16             $4.00               $5.99            12         $71.88
# 17             $6.49               $9.74            12        $116.88
# 18             $1.74               $2.60             2          $5.20
# 19             $7.53              $11.30             2         $22.60
# 20             $3.73               $5.59             3         $16.77
# 21            $16.92              $25.37            24        $608.88
# 22             $3.46               $5.19            12         $62.28
# 23            $20.83              $31.25             2         $62.50
# 24            $17.76              $26.65            36        $959.40
# 25            $17.97              $26.96            12        $323.52
# 26            $11.82              $17.74            12        $212.88
# 27             $3.25               $4.88            12         $58.56
# 28             $7.00              $10.50             6         $63.00
# 29             $3.07               $4.60            24        $110.40
# 30             $3.39               $5.09             2         $10.18
# 31            $14.98              $22.47            12        $269.64
# 32             $1.56               $2.34            12         $28.08
# 33             $8.25              $12.38             6         $74.28
# 34             $4.01               $6.01            24        $144.24
# 35             $7.69              $11.53             2         $23.06
# 36            $14.67              $22.00             6        $132.00
# 37            $14.89              $22.34            12        $268.08
# 38             $9.99              $14.99             3         $44.97
# 39             $6.50               $9.74             1          $9.74
# 40            $16.99              $25.49             1         $25.49
# 41             $7.47              $11.20             1         $11.20
# 42            $12.50              $18.75            12        $225.00
# 43             $0.00               $0.00            12          $0.00
# 44            $14.25              $21.37             6        $128.22
# 45            $10.99              $16.49            12        $197.88
# 46             $4.50               $6.74             3         $20.22
# 47            $10.16              $15.74             3         $47.22
# 48            $18.08              $27.13             6        $162.78
# 49            $12.49              $18.74             2         $37.48
# 50             $6.01               $9.52            60        $571.20
# 51             $7.58              $11.37             6         $68.22
# 52             $7.67              $11.50             3         $34.50
# 53             $8.40              $12.59             4         $50.36
# 54            $14.98              $22.47             6        $134.82
# 55            $12.00              $17.99            12        $215.88
# 56             $5.69               $8.54             3         $25.62
# 57             $3.37               $5.05             2         $10.10
# 58            $14.67              $22.00             6        $132.00
# 59             $7.35              $11.02             1         $11.02
# 60             $4.67               $7.00             6         $42.00
# 61             $7.46              $11.19             6         $67.14
# 62             $7.31              $10.97             6         $65.82
# 63             $4.55               $6.82            12         $81.84
# 64             $7.50              $11.24             4         $44.96
# 65            $14.25              $21.37             2         $42.74
# 66             $8.49              $12.74             6         $76.44
# 67            $10.06              $15.09             6         $90.54
# 68            $20.00              $29.99             6        $179.94
# 69            $26.08              $39.13            12        $469.56
# 70            $11.80              $17.70             1         $17.70
# 71            $24.30              $36.44             3        $109.32
# 72             $6.75              $10.12             3         $30.36
# 73             $3.48               $5.23            12         $62.76
# 74            $13.89              $20.84             2         $41.68
# 75            $10.00              $15.00            12        $180.00
# 76            $11.55              $17.32             6        $103.92
# 77             $4.54               $6.81             1          $6.81
# 78             $7.96              $11.94            12        $143.28
# 79            $31.50              $47.24             6        $283.44
# 80            $13.01              $19.51             3         $58.53
# 81            $10.49              $15.73             3         $47.19
# 82            $13.11              $19.67             2         $39.34
# 83             $7.79              $12.29             6         $73.74
# 84            $19.87              $29.81             3         $89.43
# 85            $18.50              $27.74             1         $27.74
# 86             $7.97              $11.95            12        $143.40
# 87            $10.50              $15.75             6         $94.50
# 88             $3.00               $4.49            48        $215.52
# 89            $11.49              $17.24             1         $17.24
# 90             $2.13               $3.19            12         $38.28
# 91             $3.67               $5.50             6         $33.00
# 92            $10.89              $16.33             6         $97.98
# 93            $11.00              $16.49             3         $49.47
# 94             $6.92              $10.38             2         $20.76
# 95            $11.55              $17.32            24        $415.68
# 96             $7.58              $11.37             6         $68.22
# 97            $11.24              $16.87            12        $202.44
# 98             $7.38              $11.07            12        $132.84
# 99             $3.30               $4.96             5         $24.80
#
#     Volume Sold (Liters)  Volume Sold (Gallons)  Year
# 0                   2.25                   0.59    12
# 1                   5.25                   1.39    12
# 2                   9.00                   2.38    12
# 3                   9.00                   2.38    12
# 4                   9.00                   2.38    12
# 5                   0.75                   0.20    12
# 6                   9.00                   2.38    12
# 7                   9.00                   2.38    12
# 8                   1.75                   0.46    12
# 9                   3.50                   0.92    12
# 10                  9.00                   2.38    12
# 11                  9.00                   2.38    12
# 12                  3.00                   0.79    12
# 13                 10.50                   2.77    12
# 14                  0.60                   0.16    12
# 15                  9.00                   2.38    12
# 16                  9.00                   2.38    12
# 17                 21.00                   5.55    12
# 18                  0.75                   0.20    12
# 19                  1.50                   0.40    12
# 20                  1.50                   0.40    12
# 21                 24.00                   6.34    12
# 22                  9.00                   2.38    12
# 23                  1.50                   0.40    12
# 24                 36.00                   9.51    12
# 25                  9.00                   2.38    12
# 26                 12.00                   3.17    12
# 27                  9.00                   2.38    12
# 28                 10.50                   2.77    12
# 29                  9.00                   2.38    12
# 30                  1.50                   0.40    12
# 31                 12.00                   3.17    12
# 32                  2.40                   0.63    12
# 33                  4.50                   1.19    12
# 34                 24.00                   6.34    12
# 35                  1.50                   0.40    12
# 36                 10.50                   2.77    12
# 37                 12.00                   3.17    12
# 38                  2.25                   0.59    12
# 39                  0.75                   0.20    12
# 40                  1.00                   0.26    12
# 41                  0.50                   0.13    12
# 42                  9.00                   2.38    12
# 43                  9.00                   2.38    12
# 44                  4.50                   1.19    12
# 45                 12.00                   3.17    12
# 46                  2.25                   0.59    12
# 47                  2.25                   0.59    12
# 48                  4.50                   1.19    12
# 49                  1.50                   0.40    12
# 50                 45.00                  11.89    12
# 51                 10.50                   2.77    12
# 52                  2.25                   0.59    12
# 53                  3.00                   0.79    12
# 54                  4.50                   1.19    12
# 55                  9.00                   2.38    12
# 56                  2.25                   0.59    12
# 57                  1.50                   0.40    12
# 58                 10.50                   2.77    12
# 59                  1.00                   0.26    12
# 60                  3.00                   0.79    12
# 61                 10.50                   2.77    12
# 62                 10.50                   2.77    12
# 63                  9.00                   2.38    12
# 64                  3.00                   0.79    12
# 65                  1.50                   0.40    12
# 66                 10.50                   2.77    12
# 67                 10.50                   2.77    12
# 68                 10.50                   2.77    12
# 69                  9.00                   2.38    12
# 70                  1.75                   0.46    12
# 71                  2.25                   0.59    12
# 72                  2.25                   0.59    12
# 73                  9.00                   2.38    12
# 74                  3.50                   0.92    12
# 75                  9.00                   2.38    12
# 76                 10.50                   2.77    12
# 77                  0.50                   0.13    12
# 78                  9.00                   2.38    12
# 79                  4.50                   1.19    12
# 80                  2.25                   0.59    12
# 81                  2.25                   0.59    12
# 82                  1.50                   0.40    12
# 83                 10.50                   2.77    12
# 84                  2.25                   0.59    12
# 85                  0.75                   0.20    12
# 86                  9.00                   2.38    12
# 87                 10.50                   2.77    12
# 88                  9.60                   2.54    12
# 89                  0.38                   0.10    12
# 90                 12.00                   3.17    12
# 91                  4.50                   1.19    12
# 92                  4.50                   1.19    12
# 93                  2.25                   0.59    12
# 94                  3.50                   0.92    12
# 95                 42.00                  11.10    12
# 96                 10.50                   2.77    12
# 97                 21.00                   5.55    12
# 98                 21.00                   5.55    12
# 99                  3.75                   0.99    12

# %%
listof6=(y12,y13,y14,y15,y16,y17)
for i in listof6:
    i['Category Name']=list(map(vodka,i['Category Name'],i['Category']))
    i['Category']=list(map(cvodka17,i['Category'],i['Category Name']))
    i['Category Name']=list(map(cnvodka17,i['Category Name'],i['Category']))
    i['County']=list(map(cg_county,i['County'],i['City']))
    i['County Number']=list(map(cg_county_number,i['County Number'],i['City']))

# %%
listof6 = (y12,y13,y14,y15,y16,y17)
for i in listof6:
    print(i.isna().sum())
# Out:
# Unnamed: 0                0
# Invoice/Item Number       0
# Date                      0
# Store Number              0
# Store Name                0
# Address                   0
# City                      0
# Zip Code                  0
# Store Location            0
# County Number             0
# County                    0
# Category                  0
# Category Name             0
# Vendor Number             0
# Vendor Name               0
# Item Number               0
# Item Description          0
# Pack                      0
# Bottle Volume (ml)        0
# State Bottle Cost        10
# State Bottle Retail      10
# Bottles Sold              0
# Sale (Dollars)           10
# Volume Sold (Liters)      0
# Volume Sold (Gallons)     0
# Year                      0
# dtype: int64
# Unnamed: 0               0
# Invoice/Item Number      0
# Date                     0
# Store Number             0
# Store Name               0
# Address                  0
# City                     0
# Zip Code                 0
# Store Location           0
# County Number            0
# County                   0
# Category                 0
# Category Name            0
# Vendor Number            0
# Vendor Name              0
# Item Number              0
# Item Description         0
# Pack                     0
# Bottle Volume (ml)       0
# State Bottle Cost        0
# State Bottle Retail      0
# Bottles Sold             0
# Sale (Dollars)           0
# Volume Sold (Liters)     0
# Volume Sold (Gallons)    0
# Year                     0
# dtype: int64
# Unnamed: 0               0
# Invoice/Item Number      0
# Date                     0
# Store Number             0
# Store Name               0
# Address                  0
# City                     0
# Zip Code                 0
# Store Location           0
# County Number            0
# County                   0
# Category                 0
# Category Name            0
# Vendor Number            0
# Vendor Name              0
# Item Number              0
# Item Description         0
# Pack                     0
# Bottle Volume (ml)       0
# State Bottle Cost        0
# State Bottle Retail      0
# Bottles Sold             0
# Sale (Dollars)           0
# Volume Sold (Liters)     0
# Volume Sold (Gallons)    0
# Year                     0
# dtype: int64
# Unnamed: 0                 0
# Invoice/Item Number        0
# Date                       0
# Store Number               0
# Store Name                 0
# Address                    0
# City                       0
# Zip Code                   0
# Store Location             0
# County Number              0
# County                     0
# Category                 174
# Category Name              0
# Vendor Number              0
# Vendor Name                0
# Item Number                0
# Item Description           0
# Pack                       0
# Bottle Volume (ml)         0
# State Bottle Cost          0
# State Bottle Retail        0
# Bottles Sold               0
# Sale (Dollars)             0
# Volume Sold (Liters)       0
# Volume Sold (Gallons)      0
# Year                       0
# dtype: int64
# Unnamed: 0                 0
# Invoice/Item Number        0
# Date                       0
# Store Number               0
# Store Name                 0
# Address                    0
# City                       0
# Zip Code                   0
# Store Location             0
# County Number            797
# County                   797
# Category                   5
# Category Name              0
# Vendor Number              2
# Vendor Name                0
# Item Number                0
# Item Description           0
# Pack                       0
# Bottle Volume (ml)         0
# State Bottle Cost          0
# State Bottle Retail        0
# Bottles Sold               0
# Sale (Dollars)             0
# Volume Sold (Liters)       0
# Volume Sold (Gallons)      0
# Year                       0
# dtype: int64
# Unnamed: 0                 0
# Invoice/Item Number        0
# Date                       0
# Store Number               0
# Store Name                 0
# Address                    1
# City                       0
# Zip Code                   0
# Store Location             0
# County Number              0
# County                     0
# Category                 128
# Category Name              0
# Vendor Number              0
# Vendor Name                0
# Item Number                0
# Item Description           0
# Pack                       0
# Bottle Volume (ml)         0
# State Bottle Cost          0
# State Bottle Retail        0
# Bottles Sold               0
# Sale (Dollars)             0
# Volume Sold (Liters)       0
# Volume Sold (Gallons)      0
# Year                       0
# dtype: int64

# %%
#y15,y16, and y17 condensed categories due to .upper() function
listof6 = (y12,y13,y14,y15,y16,y17)
for i in listof6:
    print(i[i['Category Name']=='nan']['Category Name'].sum())
# Out:
# 0
# 0
# 0
# 0
# 0
# 0

# %%
np.set_printoptions(threshold=sys.maxsize)

# %%
print(y16['Category Name'].unique())
# Out:
# ['Sheep Dip' 'Laphroaig w/ Whiskey Stones' 'Forbidden Secret Coffee Pack'
#  'Disaronno Amaretto Cavalli Mignon 3-50ml Pack' 'Rumchata "GoChatas"'
#  'Absolut with Ginger Beer' 'Itty Bitty Juggs Sample Pack'
#  'Kinky Vodka Martini Pack' 'Skyy Bundle Up' 'Blackheart Playboy Edition'
#  'Cointreau w/ Lime Squeezer' 'Basil Hayden w/ Shaker'
#  'Knob Creek w/Glasses' "Maker's Mark Co-Pack" 'Glenmorangie Pioneer Pack'
#  'Jack Daniels Tennessee Honey w/Glass' 'Gentleman Jack w/2 Glasses'
#  'Southern Comfort w/Shot Glass & Lanyard'
#  'Admiral Nelson Black Patch Mini Counter Unit'
#  'Absolut Electrik w/2 Glasses' 'Midnight Moon Apple Pie w/Drinking Jar'
#  'Jameson w/Shot Glass' 'Glenlivet Nadurra Oloroso'
#  'Absolut Ruby Red w/ Grapefruit Juice' 'Canadian Club w/Glass'
#  'Cedar Ridge Whiskey 3 Btl Gift Pack' 'Chopin Vodka W/Shot Glasses'
#  'Hennessy VS Gold Box' 'Captain Morgan Spiced Barrel' 'J & B Rare Scotch'
#  'Malibu w/Dole Pineapple Juice' 'Hennessy VS 750ml + VSOP 50ml Chain VAP'
#  'Amaretto Di Amore w/2 Snifters' 'Courvoisier VS w/2 Glasses'
#  'Merrys White Chocolate Liqueur w/2 Glasses'
#  'Merrys Irish Cream Liqueur w/2 Glasses' 'Herradura Silver'
#  'Herradura Anejo' 'Herradura Gold Reposado 6pak'
#  'Jagermeister w/Shot Glasses' 'Caravella Limoncello w/Glass'
#  'Aberlour 12 Year Single Malt Scotch' 'Ardbeg Corryvreckan'
#  'Ardbeg 10 Yr Islay Single Malt Scotch' 'Ardbeg Uigeadail'
#  'Pinnacle w/3-50mls' 'Pearl Mini Party Pack' 'Auchentoshan American Oak'
#  'Auchentoshan Three Wood' 'Balvenie 12yr Doublewood Single Malt Scotch'
#  'Balvenie Caribbean Cask 14yr' 'Balvenie 17YR Doublewood'
#  'Balvenie 15yr Sherry Cask' 'Balvenie 21YR' 'Johnnie Walker Red'
#  'Buchanan Special Reserve 18YR' "Buchanan's 12 Yr Deluxe Scotch"
#  'Bowmore 12 Yr Single Malt Scotch' 'Cutty Sark Scotch'
#  'Chivas Regal 12 Yr' 'Dalwhinnie 15 Yr Single Malt Scotch'
#  "Dewar's White Label Scratched Cask" 'Dewars White Label Scotch'
#  'Dewars 12yr' 'Famous Grouse Scotch' 'Glen Moray'
#  'Glendronach 12YR Original' 'Glenfiddich 12yr Special Reserve'
#  'Glenfiddich 15 Yr Solera Reserva' 'Glenlivet 12 Yr Malt Scotch'
#  'Glenlivet 18yr' 'Glenlivet 15 Year French Oak' 'Glenlivet 16yr Nadurra'
#  'Glenmorangie Lasanta' "Glenmorangie Nectar D'or"
#  'Glenmorangie Quinta Ruban' "Grant's Blended Scotch"
#  'Glenmorangie 10 Yr Single Malt Scotch' 'Glenfiddich 18yr'
#  'Glenfiddich 14YR' 'Haig Club' 'Highland Park 12yr Single Malt Scotch'
#  'Johnnie Walker Select Cask' 'Johnnie Walker Double Black'
#  'Johnnie Walker Platinum' 'Johnnie Walker Black' 'Johnnie Walker Blue'
#  'Johnnie Walker Red Label Scotch' 'Johnnie Walker Green'
#  'Lagavulin 16yr Single Malt Scotch' "Lauder's"
#  'Laphroaig 10 Yr Single Malt Scotch' 'Macallan 12 Yr Single Malt Scotch'
#  'Macallan Fine Oak 10 Year' 'Macallan 18yr Single Malt Scotch'
#  'Mcclelland Highland' 'Monkey Shoulder' 'Oban Single Malt Scotch'
#  'Oban Little Bay' 'Talisker Storm' 'Talisker 10YR' 'Tomatin Single Malt'
#  'Clan Macgregor Scotch' 'House Of Stuart' "Lauder's Scotch Traveler"
#  "Lauder's Scotch" 'Old Smuggler Scotch Pet' 'Passport Scotch'
#  'Scoresby Rare Scotch' "Usher's Green Stripe"
#  'Black Velvet Toasted Caramel' 'Black Velvet Toasted Caramel Mini'
#  'Black Velvet Cinnamon Rush Mini' 'Black Velvet Cinnamon Rush'
#  'Canadian Club Whisky' 'Canadian Club Whisky Pet'
#  'Canadian Club Reserve Triple Aged' 'Crown Royal Regal Apple Mini'
#  'Crown Royal Regal Apple' 'Crown Royal 75th Anniversary'
#  'Crown Royal Maple' 'Crown Royal XO' 'Crown Royal Northern Harvest Rye'
#  'Crown Royal Black' 'Canadian Club Small Batch Classic'
#  'Forty Creek Cooper Pot' 'Forty Creek'
#  'Penthouse Spirits Canadian Whiskey' 'Crown Royal Xr Canadian Whiskey'
#  'Crown Royal' 'Crown Royal Canadian Whisky Mini'
#  'Crown Royal Canadian Whisky' 'Seagrams V.o. Bl Canadian Whisky'
#  'Canadian Ltd Whisky' 'Windsor Canadian'
#  'Seagrams V.o. Bl Canadian Whisky Pet' 'Crown Royal Special Reserve'
#  "Serpent's Bite Apple Cider Flavored Whisky Mini"
#  "Serpent's Bite Apple Cider Flavored Whisky" 'Black Velvet Reserve'
#  'Windsor Canadian Pet' 'Black Velvet Mini' 'Black Velvet' 'Jameson'
#  'Bushmills Irish Whiskey' 'Jim Beam' "Maker's Mark" 'Old Crow' 'Ten High'
#  "Beam's 8 Star Bl Whiskey" 'Five Star Pet' 'Black Velvet Traveler'
#  'Five Star' 'Canadian Ltd Whisky Convenience Pack' 'Canadian Hunter Rye'
#  'Canadian Hunter Traveler Camo' 'Canadian LTD' 'Canadian Mist Whisky'
#  'Canadian Mist Whiskey Pet' 'Canadian Mist' 'Canadian Woods Canadian Why'
#  'Rich & Rare Reserve' 'Rich & Rare Caramel' 'Rich & Rare Apple'
#  'Rich & Rare Apple Mini' 'Rich & Rare Canadian Whisky'
#  'Canadian Reserve Whisky' 'Northern Light' 'Legacy Canadian Whisky'
#  'Lord Calvert Canadian Whisky' "Mcmaster's Canadian"
#  'Pendleton Canadian Whisky' 'Pendleton 1910' 'Revel Stoke Roasted Pecan'
#  'Revel Stoke Pumpkin' 'Revel Stoke Roasted Apple Mini'
#  'Revel Stoke Roasted Apple' 'Windsor Canadian Supreme Whisky'
#  'Windsor Canadian Traveler' 'Bushmills Black Bush Irish Whiskey'
#  'Hell Cat Maggie' 'Green Spot' 'Jameson Mini' 'Jameson Caskmates'
#  'Jameson Gold' 'Jameson Black Barrel' 'Powers Irish Whiskey' 'Morrigan'
#  '2 Gingers Mini' '2 Gingers' 'Redbreast 12YR'
#  'Teeling Small Batch Irish Whiskey' 'Tullamore Dew Irish Whisky'
#  'Evan Williams Bottled in Bond' 'Jim Beam Bonded'
#  'Old Forester Signature 100prf Bourbon'
#  'Old Grand-Dad 100 Prf Bond Bourbon 4 Yr' 'Ancient Age Bourbon'
#  'Basil Hayden 8YR' "Booker's 6YR" 'Bird Dog Bourbon' "Blanton's Bourbon"
#  'Bourbon Supreme Bourbon' 'Bulleit Bourbon'
#  'Bulleit Bourbon Frontier Whiskey' 'Bulleit Bourbon 10YR'
#  'Cabin Still Str Bourbon' 'Cedar Ridge Bourbon'
#  'Evan Williams Yr Str Bourbon' 'Calumet Farm Bourbon'
#  "Tim Smith's Climax Fire #32" 'Duke Bourbon Whiskey' 'Eagle Rare'
#  'Early Times 36 Mo Ky Str Bourbon' 'Early Times 36 Mo Ky Str Bourbon Pet'
#  'Elijah Craig' 'Evan Williams Str Bourbon' 'Buffalo Trace Bourbon'
#  'Evan Williams Green Label' 'Evan Williams 1783'
#  'Evan Williams Black Label Traveler' 'Evan Williams Vintage'
#  'Ezra Brooks 50 Mo Ky Sour Mash Bourbon'
#  'Ezra Brooks Ky Sour Mash Bourbon' 'Four Roses Small Batch'
#  'Four Roses Single Barrel' 'Four Roses Yellow Label' 'G & W Bourbon'
#  'High West American Prairie Bourbon' 'Hirsch Small Batch Bourbon'
#  'J.R. Ewing Private Reserve' "Jefferson's Reserve"
#  "Jefferson's Very Small Batch" 'Jesse James Bourbon' 'Jim Beam Black'
#  "Jim Beam Jacob's Ghost" 'Jim Beam Mini' 'Jim Beam Traveler'
#  "Jim Beam Devil's Cut" 'Jim Beam Single Barrel' 'Knob Creek'
#  'Knob Creek Single Barrel Reserve' 'Lexington' "Maker's Mark Replica"
#  "Maker's 46" "Michter's US 1 Small Batch" 'Old Crow Traveler'
#  'Old Forester Bourbon' 'Rebel Yell' 'Ridgemont Reserve 1792'
#  'Benchmark Old No. 8' 'Ten High Traveler' 'E.H. Taylor Jr. Small Batch'
#  'Wild Turkey 81' 'Wild Turkey 101 Mini' 'Wild Turkey 101 Round'
#  'Wild Turkey 101' "Russell's Reserve 10YR" 'Woodford Reserve'
#  'Woodford Reserve Bourbon' 'Woodford Reserve Double Oaked'
#  'Calvert Extra Bl Whiskey' "Fleischmann's Preferred Bl Whiskey"
#  'Hawkeye Blend Whiskey' 'Kessler Blend Whiskey Mini'
#  'Kessler Blend Whiskey' 'Kessler Blend Whiskey Traveler'
#  'Mccormick Blend Whiskey' 'Mccormick Blend Whiskey, Pet'
#  'Rebel Yell American Whiskey' 'Seagrams 7 Crown Bl Whiskey Mini'
#  'Seagrams 7 Crown Bl Whiskey' 'Tanqueray Gin'
#  'Seagrams 7 Crown Pet Flask' 'Sunny Brook Blend Whiskey' 'Gentleman Jack'
#  'George Dickel #12' 'Jack Daniels Old #7 Black Lbl Flat'
#  'Jack Daniels Old #7 Black Lbl Mini' 'Jack Daniels Black Label'
#  'Jack Daniels Old #7 Black Lbl' 'Jack Daniels Old #7 Black Lbl Square'
#  "Five O'clock Gin" 'Hawkeye Gin' 'Jack Daniels Single Barrel Why.'
#  'Jailers Tennessee Whiskey' 'Iowa Legendary Rye Unaged'
#  'Cedar Ridge Malted Rye' 'Bulleit 95 Rye' 'Cody Road Rye' 'Jim Beam Rye'
#  'George Dickel Rye' 'Sazerac Rye' 'High West Double Rye' 'Knob Creek Rye'
#  'Old Overholt Rye' 'Rebel Yell Small Batch Rye' 'Templeton Rye'
#  "Russell's Reserve Rye 6YR" 'Three Rangers Whiskey'
#  'Artisan Grain Original Moonshine' 'Iowish Whiskey'
#  "Two Jay's Iowa Corn Whiskey" "Two Jay's Country Style Blended Why."
#  'Wicked 87 American Light Whiskey'
#  'Wicked 87 American Light Whiskey Mini'
#  'American Born Moonshine Apple Pie' 'American Born Moonshine Dixie'
#  'American Born Moonshine Original' 'Cedar Ridge Reserve Bourbon'
#  'Jim Beam Maple Mini' 'New Amsterdam Gin' 'Jim Beam Maple'
#  'Jim Beam Honey Mini' 'Jim Beam Honey' 'Bird Dog Maple'
#  'Bird Dog Peach Flavored Whiskey' "Tim Smith's Climax Moonshine"
#  'Cinerator Mini' 'Cinerator' 'Cedar Ridge Wheat Whiskey'
#  'Bird Dog Blackberry Whiskey' 'Hot Stuff' 'Bird Dog Blackberry'
#  'Cedar Ridge Unaged Whiskey' 'Cody Road Bourbon'
#  'Queen Bee Honey Whiskey' 'Red Stag Black Cherry Mini'
#  'Red Stag By Jim Beam' 'Seagrams Seven Crown Dark Honey'
#  'Red Boot Spiced Whiskey' 'Knob Creek Smoked Maple' 'Prairie Fire'
#  "Cedar Ridge Short's Whiskey" 'Stone Fence Apple Cider Whiskey'
#  'Jim Beam Kentucky Fire Mini' 'Jim Beam Kentucky Fire'
#  'Bird Dog Apple Flavored Whiskey Mini' 'Bird Dog Apple Flavored Whiskey'
#  'Seagrams Seven Crown Orchard Apple' 'Jim Beam Apple'
#  "Uncle Bob's Root Beer" 'Jim Beam Apple Mini'
#  "Uncle Bob's Root Beer Mini" 'Beefeater Gin' 'Paramount Gin'
#  'Bombay Dry Gin' 'Bombay Sapphire East' 'Bombay Sapphire Gin'
#  'Boodles British Gin London Dry' "Broker's London Dry Gin" 'Bulldog Gin'
#  "Hendrick's Gin" "Master's Gin" 'Pinnacle Gin' 'Plymouth Gin'
#  'Tanqueray Bloomsbury Gin' 'Tanqueray No. Ten' 'Tanqueray Rangpur Gin'
#  'Aviation American Gin' 'Barton Gin' 'Arrow Gin' 'Blaum Bros. Gin'
#  "Burnett's Gin London Dry" 'Calvert Gin' 'Clearheart Gin' "Five O'clock"
#  "Fleischmann's Gin" "Fleischmann's Dry Gin" "Gilbey's Gin London Dry"
#  "Gordon's Gin London Dry" "Gordon's Gin London Dry - Pet"
#  'Tippy Cow 50ml Sampler Pack' 'McCormick Gin' 'McCormick Gin Pet'
#  'Mr. Boston Riva Gin' 'Paramount Gin Traveler' 'Phillips Gin'
#  'Prairie Organic Gin' 'River Rose Gin' 'Paramount Sloe Gin'
#  'Seagrams Extra Dry Gin Mini' 'Seagrams Extra Dry Gin'
#  'Seagrams Extra Dry Gin Pet' 'Seagrams Lime Twisted Gin'
#  'Seagrams Peach Twisted Gin' 'Pinnacle Cucumber' 'Belvedere Wild Berry'
#  'Arrow Sloe Gin' 'Svedka Peach' 'Pinnacle Mimosa'
#  'Svedka Mango Pineapple' 'Kru Pistachio' 'Svedka Strawberry Lemonade'
#  'Grey Goose Le Melon' 'Absolut Cilantro' 'Belvedere Intense Unfiltered'
#  'Absolut Berri Acai' 'Effen Vodka' 'Absolut Grapevine'
#  'Absolut Swedish Vodka 80 Prf Mini' 'Absolut Swedish Vodka 80 Prf'
#  'Chopin Vodka' 'Absolut Apeach' 'Absolut Peppar' 'Grey Goose Vodka'
#  'Absolut Citron (lemon Vodka)' 'Absolut Pears' 'Absolut Raspberri'
#  'Absolut Ruby Red' 'Absolut Vanilia' 'Grey Goose Vodka Mini'
#  'Belvedere Pink Grapefruit' 'Absolut Mandrin' 'Crystal Head Vodka'
#  'Belvedere Vodka' 'Ciroc Luxury Vodka' 'Effen Black Cherry Vodka'
#  'Absolut Cherrykran' 'Grey Goose Le Citron' 'Fris Danish Vodka'
#  'Effen Cucumber' "Grey Goose Vodka L'orange" 'Ketel One Citroen'
#  'Ketel One Imported Vodka' 'Pearl Vodka' 'Pearl Vodka PET'
#  'Pinnacle Vodka' 'Grey Goose La Poire Vodka' 'Pinnacle Raspberry'
#  'Sobieski Vodka' 'Pearl Pomegranate Vodka' 'Stolichnaya Elit Vodka'
#  'Stolichnaya Ohranj Vodka' 'Stolichnaya Russian Vodka 80 Prf'
#  'Stolichnaya Premium Vodka 80 Proof (lv)' 'Reyka Vodka' 'Pinnacle Grape'
#  'Stolichnaya Blueberi' 'Svedka Raspberry Vodka' 'Svedka' 'Svedka Vodka'
#  'Barton Vodka' 'Barton Vodka Pet' 'Three Olives Vodka'
#  'Svedka Clementine Vodka' 'Svedka Citron Vodka'
#  'Tanqueray Sterling Vodka' 'Stoli Razberi (raspberry)'
#  'Stolichnaya Razberi Vodka 75 Proof' 'Stoli Strasberri Vodka'
#  'Bakon Rosemary Vodka' 'Shady Fruit Valencia Orange' 'UV Sangria Mini'
#  'UV Sangria' 'Shady Fruit Ruby Red Grapefruit' 'Deep Eddy Lemon Mini'
#  'Deep Eddy Lemon Vodka' 'Skyy Infusions Texas Grapefruit'
#  'Skyy Infusions Pacific Blueberry' 'New Amsterdam Mango'
#  "Seagram's Red Berry Flavored Vodka" 'Dueces Wild Vodka'
#  "Burnett's Mango Pineapple" 'Deep Eddy Cranberry Mini'
#  'Deep Eddy Cranberry' "Seagram's Peach Flavored Vodka"
#  'New Amsterdam Orange' 'New Amsterdam Pineapple' 'UV Sriracha'
#  'Prairie Organic Cucumber' 'New Amsterdam Coconut' 'New Amsterdam Citron'
#  'New Amsterdam Peach' 'New Amsterdam Red Berry' 'Deep Eddy Ruby Red Mini'
#  'Deep Eddy Sweet Tea' "Burnett's Strawberry Banana"
#  "Burnett's Tropical Punch" 'UV Candy Bar Mini' 'UV Candy Bar' 'UV Peach'
#  'UV Salty Watermelon Mini' 'Jeremiah Weed Sweet Tea Vodka'
#  'UV Salty Watermelon' 'Skyy Infusions Wild Strawberry'
#  'Smirnoff Root Beer Float' 'Rain Cucumber Vodka' 'UV Whipped'
#  'UV Chocolate Cake Mini' "Burnett's Grape Vodka" 'UV Chocolate Cake'
#  'Skyy Infusions Citrus' 'Skyy Infusions Pineapple'
#  'Smirnoff Silver Vodka 90 Prf' '360 Double Chocolate Vodka'
#  "Burnett's Watermelon" 'Jeremiah Weed Sweet Tea'
#  'Jeremiah Weed Peach Sweet Tea' 'Sweet Carolina Sweet Tea Flavored Vodka'
#  'Firefly Sweet Tea Vodka' "Burnett's Cherry Vodka"
#  'Burnetts Raspberry Vodka' "Burnett's Citrus" 'Uv Pink Lemonade Vodka'
#  "Burnett's Pineapple" '360 Sorrento Lemon Vodka'
#  'Hawkeye Blue Raspberry Vodka' 'Hangar One Citron' 'Hangar One Mandarin'
#  'Hangar One Lime' 'Uv Blue (raspberry) Vodka' 'Uv Grape Vodka'
#  'Uv Citruv (citrus) Vodka' 'Admiral Nelson Spiced Rum'
#  "Burnett's Blue Raspberry Vodka" 'Uv Red (cherry) Vodka'
#  'Uv Blue Raspberry Vodka Traveller' 'Bacardi Peach Red' 'Bacardi Limon'
#  'Everclear Alcohol' "Burnett's Fruit Punch" 'Uv Cake Vodka'
#  'UV Cake Vodka' 'Blue Chair Bay White' 'Blue Chair Bay Coconut'
#  'Uv Green (apple) Vodka' 'Uv Ivory (vanilla) Vodka' 'Uv Orange Vodka'
#  'Bacardi Torched Cherry' 'Captain Morgan Parrot Bay Key Lime'
#  'Captain Morgan 1671' 'Phillips Lime Flavored Vodka'
#  'Uv Blue Raspberry Vodka Mini' "Burnett's Limeade Vodka"
#  'Uv Cherry Red Vodka Mini' 'Captain Morgan Spiced Rum Mini'
#  '360 Concord Grape Vodka' '360 Mandarin Orange Vodka'
#  '360 Madagascar Vanilla Vodka' '360 Bing Cherry Vodka'
#  '360 Georgia Peach Vodka' 'UV Sugar Crush' 'Dehner Distillery 151'
#  'Calico Jack Cherry' 'Cruzan Blueberry Lemonade' 'Cruzan Raspberry Rum'
#  'Cruzan Coconut Rum' 'Cruzan Dark Rum' 'Cruzan Light Rum'
#  'Cruzan Vanilla Rum' 'Cruzan Strawberry Rum' 'Lady Bligh Spiced Rum'
#  'Paramount Gold Rum Traveler' 'Lady Bligh Butter Rum'
#  'Paramount Gold Rum' 'Paramount White Rum' 'Paramount White Rum Traveler'
#  'Phillips White Rum' 'Sailor Jerry Spiced Navy Rum'
#  'Artisan Grain Silver Rum' 'Cedar Ridge Dark Rum' 'Hawkeye Light Rum'
#  'Clearheart Rum' 'Kraken Black Spiced Rum' 'Ciroc Peach'
#  'Holstein Coconut Rum' "Holstein Single Barrel Sippin' Rum"
#  'Kraken Black Spiced Mini' 'Ciroc Red Berry' 'Fireball Cinnamon Whiskey'
#  'Paradise Caribbean Mist Rum' 'Paradise Island Bay Rum'
#  'Paradise White Sand Rum' 'Havana Judge White'
#  'Steel Drum Pure Cane Reserve' 'Steel Drum' 'Courvoisier Vsop Cognac'
#  'Courvoisier Vs Coganc' 'Courvoisier Vs Cognac' "D'usse VSOP"
#  'Hennessy VS' 'Hennessy Vs Cognac Minis' 'Hennessy Vs Cognac 100ml'
#  '1800 Coconut' "Carolan's Irish Cream Liqueur" "McCormick's Irish Cream"
#  'Hennessy Vs Cognac' 'Rumchata Mini' 'Hennessy XO Cognac'
#  'Hennessy Black' 'Hennessy VSOP Privilege'
#  'Remy Martin 1738 Accord Royal' 'Remy Martin Xo Excellence'
#  'Remy Martin VSOP' 'Remy Martin Vsop (flask)' 'Remy Martin Vsop Cognac'
#  'Original Gangster XO' 'St. Remy Vsop Napoleon Brandy'
#  'Five Star Pegasus' 'Five Star Pirate Sword' 'Five Star Turtle'
#  'Presidente Grape Brandy (pedro Domecq)' 'Stock 84 Brandy'
#  'Christian Bros Brandy Traveler' 'Christian Bros Grand Reserve Vsop'
#  'Cedar Ridge Brandy' 'Christian Bros Brandy'
#  'Christian Bros Brandy-Square' 'Christian Bros Brandy-Round'
#  'E & J Xo Brandy' 'E & J Vsop Superior Reserve Mini'
#  'E & J Vsop Superior Reserve' 'E & J VS' 'E & J Vs Brandy Mini'
#  'Rumchata' 'E & J Vs Brandy' 'E & J Vs' 'Korbel Brandy'
#  'E & J Vs Brandy Travelers' 'E & J Vs Brandy Square'
#  'E & J Vs Brandy Round' 'Hartley Brandy' 'Korbel Brandy Pet'
#  'Paul Masson Vsop Grande Amber Brandy' 'Paul Masson Grande Amber Brandy'
#  'Arrow Apricot Flav Brandy' 'Paul Masson Vs Brandy Mini'
#  'Mr. Boston Apricot Brandy' 'Cedar Ridge Apple Brandy'
#  'Cedar Ridge Grappa' "Two Jay's Grappa" 'Wisconsin Club Brandy'
#  'Paramount Apricot Flavored Brandy' 'Arrow Blackberry Flav Brandy'
#  'Dekuyper Blackberry Brandy' 'Mr. Boston Blackberry Brandy'
#  'Paramount Cherry Brandy' 'Paramount Blackberry Brandy'
#  'Christian Bros Peach' 'Phillips Blackberry Flav Brandy'
#  'Berentzen Apple' 'Berentzen Bushel & Barrel' 'Ciroc Pineapple Mini'
#  'Ciroc Pineapple' 'Caravella Limoncello' 'Campari Italian Aperitivo'
#  'Domaine de Canton' 'Chambord Liqueur Royale De France' 'Ciroc Amaretto'
#  'Citronge' 'Ciroc Coconut' 'Cointreau Liqueur' 'Romana Black Sambuca'
#  'Fireball Cinnamon Whiskey Mini Dispenser' 'Fireball Cinnamon Whisky'
#  'Fireball Cinnamon Whiskey PET' 'Drambuie Liqueur'
#  'Fernet Branca Liqueur' 'French Kiss Tropical Liqueur Mini'
#  'French Kiss Tropical Liqueur' 'Frangelico Liqueur' 'Grey Goose VX'
#  'Galliano Liqueur' 'Goldschlager Cinnamon Schnapps Mini'
#  'Goldschlager Cinnamon Schnapps' 'Grand Marnier Cordon Rouge Mini'
#  'Grand Marnier Cordon Rouge' 'Il Tramonto Limoncello' 'Hpnotiq Mini'
#  'Hpnotiq' 'Tequila Rose Liqueur' 'Tequila Rose Liqueur Mini'
#  'Hornitos Spiced Honey' 'Jagermeister Spice' 'Jagermeister Liqueur Mini'
#  'Jagermeister Liqueur' 'Licor 43' 'Lucid Absinthe Liqueur w/Glass'
#  'Lucid Absinthe' 'Maraska Kruskovac' 'Metaxa Ouzo' 'Old Barrel'
#  'Penthouse Spirits Whiskey Tequila Fusion'
#  'Penthouse Spirits Cherry Flavored Vodka for Her'
#  'Penthouse Spirits Cherry Flavored Vodka for Him' 'Peligroso Cinnamon'
#  'Piehole Apple Pie Mini' 'Piehole Apple Pie' 'Piehole Cherry Pie Mini'
#  'Piehole Cherry Pie' 'Piehole Pecan Pie' "Pimm's Cup No. 1"
#  'Remy Martin V' 'Romana Sambuca Italian Liquore'
#  'Solerno Blood Orange Liqueur' 'St. Germain'
#  'Grangala Triple Orange Liqueur' 'Midori Melon Liqueur'
#  'X Rated Fusion Liqueur' 'Yukon Jack Canadian Liqueur'
#  'Yukon Jack Jacapple' 'Yukon Jack Perma Frost Schnapps'
#  'Copa De Oro Mexican Coffee' 'Grand Marnier Raspberry Peach'
#  'Kahlua Coffee Liqueur Mini' 'Kahlua Coffee Liqueur' 'Kahlua Especial'
#  'Kahlua French Vanilla Liqueur' 'Kamora Coffee Liqueur'
#  'Kahlua Pumpkin Spice' 'Kahlua Salted Caramel' 'Kapali Coffee Liqueur'
#  'Kahlua Peppermint Mocha' 'Patron Xo Cafe' 'Luxardo Maraschino Cherry'
#  'Baileys Expresso Creme' "Bailey's Chocolate Cherry"
#  "Bailey's Salted Caramel" "Bailey's Original Irish Cream Minis"
#  "Bailey's Original Irish Cream" "Bailey's Vanilla Cinnamon"
#  'Emmets Irish Cream Liqueur' "St. Brendan's Superior Irish Cream Liqueur"
#  "St. Brendan's Peppermint Bark Liqueur"
#  "St. Brendan's Salted Caramel Liqueur"
#  "Dr. McGillicuddy's Apple Pie Mini"
#  "Dr. Mcgillicuddy's Apple Pie Schnapps" "Dr. Mcgillicuddy's Cherry Mini"
#  "Dr. Mcgillicuddy's Cherry Schnapps" "Dr. Mcgillicuddy's Mentholmint"
#  'Dekuyper Luscious Peachtree Schnapps' 'Juarez Triple Sec'
#  'Dekuyper Peachtree Schnapps Pet' 'Dekuyper Island Punch Pucker'
#  'Dekuyper Watermelon Pucker' 'Dekuyper Hot Damn! 100 Proof'
#  'Dekuyper Mixed Berry Medley' 'Firewater Cinnamon Schnapps'
#  'Ice Hole Plum Schnapps' 'Ice Hole Butterscotch Schnapps'
#  'Montezuma Triple Sec' 'Ice Hole Mint Schnapps'
#  'Maui Blue Hawaiian Schnapps' 'Paramount Triple Sec'
#  'Paramount Peach Schnapps' '99 Cinnamon Mini' 'Southern Comfort'
#  '99 Apples' '99 Blackberries' '99 Bananas' '99 Bananas Mini'
#  'Paramount Butterscotch Schnapps' 'Paramount Strawberry Schnapps'
#  'Jose Cuervo Especial Silver' 'Phillips Root Beer Schnapps'
#  'Phillips Hot 100 Cinnamon Schnapps' 'Arrow Anisette'
#  'Paramount Anisette' 'Dekuyper Signature Blue Curacao'
#  'Hiram Walker Orange Curacao' 'Paramount Blue Curacao'
#  'Mr. Boston Rock & Rye' 'La Prima Triple Sec'
#  'Cold Spell Mint Whiskey Mini' 'Cold Spell Mint Whiskey'
#  'Tortilla Triple Sec' 'Atomic Cinnamon Whiskey' 'Bella Limoncello'
#  'Jeremiah Weed 100prf Bourbon Liqueur'
#  "Jack Daniel's Tennessee Honey Mini" "Jack Daniel's Tennessee Honey"
#  'Don Julio Blanco Tequila' 'Firefly Apple Pie Moonshine'
#  "Jack Daniel's Tennessee Fire Mini" "Jack Daniel's Tennessee Fire"
#  '1800 Silver Tequila'
#  'Ole Smoky Harley Davidson Road House Charred Moonshine'
#  'Ole Smoky Apple Pie Moonshine' 'Ole Smoky Cherry Moonshine'
#  "Ole Smoky Hunch Punch Lightnin'" "Sipp'n Sweet Corn"
#  'Southern Host Whiskey Liqueur' 'Southern Comfort Caramel'
#  'Southern Comfort Cherry' 'Southern Comfort Lime' 'Southern Comfort Mini'
#  'Southern Comfort Pet' 'Southern Comfort PET' 'Southern Comfort 100 Prf'
#  'Avion Silver' 'Cabo Wabo Blanco' 'Casa Noble Crystal'
#  'Casa Noble Reposado' 'Casamigos Blanco'
#  'Jose Cuervo Especial Silver Tequila Mini'
#  'Jose Cuervo Especial Silver Tequila'
#  'Jose Cuervo Silver "Rolling Stones"' 'DeLeon Platinum'
#  'Don Julio Blanco' '1800 Silver' 'El Jimador Silver Tequila'
#  'El Mayor Blanco' 'El Zarco Silver' 'Espolon Blanco'
#  'Familia Camarena Silver' 'Exotico Blanco' 'Juarez Tequila Silver'
#  'La Prima Tequila/white' 'Margaritaville Silver Tequila'
#  'Milagro Silver Tequila' 'Montezuma White Tequila' 'Sauza 901 Silver'
#  'Olmeca Altos Plata Mini' 'Olmeca Altos Plata' 'Patron Tequila Silver'
#  'Patron Silver Tequila' 'Patron Tequila Silver Mini' 'Peligroso Silver'
#  'Sauza Blue Silver' 'Hornitos Lime Shot' 'Hornitos Plata'
#  'Sauza Blanco Silver' 'Tortilla White Tequila' 'Hornitos Black Barrel'
#  'Casa Noble Anejo' 'Avion Anejo' 'Avion Reposado' 'Cazadores Anejo'
#  'Cazadores Reposado' 'Cabo Wabo Reposado' 'Don Julio Reposado'
#  'Cabrito Reposado' 'Don Julio 1942' 'Don Julio Anejo Tequila'
#  'Don Julio Anejo' 'Casamigos Reposado' 'El Mayor Anejo Tequila'
#  'El Mayor Reposado' 'Jose Cuervo Especial Reposado Tequila Mini'
#  'Jose Cuervo Especial Reposado Tequila'
#  'Jose Cuervo Especial Reposado Flask'
#  'Jose Cuervo Especial Reposado Square' '1800 Reposado Tequila'
#  '1800 Reposado' 'Jose Cuervo Tradicional Reposado Tequila'
#  '1800 Anejo Tequila' 'Corralejo Reposado Tequila'
#  'El Jimador Anejo Tequila' 'El Jimador Reposado Tequila'
#  'Espolon Reposado' 'DeLeon Reposado' 'Juarez Tequila Gold'
#  'Juarez Gold Tequila' 'Exotico Reposado' 'La Prima Tequila/gold'
#  'Margaritaville Gold Tequila' 'Familia Camarena Reposado'
#  'Monte Alban Mezcal' 'Montezuma Gold Tequila' 'Olmeca Altos Reposado'
#  'Sauza Cien Anos Reposado' 'Patron Reposado Tequila' 'Patron Anejo'
#  'Pepe Lopez Gold' 'Peligroso Anejo' 'Peligroso Reposado' 'Sauza Gold'
#  'Sauza Conmemorativo' 'Sauza Blue Reposado' 'Hornitos Gold'
#  'Sauza Hornitos Anejo' 'Tres Generaciones Anejo' 'Torada Tequila Gold'
#  'Tortilla Gold Tequila' 'Mac Spey Blended' 'Cragabus Blended'
#  "Irish Single Malt 5yr ( Stephen's choice)"
#  "Irish Single Malt 11yr( Jack's Choice)" 'Great Glen 8 yr'
#  'Yahara Bay Barrell Mellowed Gin' 'Rothman & Winter Orchard Pear'
#  'Rothman & Winter Orchard Peach'
#  "Jack Daniel's Single Barrel Barrel Proof" '5 year Irish Single Grain'
#  'Two Casks- Caol IIa & Speyburn Sherry' 'Blair Athol' 'Absinthe Verde'
#  'Elderflower Liqueur' 'Fernandez Brandy De Jerez'
#  'Hunters Herbal Liqueur' 'Italian Brandy' 'Apricot Grappa'
#  'Framboise Raspberry Liqueur' 'Ginger Liqueur' 'Nut Chocolate'
#  'Yahara Bay American Whiskey' 'Kirsch Cherry Brandy' 'Latte Machiatto'
#  'Libertine Absinthe(French Absinthe)' 'Whiskey Liqueur'
#  'Tres Agaves Reposado' 'The Botanist Islay Dry Gin'
#  'Yahara Bay Lavendar Liqueur' 'Irish Single Malt 14yr-Brother in Arms'
#  'Calvados Morin Selection' 'Yahara Bay Vanilla Dream'
#  'Buchanan Deluxe 12yr' 'Johnnie Walker Red Scotch Minis'
#  'St Elizabeth Allspice Dram' 'Rothman & Winter Orchard Apricot Liqueur'
#  'Highland Park 18yr Sing Malt Scotch HA'
#  'Dekuyper Signature Hazelnut Bliss' 'Cerises  Rogue(cherry Liqueur)'
#  'No. 3 London Dry Gin' 'Sour Cherry' 'Maraska Slivovitz'
#  'Hiram Walker Blackberry Brandy' "Trader Vic's Macadamia Nut Liqueur"
#  'Pittyvaich 25YR HA' 'The Cally 40YR HA' "Maker's Mark Mini"
#  "Wild Turkey Master's Keep HA" 'Chartreuse Green French Liqueur'
#  "Stranahan's Colorado Whiskey" "Jim Beam Distiller's Masterpiece HA"
#  'Monkey 47' "Uncle Val's Botanical Gin" 'Anchor Old Tom Gin'
#  'Hudson Manhattan Rye' 'Hudson New York Corn'
#  'Bird Dog Hot Cinnamon Flavored Whiskey' 'Hudson Single Malt'
#  'St. George Terroir Gin' 'Westland American Single Malt'
#  'Westland Peated Single Malt' 'Tru Gin'
#  'Westland Sherry Wood Single Malt' 'Citadelle Gin'
#  'Svedka Strawberry Lemonade Vodka' 'Beluga Noble Vodka'
#  'Three Olives Tartz' 'Bluecoat American Dry Gin' 'Letherbee Gin'
#  'Double Cross Vodka' 'Three Olives Vanilla' 'Karlssons Gold Vodka'
#  'Ketel One Oranje' 'Three Olives Purple' 'Sobieski Raspberry Vodka'
#  "Member's Mark Vodka" 'Ocean Organic Vodka'
#  'Three Olives "Dude" Flavored Vodka' 'Pinnacle Red Liquorice'
#  'Kru 82 Vodka glass' "Gilbey's Vodka" 'High Stick Vodka'
#  'Christian Drouin Calvados Selcetion' 'Kirk & Sweeney 12YR Old Anejo'
#  'Hamilton Overproof Rum' 'Relska 80 Proof Vodka'
#  'Teton Glacier Potato Vodka' 'Popov Vodka 100 Prf'
#  'Pucker Vodka Watermelon' 'DeKuyper Apricot Brandy' 'Alize Red Passion'
#  'Penny Blue XO Rum' 'Ypioca Cachaca Prata' 'Don Q Passion'
#  'Don Q Coconut' "Member's Mark Spiced Rum" 'The Kings Ginger'
#  'Pierre Ferrand Dry Curacao' 'Piehole Pecan Pie Mini'
#  'Yukon Jack Wicked Hot' 'Smirnoff Iced Cake'
#  'Buffalo Trace Bourbon Cream HA' 'Ice Hole Salty Caramel Schnapps'
#  'Luxardo Morlacco Cherry Liqueur' 'Revel Stoke Spiced'
#  "St. Brendan's Irish Cream Liqueur" 'Hiram Walker Caramel Apple'
#  'Hophead Hopped Vodka' 'Figenza Mediterranean Fig Vodka'
#  'Dekuyper Cranberry Crush' 'Dekuyper Red Apple' 'Grapefruit Liqueur'
#  'Black Currant Liqueur Creme de Cassis' 'Kavalan Concertmaster'
#  'Kavalan King Car Conductor' 'Lunazul Blanco Tequila'
#  'Glen Garioch Renaissance' "Berry's Own 11yr St. Lucian Rum"
#  "Berry's Own 8yr Grenada Rum" 'Maestro Dobel Tequila'
#  "Jack Daniel's Masters Distillers 3" 'Buchanan Deluxe 12YO'
#  'Caol Ila 17YR HA' 'Clynelish Select Reserve HA' 'Dailuaine 34YR HA'
#  'Dalwhinnie Distillers Edition HA' 'Macallan Rare Cask HA'
#  'Hiram Walker Peppermint Schnapps' 'Christian Brothers Frost Brandy'
#  'Jack Daniels Single Barrel' 'E & J Apple' 'Red Stag Black Cherry'
#  'Lady Bligh' 'Paradise Caribbean Mist' 'Artisan Grain Silver'
#  'Outerspace Mini' 'Celtic Honey Liqueur' 'Bacardi 151 Prf'
#  'Elijah Craig Cask Barrel Proof HA' 'Pikesville Rye 110prf HA'
#  'Fireball Cinnamon' 'Jose Cuervo Platino Reserva De La Familia'
#  'Gran Gala Liqueur' "Seagram's Lime Twisted Gin"
#  'Naked Jay Big Dill Vodka' 'Old Ezra 7yr 101 proof'
#  "Berry's Own 10yr Panama Rum" "Berry's Own 12yr Guadaloupe Rum"
#  "Berry's Own 9yr Fiji Rum" 'Grande Absente' 'Yeni Raki' 'Kahlua Mocha'
#  'Bols Black Raspberry Liqueur' 'Di Amore Quattro Orange'
#  "Hussong's Reposado Tequila 100% Agave" 'Mr Boston Five Star Brandy'
#  'Seagram Blue Beast Gin & Juice' 'Dr. McGillicuddys Wild Grape'
#  'Amaretto Gozio' 'Buchanans Scotch' 'Speyburn Single Malt Scotch'
#  'Mr Boston Sloe Gin' 'Don Julio Real' 'Mr Boston 5 Star Brandy'
#  'Bastille 1789' 'Burnetts Appleberry' 'Burnetts Cherry Limeade'
#  "Burnett's Peach Vodka" "Burnett's Pink Lemonade"
#  "Burnett's Ruby Red Grapefruit" 'Chila Orchata Mini'
#  'Evan Williams Black Label Mini' 'Evan Williams Cherry Mini'
#  'Evan Williams Honey Mini' 'Taaka Pineapple Vodka Mini'
#  'Taaka Pink Lemonade Mini' 'Wave Baja Mini' 'Wave Blue Raspberry Mini'
#  'Wave Cherry Vodka' 'Wave Tiki Vodka Mini' 'Del Maguey Vida Mezcal'
#  "Dr. McGillicuddy's Grape" 'Di Amore Raspberry' 'Inver House Scotch'
#  'Skyy Infusions Blood Orange' 'SKYY Infusions Vanilla Bean'
#  'Everclear Alcohol 190 Proof' 'Penderyn Single Malt Welsh Why.'
#  'Ron Zacapa XO' 'Speyburn Arranta Casks' 'Springbank 10yr'
#  'Van Gogh Dutch Caramel Vodka' 'Charbay R5 Whiskey'
#  'Clement Premiere Canne Rum' 'Hillrock Estate Solera Str. Bourbon Why.'
#  'Kilchoman 100% Islay' 'Old Pulteney 12yr Sing Malt Scotch DNO DISC'
#  'Stroh 160 Rum' 'Black Haus Blackberry Schnapps'
#  'Pueblo Viejo Anejo Tequila' 'Pueblo Viejo Reposado'
#  'Canadian Regency Light' 'Pirassunga 51 Cachaca' 'Ketel One Vodka Mini'
#  'Cedar Ridge Single Malt Whiskey' 'Wicked 87 Mini' 'E & J Peach'
#  'Outerspace' 'Russian Standard' 'Smirnoff Pomegranate'
#  'Forbidden Secret White Chocolate' 'Evan Williams Traveler'
#  'Penthouse Spirits Cherry for Him' 'Penthouse Spirits Cherry for Her'
#  'Stolichnaya Premium Vodka 80 Prf' "Serpent's Bite Apple Cider Mini"
#  'E & J XO' 'Juarez Gold' 'New Amsterdam'
#  'Smirnoff Sourced Cranberry Apple' 'Smirnoff Sourced Pineapple'
#  'Smirnofff Sourced Ruby Red Grapefruit' 'Hustle'
#  'Sminoff Sourced Pineapple Mini'
#  'Smirnoff Sourced Ruby Red Grapefruit Mini'
#  'Smirnoff Sourced Cranberry Apple Mini' 'French Kiss Tropical Mini'
#  "Serpent's Bite Apple Cider" 'Deep Eddy Lemon' 'French Kiss Tropical'
#  'Rain Cucumber' 'Calico Jack' '360 Bing Cherry'
#  "Michter's US*1 Small Batch Bourbon Whiskey"
#  "Hot Lil' Hooch Cherry Cinnamon Whiskey" 'Midnight Moon Peach'
#  'Paradise Island Bay' 'Paradise White Sand' 'Cold Spell Mint'
#  "Hussong's Platinum Anejo" 'Wisconsin Club'
#  'Paul Masson Red Berry Grande Amber' 'Svedka 100 Prf' 'Duke'
#  'Glenfiddich 18YR' 'Seagrams Red Berry' 'Cleopatra XO'
#  'TGIFridays Ultimate Orange Dream' 'Seagrams Peach'
#  'Paul Masson Red Berry Grande Amber Mini' 'Cold Spell Mint Mini'
#  'Wicked 87' 'Hartley' 'Canadian Ltd'
#  "Ole Smoky Hunch Punch Lightnin' Moonshine" 'Bulleit' 'Mr. Boston Riva'
#  'Penthouse' 'Bakon Rosemary' "Annie's Apple Pie"
#  'Tyrconnell Irish Sing Malt' 'Finlandia Vodka Raspberry'
#  "Burnett's Orange Cream Vodka" "Carolan's Irish Cream"
#  'Bacardi Anejo Mex Rum' 'Metaxa 7 Star Amphora'
#  'Metaxa Five Star Liqueur' 'Patron Gran Platinum'
#  "Whaler's Rare Res Dark Rum" 'Whalers Vanille Rum' "Dewar's 15 Yr Old"
#  'Spinnaker-Speyside Single Malt Scotch Whiskey' 'Bacardi Big Apple Rum'
#  'Belvedere Citrus' 'Cruzan Guava Rum' 'Dekuyper Creme De Cassis'
#  'Leroux Blackberry Brandy' 'Passoa Liqueur' 'Lunazul Tequila Reposado'
#  'Bird Dog Jalapeno Honey' 'Cazadores Blanco'
#  'Flor de Cana Gran Reserva 7YR' 'Irish Mist Honey Liqueur'
#  'Forty Creek Barrel Select' 'Famous Black Grouse'
#  "Gibson's Finest Aged 12 yr" 'Wisconsin Club Gold Tequila'
#  'Cinnabon Cinnamon' 'Five Star Horse'
#  'Jack Daniels TN Honey & Jack Daniels TN Fire 750mls w/2Gls' 'Regalia'
#  'Giori Lemoncillo' 'Christian Bros Apple' 'Christian Bros Apple Mini'
#  'La Collection Tiger Blue' 'Arrow Apricot Brandy'
#  'Arrow Blackberry Flav Brandy Pet' 'Arrow Ginger Flav Brandy'
#  'Aberfeldy 12 Year Single Malt Scotch' 'Don Q Gold Rum' 'Alize Blue'
#  'Alize Gold' 'Bernheim Original Wheat Whiskey' 'Flor De Cana White'
#  'Haymans Sloe Gin' 'Jts Brown Bourbon'
#  'Mackinlays Shackleton The Journey' 'Milagro Tequila Sbr Silver'
#  'Smith And Cross Jamaica Rum' "Michter's Us*1 American Whiskey"
#  "Dr. McGillicuddy's Mentholmint" 'J W Dant Bond 100prf Bourbon'
#  'The Quiet Man' 'The Quiet Man 8YR' 'La Collection Santa Claus'
#  'La Collection Race Car' 'High West' 'Griffon'
#  'Firefly Raspberry Tea Vodka' 'Pina Colada' 'Armagnac XO 25yr'
#  'Irish Single Malt 14yr- Brother in Arms' 'Williams Pear Brandy'
#  'Yahara Bay Apple Crisp(apple pie)' 'Armagnac XO 10 YR' 'Dalmore 12YR'
#  "Jack Daniel's  4YR Rye Single Barrel" 'Patron Roca Anejo'
#  'Patron Roca Reposado' 'Patron Roca Silver'
#  'Three Olives Cake Flavored Vodka' 'Three Olives Watermelon Vodka'
#  'Koval Bourbon' 'Kammer Williams Pear Brandy W/pear'
#  'Baja Luna Black Raspberry' 'Barsol Primero Quebranta Pisco'
#  'Chartreuse Yellow' 'Glenrothes 2001' 'Nikka Coffey Grain Whiskey'
# ...
#  'YB Bourbon 200ml' 'YB Bourbon 100ml' 'YB Bourbon 50ml Tripple'
#  'Johnnie Walker Blue Year of the Monkey HA' 'Rhetoric 22YR HA'
#  'Rebel Yell Kentucky Straight Bourbon Mini'
#  'Roger Clynes Mexican Moonshine Silver Tequila'
#  'Roger Clynes Mexican Moonshine Anejo'
#  'Roger Clynes Mexican Moonshine Reposado' 'Mellow Corn Whiskey'
#  'Barsol Selecto Italia Pisco' 'Encanto Grand & Noble'
#  'Glenfarclas 25yr Sing Malt' 'Pierre Ferrand Cognac 1840' 'Hendrick Gin'
#  'The Knot Irish Whiskey' '99 Blackberries Mini' '99 Watermelon Mini'
#  "Dr. McGillicuddy's Ice Mint" 'Whalers Great White Rum'
#  "Whaler's Original Dark Rum" "Distiller's Gin No. 11"
#  'North Shore Aquavit - Private Reserve'
#  'North Shore Sirène Absinthe Verte'
#  'Woodford Reserve Personal Selection Barrel' 'Effen Green Apple'
#  'Effen Blood Orange' 'Crown Royal Vanilla' 'Yellowstone Select'
#  "Dr. McGillicuddy's Mentholmint Mini" 'Till American Wheat Vodka'
#  'Cruzan 151' 'Skyy Infusions Bartlett Pear'
#  '"Jose Cuervo Silver ""Rolling Stones"""'
#  'Baileys Pumpkin Spice Irish Cream' '"Rumchata ""GoChatas"""'
#  'Gjergj Kastrioti Skenderbeu V.S Konjak'
#  'Paul Masson Pineapple Grande Amber Brandy'
#  'Gjergj Kastroti Skenderbeu Balle Kazani Skrapari'
#  'Gjergj Kastrioti Skenderbeu V.S.O.P Konjak'
#  '"Rumchata ""MiniChatas"" Creamer Cups"' 'Deep Eddy Ruby Red Grapefruit'
#  'Paul Masson Apple Grande Amber Brandy'
#  "Fulton's Harvest Pumpkin Liqueur" 'Virginia Black Whiskey'
#  'Gas Monkey Cinnamon Tequila' 'Jim Beam Double Oak'
#  "Fulton's Harvest Apple Pie Liqueur"
#  "Jack Daniel's 4YR Rye Single Barrel" 'Laphroaig Lore HA' 'Malfy Gin'
#  'Clase Azul Reposado' 'Kentucky Tavern' 'Stock Limonce' 'Cherry Heering'
#  'Clear Creek Cherry Brandy (Kirschwasser)' 'Clear Creek Grapp Nebbiolo'
#  'Clear Creek Grappa Muscat' 'Clear Creek Grappa Pinot Noir'
#  'Clear Creek Grappa Sangioveses'
#  'Clear Creek Reserve Apple Brandy - Aged 8 years' 'Ouzo #12'
#  'Limited Edition Rebel Yell Straight Kentucky Bourbon'
#  'Bombay Sapphire Gin Minis' 'Tequila Tapation Reposado'
#  'Jose Cuervo Especial Silver Mini' 'Massenez Poire William Pear Brandy'
#  'Bols Apricot Brandy' 'Tomatin Single Malt Scotch 18yr'
#  'Bacardi Limon Mini' "Burnett's Cranberry"
#  "Burnett's Cucumber Lime  Vodka" "Burnett's Sour Apple"
#  "Burnett's Sweet Tea Vodka" 'Espolon Anejo X HA' 'Bowmore 18YR HA'
#  'Auchentoshan 21YR HA' 'Members Mark Silver Rum Tray Pack'
#  'Sauza Cucumber Chili' 'Sheep Dip Orig Oldbury Malt Scotch'
#  'Tomatin Scotch Whisky 14 YR' 'Arrow Blackraspberry Liqueur'
#  'Sugar Island Rum Coconut' 'Grand Marnier Cordon Rouge Liqueur Mini'
#  'Courvoisier C' 'Firefly Sweet Tea Lemonade' 'Laphroaig Quarter Cask HA'
#  'Skinnygirl Tangerine' 'Canadian Hunter Mini'
#  "Fleischmann's Preferred Whiskey Mini"
#  'Amador Whiskey Bourbon Double Barrel' 'Glenfarclas 105 Scotch'
#  "Pig's Nose Scotch" 'Pulteney 17YR Scotch HA'
#  "Two Jay's Urban Style Light Whiskey"
#  "Russell's Reserve Single Barrel - Barrel" 'Hiram Walker Blue Curacao'
#  'Vat 69 Scotch' 'Tarantula Blue Ready To Drink Margarita'
#  'Curacao Of Curacao Orange' 'Absolut Black 100'
#  'Aguardiente Cristal Liqueur' 'Hangar One Mandarin Flavored Vodka'
#  'Hangar One Buddahs Hand Citron' 'Triple Crown Blended Whiskey'
#  'Old Hickory Black Label Whiskey' 'Tanqueray Gin Mini'
#  'David Nicholson Reserve HA' '1792 Single Barrel HA'
#  'E.H. Taylor Jr. Straight Rye Why. HA'
#  'Glen Moray Scotch 25 YR Portwood HA' 'Glen Garioch Virgin Oak HA'
#  'Laphroaig 25YR Cask Strength HA' 'Yazi'
#  'Amrut Fusion Single Malt Whisy HA' 'Clear Creek Cherry Brandy'
#  'Old Camp Peach Pecan Whiskey' 'Millet Armagnac VS'
#  'Millet Armagnac VSOP' 'Millet Armagnac XO'
#  'Barrell Bourbon Cask Strength' 'Compass Box Oak Cross Whisky'
#  'Rebel Reserve Honey' 'Evan Williams Kentucky Cider'
#  "Uncle Val's Restorative Gin" "Jacquin's Blackberry Brandy"
#  'Bauchant Liqueur' 'Koval Vodka' 'Montelobos' 'Ron Barcelo Anejo'
#  "Burnett's  Blackberry  Flav. Vodka" "Burnett's Mango"
#  'Evan Williams Fire Mini' 'Paramount Rock & Rye'
#  "Mc Master's Canadian Whiskey" 'Bison Ridge Canadian Whisky 8yr'
#  'Old Forester 1870 Whisky Row Series' 'Dekuyper Strawberry Liqueur'
#  'Calico Jack Pineapple' 'Yahara Bay Gin' 'Clear Creek Cherry Brandy Mini'
#  'Jeremiah Weed Sarsparilla Whiskey' 'Barbancourt 3* Rhum 4yr'
#  'Barbancourt 5* Rhum 8yr' 'Kirkland Signature French Vodka'
#  'Montego Bay Coconut Rum' 'Fernet Gancia Liqueur' 'Green Mark Vodka'
#  'Hibiki 12YR HA' 'Clix Vodka HA' 'Laphroaig 10YR Cask Strength HA'
#  'E & J Vsop' 'Crown Royal Vanilla Mini'
#  "Blue Nectar Anejo Founder's Blend" 'Del Maguey Minero'
#  'Dekuyper Sour Apple Pucker Schnapps' 'Dumante Verdenoce'
#  'Rogue Spruce Gin' 'Hornitos Reposado' 'J.w. Dant Scotch'
#  'Calvados Morin Selection 3YR' 'Three Olives Triple Shot Espresso'
#  'Bib & Tucker Small Batch Bourbon Aged 6YR'
#  "Clyde May's Straight Bourbon" 'Salignac VS'
#  'Captain Morgan Jack-O Blast' 'Captain Morgan Jack-O Blast Mini'
#  'Crown Royal w/Alternate Bag' 'Ole Smoky Lemon Drop Moonshine'
#  'I.W. Harper 15YR' 'The Glenlivet Nadurra First Fill'
#  'David Nicholson 1843 HA' 'Badel Williams Pear Brandy'
#  'Artisan Grain Gold Rum' 'Absolut w/Fever Tree Ginger Beer'
#  'Crown Royal w/2 Glasses' 'Cedar Ridge American Whiskey Explorer Pack'
#  'Forbidden Secret Pumpkin Spice Liqueur' 'Malibu Tropical Banana Liqueur'
#  'Georgia Moon Peach Fruit Jar' "Burnett's Pomegranate"
#  'El Mayor Extra Anejo 100% Agave' 'Dr. Blackberry Whiskey'
#  'Evan Williams Egg Nog' 'Ciroc Mango' 'Dr. Blackberry Whiskey Mini'
#  'Dr. Honey Whiskey Mini' 'Dr. Apple Whiskey Mini'
#  'Deep Eddy Straight Vodka' 'Dr. Honey Whiskey' 'Dr. Peach Whiskey'
#  'Christian Brothers Holiday Nog' 'Barton Gold Rum 1.75'
#  'Compass Box Peat Monster Whisky' 'Russian Standard Imperia Vodka'
#  "Russell's Reserve Single Barrel Rye HA" 'Antiguo Anejo'
#  'Antiguo Reposado' 'The Macallan Edition No. 2 HA'
#  'Laphroaig Triple Wood HA' 'Glen Garioch Renaissance HA'
#  'Dekuyper Peachtree Schnapps Minis' 'Ron Abuelo 12YR'
#  'Ron Abuelo Anejo 7YR' 'Bowmore 25YR HA' 'Sugar Island Spiced Rum'
#  'Ilegal Mezcal Anejo' 'SWELL Vodka - Mary Me Bloody Mary Pack'
#  'Ole Smoky Blue Flame Moonshine' 'Ilegal Mezcal Joven'
#  'Ilegal Mezcal Reposado' 'Jim Beam Double Oak in Gift Box'
#  'Crown Royal w/2 Glasses Tray Pack' 'Glenlivet Founders Reserve'
#  'Courvoisier VS' 'Calico Tropical Punch Jack Rum'
#  'The Pogues Irish Whiskey' 'Balvenie 12YR SIngle Barrel'
#  'Pear Necessity Liqueur' 'Fireball Bag in Box' 'Three Olives w/3-50mls'
#  'Crown Royal w/Glass & Coaster'
#  'Jagermeister w/ Mobile Phone Wood Amplifier' 'Drambuie w/2 Glasses'
#  'Disaronno Etro Mignon Counter Unit'
#  'Disaronno Amaretto ETRO w/2 Glasses' 'Midnight Moon Cran-Apple Pie'
#  'Bird Dog Peach w/2 Shot Glasses' 'Bird Dog Apple w/Glass'
#  'Tequila Rose Holiday w/1 Collins Glass' 'Templeton Rye w/Flask'
#  'Pinnacle Candy Cane Trial Pack' 'Jack Daniels w/Glass'
#  'Hpnotiq w/2 Trendy Rock Glasses' 'Jim Beam Black w/2 Glasses'
#  'Kraken Rum w/ Tiki Glass' 'Bols Lychee Liqueur'
#  'Grey Goose w/2 Martini Glasses' 'Ardbeg 10YR Exploration Pack'
#  'Hennessy VS 750ml w/50ml VSOP' 'Hennessy XO w/2 Glasses'
#  'Stolichnaya Premium 80prf w/2 Stemless Martini Glasses'
#  'Barrel Hitch American Whiskey' "Hennessy Master Blender''s Selection"
#  'Ezra Brooks Bourbon Cream' 'Hennessy V.S.O.P Privilege w/2 Glasses'
#  'Paul Masson Grande Amber Brandy VS' 'Forty Creek w/Thermos'
#  'Frangelico w/2 Rocks Glasses' 'Grand Marnier w/2 Shot Glasses'
#  'Deleon Reposado' 'Glenmorangie Original w/ Quinta Ruban & Lasanta'
#  'Saints N Sinners Apple Pie' 'Caol Ila 15YR HA' 'Toschi Lemoncello'
#  'Cragganmore LE HA' 'Lagavulin 25YR HA' 'Linkwood 37YR HA'
#  'Reservoir Bourbon Whiskey' 'Reservoir Wheat Whiskey'
#  'St. George All Purpose Vodka' 'St. George Botanivore Gin'
#  'St. George Bruto Americano' 'St. George California Citrus Vodka'
#  'St. George Dry Rye Gin' 'St. George Green Chile Vodka'
#  'St. George Rapsberry Liqueur' 'St. George Spiced Pear Liqueur'
#  'Belvedere Pure Red w/Shaker' 'Belvedere Pure w/Martini Glass'
#  'Glenmorangie Original w/2 Craftsman Cups'
#  'Atomic Fusion Cinnamon Whiskey' 'Atomic Fusion Spiced Apple Whiskey'
#  "Carolan's Irish Cream w/2 Glasses" 'Kerrygold Irish Cream Liqueur'
#  'Courvoisier Vs Cognac Mini' 'Rogue Dark Rum'
#  'Jeremiah Weed Spiced Whiskey' 'Ardbeg 10YR Quadrant & 50ml Uigeadail'
#  'Kahlua Chili Chocolate' 'Iowa Legendary Rye Aged'
#  'Revel Stoke Rootbeer Mini' 'Yahara Bay American Rye Whiskey'
#  'Libertine Absinthe(french Absinthe)' 'Grappa Moscato'
#  'Atomic Fusion Cinnamon Whiskey Mini' 'Dehner Distillery Vodka Mini'
#  'Cedar Ridge Port Cask Finished Bourbon' 'Revel Stoke Rootbeer'
#  'Smirnoff 1.75L PET w/2-50ml Smirnoff Peppermint'
#  'Cedar Ridge Barrel Proof Bourbon'
#  'Weller Antique Bourbon- Special Barrel' 'Auchroisk 25YR HA'
#  'Glenkinchie 24YR HA' 'Cedar Ridge Malted Rye Barrel Urbandale'
#  'Cedar Ridge Reserve Bourbon Private Cask'
#  'Cedar Ridge Lost Pirate Port Finish Rum'
#  'Paradise Distilling Coconut Bay Liqueur'
#  'Paradise Distilling Mango Bay Liqueur'
#  'Paradise Distilling Raspberry Bay Liqueur'
#  'Templeton Rye 10YR Special Reserve' 'Templeton Rye w/2 Tumbler Glasses'
#  'McCormick Egg Nog w/2 Glasses' 'E.H. Taylor Jr. Barrel Proof HA'
#  'Cluny Blended Scotch Whisky' 'Patron Silver 2.0 2016 Edition'
#  'Dry Dock Sorghurm' 'Hamilton 86 Proof Rum'
#  'Hamilton Jamaican Pot Still Black Rum' 'Rogue Ales Single Malt Vodka'
#  'Rebel Yell 10YR Single Barrel HA' 'Ole Smoky Moonshine - Apple Pie 70'
#  'Double Cask Rye Port Finished' 'Lagavulin 8YR HA'
#  'Cragganmore Distillers Edition HA' 'Hennessy Paradis Imperial 750ML'
#  'Caribou Crossing HA' 'Weller Antique Bourbon HA' 'AO Vodka HA'
#  'Glenkinchie Distillers Edition HA' 'Gibson Finest 12YR Rare'
#  'Sauza Tres Generaciones Reposado' 'Woodford Reserve Rye'
#  'Lord Calvert Hunting Dog Decanter HA' 'Broken Bell Bourbon Whisky'
#  'Widow Jane Straight Bourbon Whiskey' 'Smirnoff Sours Green Apple Mini'
#  'Smirnoff Sours Watermelon Mini' 'Bunnahabhain 12YR' 'Calle 23 Blanco'
#  'Kalani' "Granny's Gingerbread Cream" 'Absolut Citron Mini'
#  'Absolut Raspberri Mini' 'Brooklyn Gin' 'Ledaig 18YR'
#  'Ron Barcelo Gran Platinum' 'Cody Road Double Barrel'
#  '1792 Full Proof HA' 'Talisker Malt Scotch 18YR HA' 'Ardbeg 21YR HA'
#  'Admiral Nelson Black Patch Mini' 'Grappa Di Recioto Amarone50ml'
#  'Violet Liqueur' 'Glenmorangie Taster Pack' 'Benchmark Apple Mini'
#  'Tosolini Cividina Grappa'
#  'FassZination Royal Brackla 1998 18yrs old 750ml'
#  'FassZination Bunnahabhain 1990 26yrs old 750ml'
#  'FassZination Tobermory/Ledaig 1995 21yrs old 750ml' '1792 High Rye HA'
#  'Port Ellen 37YR HA' 'Absolut 1.75L w/Powell & Mahoney Ginger Beer'
#  'Diep9 Young Genever' 'Jean Marc Xo Vodka' 'Bowman Brother Bourbon HA'
#  'Mahon Gin' 'Knob Creek Single Barrel Buy the Barrel' 'Auchentoshan 12yr'
#  'Sazerac 18yr Rye HA' 'William L. Weller Bourbon HA'
#  'Thomas Handy Rye HA' 'George T Stagg Bourbon HA' 'Knob Creek 2001 #4 HA'
#  'Crystal Head Aurora Vodka' 'Eagle Rare 17yr Bourbon HA'
#  'Pearl Coconut Vodka' 'Ultimat Vodka' 'Dubliner Honeycomb Liqueur'
#  'Dubliner Irish Whiskey' '99 Grapes Mini' '99 Peaches Mini'
#  'Midnight Moon Cranberry' 'Bellringer Gin' 'T1Tequila Estalar Anejo'
#  'New Amsterdam Mango Mini' 'New Amsterdam Red Berry Mini'
#  'Paul Masson Apple Grande Amber Brandy Mini']

# %%
listof6 = (y12,y13,y14,y15,y16,y17)
for i in listof6:
    print(i['Category Name'].unique())
# Out:
# ['Cruzan Mango Rum' 'Arrow Peppermint Schnapps' 'Kinky Liqueur'
#  'Bacardi Superior Rum Pet' 'Uv Blue (raspberry) Vodka' 'Crown Royal'
#  'Tanqueray Gin' 'Hiram Walker Pumpkin Spice' 'Calvert Extra Bl Whiskey'
#  'Paramount Gin' 'Captain Morgan Original Spiced' 'Jagermeister Liqueur'
#  'Absolut Ruby Red' 'Jim Beam' 'Absolut Swedish Vodka 80 Prf Mini'
#  'Ten High' "Chi-Chi's Margarita W/tequila" 'Skol Vodka'
#  'Bacardi Superior Rum' 'Hawkeye Vodka 80 Prf Mini'
#  'Captain Morgan Lime Bite' 'Crown Royal Canadian Whisky Mini'
#  'Christian Bros Brandy' 'Fireball Cinnamon Whiskey Mini Dispenser'
#  'Uv Red (cherry) Vodka' 'Paul Masson Grande Amber Brandy'
#  'Mt. Gay Eclipse Rum' 'Bacardi Limon' 'Malibu Pineapple Rum'
#  'Dekuyper Blustery Peppermint Burst Schnapps' 'Scoresby Rare Scotch'
#  'River Pilot Vodka' 'Black Velvet Mini'
#  'Captain Morgan Original Spiced Rum Pet' 'Pinnacle Red Berry'
#  'Jose Cuervo Golden Margarita' 'Juarez Tequila Silver'
#  "Dr. Mcgillicuddy's Cherry Schnapps" "Burnett's Vodka 80 Prf"
#  "Fleischmann's Royal Vodka 80 Prf" 'Pucker Vodka Raspberry Rave'
#  'Kraken Black Spiced Rum' 'Admiral Nelson Coconut Rum'
#  'Paramount Gold Rum' 'Rumple Minze Peppermint Schnapps Liqueur Mini'
#  'Smirnoff Vodka 80 Prf' 'Seagrams 7 Crown Bl Whiskey'
#  "Ryan's Cream Liqueur" 'OR-G' 'Pendleton Canadian Whisky'
#  'Firewater Cinnamon Schnapps' 'Yukon Jack Canadian Liqueur'
#  '1800 Silver Tequila' 'Courvoisier Vs Cognac' 'Smirnoff Vodka Traveller'
#  'Cointreau Liqueur' 'Jack Daniels Old #7 Black Lbl Mini'
#  'Jose Cuervo Especial Reposado Square' 'Hennessy VS'
#  'Kessler Blend Whiskey' 'Ciroc Super Premium Vodka' 'Dekuyper Hot Damn!'
#  'St. Remy Vsop Napoleon Brandy' 'Lady Bligh Spiced Rum'
#  'Red Stag Honey Tea' 'Northern Light' 'Jesse James Bourbon'
#  'Captain Morgan Parrot Bay Orange' 'Mccormick Vodka Pet'
#  'Paramount Peppermint Schnapps' 'Macallan 12 Yr Single Malt Scotch'
#  'Malibu Red' 'Disaronno Amaretto' 'Glenmorangie 10 Yr Single Malt Scotch'
#  'Rondiaz Rum Spiced' 'Bacardi Torched Cherry' 'Dekuyper Sour Apple'
#  'Dekuyper Grape Pucker' 'UV Chocolate Cake Mini'
#  'Christian Bros Brandy-Round' 'Black Velvet Traveler' 'Juarez Triple Sec'
#  "Maker's Mark" 'Hpnotiq Harmonie' 'Drambuie Liqueur'
#  'Mccormick Blend Whiskey, Pet' "Lauder's Scotch"
#  'Popov Vodka 80 Prf Traveler' "Burnett's Grape Vodka" 'Svedka'
#  'Jose Cuervo Especial Reposado Flask' 'Quadro Russian Vodka'
#  "Prichard's Double Barreled" 'Dekuyper Buttershots'
#  'Ice 101, Peppermint Schnapps' 'Tequila Rose Liqueur'
#  'Calico Jack Cherry' 'Sunny Brook Blend Whiskey'
#  'Arrow Spearmint Schnapps' 'E & J Vs' 'El Jimador Silver Tequila'
#  'Dekuyper Luscious Razzmatazz' 'E & J Vsop Superior Reserve'
#  "Myers's Rum Original Dark" 'Dekuyper Buttershots Schnapps'
#  'Captain Morgan Spiced Rum Pet' 'Absolut Citron (lemon Vodka)'
#  'Paramount Apricot Flavored Brandy' 'Southern Comfort Mini'
#  'Godiva White Chocolate Liqueur' 'Ketel One Imported Vodka'
#  'Chivas Regal 12yr' 'Juarez Tequila Gold'
#  'Captain Morgan Parrot Bay Passion Fruit' 'Sazerac Rye'
#  'Benchmark Old No. 8' 'Pama Pomegranate Liqueur' 'McClelland Islay'
#  'Titos Handmade Vodka' 'Smirnoff Vodka 80 Prf Pet'
#  'Tooters Ala Bama Slama' 'Cedar Ridge Bourbon' 'UV Vodka'
#  "Fleischmann's Gin" "Chi-Chi's White Russian" 'Smirnoff Cranberry Vodka'
#  'Jim Beam Mini' 'Jose Cuervo Authentic Lime Margarita'
#  'Seagrams Lime Twisted Gin' 'Ciroc Peach'
#  'Margaritaville Skinny Margarita' 'Skol Vodka Traveler'
#  'Woodford Reserve Bourbon' 'Frangelico Liqueur'
#  'Seagrams 7 Crown Bl Whiskey Mini' "McCormick's Irish Cream"
#  'Wild Turkey American Honey' 'Castillo Silver Rum' 'E & J Cask & Cream'
#  "Bailey's Original Irish Cream" 'Patron Xo Cafe' 'Jim Beam Rye'
#  "Gordon's Gin London Dry - Pet" 'Bulleit 95 Rye' 'Hennessy Vs Cognac'
#  'Wild Turkey 81' 'UV Cake Vodka' '1800 Reposado Tequila'
#  "Gordon's Vodka 80 Prf - Pet" 'Cazadores Anejo' 'Southern Comfort PET'
#  "Dr. Mcgillicuddy's Apple Pie Schnapps" "Dr. Mcgillicuddy's Vanilla"
#  "Lauder's Scotch Traveler" 'Dekuyper Michigan Cherry Liqueur'
#  'Fireball Cinnamon Whiskey' 'Absolut Mandrin' "Beam's 8 Star Bl Whiskey"
#  'Hennessy VSOP Privilege' 'Smirnoff Vanilla Vodka' 'New Amsterdam Vodka'
#  'Hennessy Vs Cognac Minis' 'Pinnacle Tropical Punch'
#  'Paramount Creme De Cacao/dark' 'Little Black Dress Black Cherry Vanilla'
#  'Bushmills Irish Whiskey' 'Grand Marnier Cordon Rouge' 'Barton Gin'
#  'Dekuyper Cherry Pucker Schnapps' 'Boodles British Gin London Dry'
#  'Hiram Walker Cherry Brandy' 'Mr. Boston Rock & Rye'
#  'Windsor Canadian Pet' 'Bombay Dry Gin' 'Knob Creek' 'Bacardi Black Razz'
#  'Canadian Club Whisky' 'Platinum 7x Vodka' 'Tgi Fridays Mudslide'
#  'Seagrams 7 Crown Pet Flask' 'Sailor Jerry Spiced Navy Rum'
#  'Paramount Creme De Menthe/green' 'Jeremiah Weed Sweet Tea Vodka'
#  'Tgif On The Rocks Pina Colada' 'El Mayor Anejo Tequila'
#  'Dekuyper Sour Apple Pucker' 'Absolut Grapevine'
#  'Three Olives Cherry Vodka' 'Glenfiddich 15 Yr Solera Reserva'
#  'Kahlua French Vanilla Liqueur' 'Grand Marnier Cordon Rouge Cherry'
#  'New Amsterdam Gin' 'Uv Blue Raspberry Lemonade Pet' 'Conjure'
#  "Gordon's Vodka 80 Prf" 'Dekuyper Rootbeer' 'Uv Vodka'
#  'Kahlua Coffee Liqueur' 'Admiral Nelson Spiced Rum Traveler'
#  "Jack Daniel's Tennessee Honey" 'Stolichnaya Russian Vodka 80 Prf'
#  'Paramount Amaretto' 'Ketel One Oranje'
#  'Seagrams V.o. Bl Canadian Whisky Pet' 'Phillips Long Island Iced Tea'
#  'George Dickel #12' 'Canadian Mist Whiskey Pet' 'Hiram Walker Triple Sec'
#  'Ten High Traveler' 'Southern Host Whiskey Liqueur'
#  'Phillips Root Beer Schnapps' 'Mc Guires Original Cream Liqueur'
#  'Uv Cake Vodka' 'Skinnygirl Margarita' 'Dekuyper Cactus Juice'
#  'Paramount Triple Sec' 'Berentzen Apple Liqueur' "Five O'clock PET Vodka"
#  'Dekuyper Cactus Juice Schnapps' "Chi-Chi's Long Island Iced Tea"
#  'Beefeater Gin' 'Johnnie Walker Blue' 'Crave Chocolate Cherry'
#  "Fleischmann's Royal Vodka" 'Knob Creek Rye'
#  'Jack Daniels Old #7 Black Lbl Square' 'Pinnacle Whipped'
#  'Smirnoff Whipped Cream Mini' 'Cazadores Reposado' '99 Bananas'
#  'Old Crow' 'El Jimador Reposado Tequila' 'Dewars 12yr' 'Stolichnaya Hot'
#  'Relska Vodka' 'Cruzan Coconut Rum' 'Patron Silver Tequila'
#  'Skyy Infusions Passion Fruit' 'Sobieski Vodka'
#  'Yukon Jack Perma Frost Schnapps' 'Smirnoff Kissed Caramel'
#  'Smirnoff Watermelon Vodka' 'Paramount Peppermint Schnapps Traveler'
#  'Tap 357' 'Jose Cuervo Black Medallion' 'Kahlua Coffee Liqueur Mini'
#  "Salvador's Margarita Pet" 'Smirnoff Vodka 100 Prf' 'Don Julio Reposado'
#  'Margaritaville Classic Lime Margarita'
#  'Jack Daniels Old #7 Black Lbl Flat' 'Canadian Reserve Whisky'
#  'Captain Morgan Spiced Rum Mini' 'Nuvo' 'Southern Comfort 100 Prf'
#  'Dekuyper Luscious Peachtree Schnapps' 'Johnnie Walker Red'
#  'Firefly Sweet Tea Vodka' 'Bacardi Superior Rum Mini'
#  'Arrow Raspberry Schnapps' 'Belvedere Vodka' 'Cruzan Strawberry Rum'
#  'Pinnacle Vodka' 'Paramount Strawberry Schnapps'
#  'New Amsterdam Red Berry' 'Uv Green (apple) Vodka' 'Bombay Sapphire Gin'
#  'Weller Special Reserve Bourbon 7yr HA' 'Johnnie Walker Black'
#  'Di Amore Amaretto' 'Two Fingers Gold Tequila' 'Bacardi Razz'
#  'Jagermeister Cocktail Glass Set' 'Hornitos Plata'
#  'Captain Morgan Tattoo' 'Smirnoff Whipped Cream'
#  'Jose Cuervo Authentic Strawberry Margarita' 'Stolichnaya Sticki'
#  'Uv Pink Lemonade Vodka' '99 Blackberries' 'Dewars White Label Scotch'
#  'Smirnoff Strawberry Vodka' 'Hawkeye Light Rum'
#  'Dekuyper Peachtree Schnapps Traveler' 'El Jimador Anejo Tequila'
#  'G & W Bourbon' 'Dekuyper Raspberry Pucker'
#  'Glenlivet 15 Year French Oak' 'Jameson' 'Juarez Gold Dss'
#  'Copa De Oro Mexican Coffee'
#  'Jose Cuervo Authentic Grapefruit Tangerine Margarita'
#  'Tanqueray Rangpur Gin' 'Jose Cuervo Especial Reposado Tequila Mini'
#  "Chi-Chi's Gold Margarita" '99 Apples' 'Finlandia Imp Vodka 80prf'
#  'Patron Reposado Tequila' 'McCormick Vodka Mini' 'Kah Anejo'
#  'Bombay Sapphire Gin Mini' 'Smirnoff Cherry Vodka'
#  'Ice Hole Mint Schnapps' 'Cabin Still Str Bourbon'
#  'Evan Williams Vintage' "Jack Daniel's Tennessee Honey w/2 Glasses"
#  'Hpnotiq Mini' 'Cutty Sark Scotch' 'Crystal Head Vodka'
#  'Campari Italian Aperitivo' 'Cabo Wabo Reposado' 'Fris Cherry Vodka'
#  'Tortilla Gold Tequila' 'E & J Xo Brandy' 'E & J Vs Brandy Round'
#  'Svedka Clementine Vodka' 'Three Olives Smores'
#  'Three Olives Chocolate Vodka' 'Midori Melon Liqueur'
#  'Evan Williams Yr Str Bourbon' 'Absolut Raspberri'
#  'Grangala Triple Orange Liqueur' "Salvador's Margarita 4pak"
#  'Van Gogh Peanut Butter and Jelly Vodka' 'Korski Vodka'
#  'Dekuyper Peachtree Schnapps Pet' 'Jim Beam Traveler'
#  'Little Black Dress Blueberry Pomegranate' 'Three Olives "dude" Vodka'
#  "Jim Beam Devil's Cut" "Burnett's Pineapple"
#  "Bailey's Hazelnut Irish Cream" "Hendrick's Gin"
#  'Dekuyper Peachtree Schnapps' "Five O'clock" 'Jeremiah Weed Sweet Tea'
#  'Ricacha Horchata' 'Bakon Vodka' 'Paramount Blue Curacao'
#  'Absolut Berri Acai' 'Tgif On The Rocks White Russian'
#  'Paul Masson Vs Brandy Mini' 'Jagermeister Liqueur Mini'
#  'McCormick Gin Pet' 'Pinnacle Strawberry-Kiwi Vodka'
#  'Evan Williams Str Bourbon' '99 Grapes' 'Kessler Blend Whiskey Mini'
#  'Bulleit Bourbon' 'Sauza Blanco Silver' 'Agavero Liqueur'
#  'Admiral Nelson Cherry Spiced Rum' 'Skinnygirl Island Coconut'
#  'Svedka Citron Vodka' 'Arrow Creme de Cacao White'
#  'Dekuyper Melon Liqueur' 'Malibu Passion Fruit Rum'
#  "Bailey's Salted Caramel" 'Laphroaig 10 Yr Single Malt Scotch'
#  'Three Olives Mango Flavored Vodka' 'Ezra Brooks Ky Sour Mash Bourbon'
#  'La Prima Tequila/gold' 'Paramount Creme De Cacao/white'
#  'Bourbon Supreme Bourbon' 'Crown Royal Cask No. 16'
#  'Stolichnaya Premium Vodka 80 Proof (lv)' 'Malibu Island Melon'
#  "Bailey's Coffee Irish Cream" 'Dekuyper Hot Damn! Traveler'
#  'Seagrams Extra Dry Gin Mini'
#  'Jose Cuervo Authentic Light Margarita Lime' 'Absolut Apeach'
#  'Mccormick Blend Whiskey' "Carolan's Irish Cream Liqueur"
#  'Torada Tequila Gold' 'Malibu Black' 'Caffe Lolita Coffee Liqueur'
#  'Clearheart Gin' 'Sauza Tres Generaciones Anejo DNO'
#  'Ezra Brooks 50 Mo Ky Sour Mash Bourbon' 'Mcclelland Highland'
#  'Voli Lyte Vodka' 'Paramount White Rum Traveler' '(ri)1 Rye'
#  'Desert Island Long Island Ice Tea Cocktail' 'Cruzan Raspberry Rum'
#  'Malibu Coconut Rum Mini' 'Cedar Ridge Lemoncella'
#  'Skinnygirl White Peach Margarita' 'St. Charles Brandy'
#  'Absolut Mango Vodka' 'Blair Athol Cask'
#  'Jack Daniels Single Barrel Why.' 'Cruzan Dark Rum' 'Godiva Liqueur'
#  'Smirnoff Fluffed Marshallmallow Mini' 'Dekuyper Hot Damn! 100 Proof'
#  'Bacardi O' 'Barenjager Imp Honey Liqueur' '1800 Coconut'
#  'Phillips White Rum' 'Isle of Jura' 'Uv Orange Vodka'
#  'Romana Sambuca Italian Liquore' 'Presidente Grape Brandy (pedro Domecq)'
#  'Three Olives Berry Vodka' 'Dekuyper Signature Creme De Banana'
#  'Canadian Ltd Whisky Convenience Pack' 'Barton Vodka Pet'
#  'Conjure Cognac' "Gilbey's Gin London Dry" 'Herradura Gold Reposado 6pak'
#  'Popov Vodka 100 Prf' 'La Prima Tequila/white'
#  'Jose Cuervo Tradicional Reposado Tequila' 'Stoli Razberi (raspberry)'
#  'Paramount Creme De Almond' 'Jose Cuervo Mango Margarita'
#  'Bird Dog Blackberry Whiskey' 'Captain Morgan Parrot Bay Mango'
#  'Stock 84 Brandy' 'Citronge' 'Dekuyper Cherry Pucker'
#  'Dekuyper Mixologist Blood Orange' 'Pinnacle Cake Vodka'
#  'Christian Brothers Holiday Nog' 'Evan Williams Cherry Reserve'
#  'Malibu Caribbean Cosmo Cocktail In Bag' 'Dueces Wild Vodka'
#  'Chopin Vodka' 'Lady Bligh Cherry Rum'
#  'Malibu Counter Unit Beach Party Pack' 'Caravella Limoncello'
#  'Jameson 18YR HA' 'Montezuma Blue' 'Clan Macgregor Scotch'
#  'Three Olives Raspberry Vodka' 'Uv Blue Raspberry Vodka Traveller'
#  'Dekuyper Sour Apple Pucker Pet' '1800 Anejo Tequila'
#  "Burnett's Whipped Cream Vodka" 'Evan Williams Egg Nog'
#  '99 Whipped Cream' 'Smirnoff Passion Fruit Vodka'
#  'Malibu Tropical Sea Breeze Cocktail' 'Crown Royal w/2 Glasses'
#  'Paramount Vodka' 'Southern Comfort Lime' 'Appleton Signature Blend'
#  'Tortilla Triple Sec' 'Cabo Wabo Blanco' 'Bacardi Grand Melon Rum'
#  'Solerno Blood Orange Liqueur' 'Rumchata Mini' 'Kapali Coffee Liqueur'
#  'Calico Jack Coconut' 'Famous Grouse Scotch' 'Canadian Club Whisky Pet'
#  "Seagram's Orange Twisted Gin" 'Cedar Ridge Dark Rum'
#  'Tooters Apple-Tini Mini' 'Cody Road Rye' 'Uv Citruv (citrus) Vodka'
#  "Blanton's Sing Barrel Bourbon 6pak" "Buchanan's 12 Yr Deluxe Scotch"
#  'Sauza Conmemorativo' 'Stolichnaya Razberi Vodka 75 Proof'
#  "Burnett's Blue Raspberry Vodka" 'Glenfiddich 12yr Special Reserve'
#  'UV Whipped' 'Smirnoff Citrus Vodka' '360 Double Chocolate Vodka'
#  'Uv Blue Raspberry Vodka Mini' 'Singleton Single Malt Scotch'
#  'Dekuyper Triple Sec' 'Ciroc Luxury Vodka' 'Hangar One Mandarine Vodka'
#  "Jack Daniel's Tennessee Honey Mini" 'Early Times 36 Mo Ky Str Bourbon'
#  'Pinnacle Atomic Hots Mini' 'Old Crow Traveler' 'Martell Vs'
#  'Margaritaville Last Mango Margarita' 'Smirnoff Kissed Caramel Mini'
#  'Rich & Rare Canadian Whisky' 'Uv Pink Lemonade Cocktail Pet'
#  'Travis Hasse Apple Pie Liqueur' 'Lucid Absinthe' 'Kah Reposado'
#  'Patron Anejo w/Crystal Bees' 'Windsor Canadian Traveler'
#  'Smirnoff Iced Cake' 'Ciroc Coconut' "Chi-Chi's Mexican Mudslide"
#  'Absolut Wild Tea' 'Ridgemont Reserve 1792' 'Jim Beam Black'
#  "Griff's Cowboy Whiskey" 'Admiral Nelson Spiced Rum Mini'
#  'Clearheart Vodka' 'Captain Morgan Parrot Bay Coconut'
#  'Rumple Minze Peppermint Mini' 'River Rose Gin'
#  'Balvenie 12yr Doublewood Single Malt Scotch'
#  'Canadian Club Dock 57 Blackberry' 'Kahlua Especial'
#  'E & J Vs Brandy Travelers' 'Pinnacle Atomic Hot' 'Jagermeister w/Flask'
#  'Familia Camarena Reposado' 'Jagermeister w/2 Shot Glasses' 'Effen Vodka'
#  'El Zarco Gold' 'UV Whipped Mini' 'Blackheart w/Tumbler'
#  'Smirnoff Fluffed Marshmallow' 'Pucker Vodka Lemonade Lust'
#  'Emmets Irish Cream Liqueur' 'Grey Goose Multi Pack'
#  'X Rated Fusion Liqueur' "Burnett's Limeade Vodka"
#  'Club Cocktails Brass Monkey' 'Don Julio 70th Anniversary'
#  'Dt Lonach Glendarroch 1966 42yr' "Grey Goose Vodka L'orange"
#  'Whitetail Caramel Flavored Whiskey' 'Three Olives Cake Flavored Vodka'
#  'Jose Cuervo Especial Silver' 'Christian Bros Honey'
#  'Blackheart Premium Spiced Rum' 'Middle Sister Cranberry Cosmo'
#  "Bailey's Original Irish Cream Minis" 'Avion Anejo'
#  "Burnett's Fruit Punch" 'Tuaca Perfect Chill' 'Ty Ku Super Premium Soju'
#  'Dalwhinnie 15 Yr Single Malt Scotch'
#  'Southern Comfort Bold Black Cherry Mini' 'Cabrito Reposado'
#  'Redbreast Irish Whiskey' 'Bacardi Multi-Flavor Mini 6 Pack'
#  'Paramount Anisette' 'Three Olives Rangtang' 'Midnight Moon Apple Pie'
#  'Ice Box Mudslide' 'Dekuyper Blackberry Brandy'
#  "Dr. Mcgillicuddy's Lemon Drop" 'Chambord Flavored Vodka' 'Pearl Vodka'
#  'Svedka Cherry Vodka' 'Pinnacle Orange Whipped'
#  'Dekuyper Island Punch Pucker' 'Malibu Melon Margarita Cocktail'
#  'Pearl Caramel Vodka' 'House Of Stuart' 'Jeremiah Weed Sweet Tea Mini'
#  'Malibu Mango Rum' 'Three Olives Pomegranate Vodka' 'Purple Passion'
#  'Kah Blanco Mini' 'Absolut Miami' "Fulton''s Harvest Pumpkin Liqueur"
#  'Absolut Vodka 100 Premium' 'Bacardi Arctic Grape Liqueur'
#  'Ursus Punch Flavored Vodka' '1800 Ultimate Blueberry RTD'
#  'Stolichnaya Chocolat Kokonut' 'Kah Anejo Mini'
#  'Early Times 36 Mo Ky Str Bourbon Pet' 'Absente w/Glass & Spoon'
#  'Pinnacle Cotton Vodka' 'Pearl Orange Vodka'
#  'Evan Williams Cinnamon Reserve Mini' "Wiser's Legacy"
#  'La Prima Triple Sec' '1800 Coconut Mini' 'E & J Vs Brandy Square'
#  'Pinnacle Red Liquorice' 'Bastille Hand Crafted Whisky'
#  'Malibu Sunshine PET Mini' 'Breakout Rye Whiskey'
#  "Gilbey's Gin London Dry Traveler" 'Bacardi Cocktails Pina Colada'
#  "Jack Daniel's w/Billboard" 'Van Gogh Double Expresso Vodka'
#  'Jagermeister Celebration Bucket' 'Pearl Blueberry Vodka'
#  "Fleischmann's Preferred Bl Whiskey"
#  'Dekuyper Luscious Pomegranate Pleasure Liq' 'Cruzan Light Rum'
#  'Skinnygirl Cucumber' 'Chila Coffee Liqueur' 'Absente'
#  'Jose Cuervo Authentic Pomegranate Margarita' 'Old Smuggler Scotch Pet'
#  "Salvador's Premium Margarita" 'Smirnoff Pomegranate Vodka'
#  'Crystal Head w/Martini Glass' "Burnett's Strawberry"
#  'Canadian Hunter Traveler Camo' 'Shellback Spiced' '99 Bananas Mini'
#  'Absolut Mini Bar' 'Sauza Cien Anos Reposado Tequila'
#  'Tatler Scotch Liqueur' 'Evan Williams Black Label' 'Capel Pisco Premium'
#  'Gran Centenario Plata' 'Bacardi Rock Coconut'
#  'Dekuyper Washington Apple' "Dr. McGillicuddy's Cherry Dispenser"
#  'Knob Creek Single Barrel Reserve' "Two Jay's Country Style Blended Why."
#  'Dekuyper Mixed Berry Medley' 'Cody Road Bourbon' 'Chila Orchata'
#  'Paul Masson Vsop Grande Amber Brandy' 'Stolichnaya Salted Karamel'
#  'Amaretto E Dolce' 'Dekuyper Sour Apple Pucker Traveler'
#  'Skinnygirl Tangerine' 'Ardbeg 10 Yr Islay Single Malt Scotch'
#  'Forbidden Secret Dark Mocha' 'Stolichnaya Chocolat Razberi'
#  "Jack Daniel's Independence w/2 Glasses"
#  "Bailey's Mint Chocolate Irish Cream" "Russell's Reserve 10YR"
#  'Voli Lemon Vodka' 'Veev Acai' 'Jeremiah Weed 100prf Bourbon Liqueur'
#  'Smirnoff Tuscan Lemonade' 'Licor 43' 'Cupcake Vodka Frosting'
#  'Pearl Peach' 'Phillips Hot 100 Cinnamon Schnapps'
#  'Midnight Moon Blackberry' 'Auchentoshan Classic' 'Powers Irish Whiskey'
#  'Glenlivet 16yr Nadurra' 'Hiram Walker Peach Schnapps'
#  'Tortilla Gold Dss' 'Lulu B Margarita'
#  'Bacardi Classic Cocktails Strawberry Daiquiri'
#  'Pucker Vodka Grape Gone Wild' 'Pearl Wedding Cake Vodka Mini'
#  'Dekuyper Tropical Coconut' 'Admiral Nelson Spiced Rum 70'
#  'Johnnie Walker Double Black' 'Dekuyper Hot Damn! Pet'
#  'McClelland Speyside Scotch' 'Red State Bourbon'
#  'Phillips Blackberry Flav Brandy' 'Southern Comfort Fiery Pepper'
#  'Christian Bros Brandy-Square'
#  '1800 Silver w/1800 Coconut 50ml & Pineapple Juice'
#  "Burnett's Candy Cane" 'Russian Standard Platinum Vodka'
#  'Titos Handmade Mini' 'McCormick Irish Cream w/2 Glasses' 'Holstein'
#  "Laird's Applejack" 'Skyy Infusions Dragon Fruit'
#  'Agavero Orange Tequila Liqueur' 'Absolut Citron' 'Cabrito Blanco'
#  "Fuzzy's Ultra Premium Vodka" 'Queen Bee Honey Whiskey'
#  '360 Madagascar Vanilla Vodka' 'Christian Bros Brandy Traveler'
#  'Three Olives Vanilla Vodka' 'Smirnoff Iced Cake Mini'
#  'Homestead American Whiskey' 'Crave Chocolate Chili'
#  'Three Olives w/Cholula' 'Skyy Infusions Pineapple'
#  'Cedar Ridge Lamponcella' 'Old Overholt Str Rye Whiskey'
#  'Sauza 901 Silver' 'Amaretto Di Amore w/2 Snifters'
#  'Kahlua Peppermint Mocha' 'XO Cafe Dark Cocoa' 'Nocello Walnut Liqueur'
#  "Dr. McGillicuddy's Apple Pie Mini" 'Canadian Club Dock 57 Mini'
#  'Belvedere Bloody Mary' 'Chartreuse Green French Liqueur'
#  'El Mayor Blanco' 'Svedka Colada' 'Spicebox Canadian Spiced Whisky'
#  'New Amsterdam Red Berry Mini' 'Hiram Walker Caramel Apple'
#  'Hiram Walker Peppermint Schnapps Sportsman Pack' 'Kahlua Hazelnut'
#  'Galliano Liqueur' 'Lulu B Chocolate Martini'
#  'Pucker Vodka Sour Apple Sass' 'Rich & Rare Reserve' 'Pinnacle Gin'
#  '1800 Ultimate Pomegranate Margarita' 'Captain Morgan Spiced Barrel'
#  'Courvoisier Rose' 'Margaritaville Dark Jamaican Rum'
#  'Hennessy Vsop Privilege Cognac' 'Baileys Mudslide' "Mc Gregor's Scotch"
#  'King Solly White Grape Vodka Mini' 'Clearheart Rum' 'Brugal Anejo Rum'
#  'Pinnacle Pumpkin Pie' 'Absolut Cherrykran' 'Barton Long Island Iced Tea'
#  'Svedka Raspberry Vodka' 'Pinnacle Cookie Dough'
#  'E & J Vs Grand Amber Brandy' 'Heaven Hill Old Style Green 90'
#  "Thatcher's Cucumber" 'Crave Chocolate Mint' 'Svedka Grape Vodka'
#  'Ice Hole Cherry Schnapps' 'Jose Cuervo Especial Max Pack'
#  'Absolut Grapevine Mini' 'Prairie Organic Vodka' 'Pearl Red Berry Vodka'
#  'Svedka Vanilla Vodka' "Jack Daniel's Black w/2 Glasses"
#  '360 Buttered Popcorn Mini' "Bailey's Original Irish Cream w/2 Glasses"
#  'New Amsterdam Vodka Mini' 'New Amsterdam Peach Mini' 'Kahlua Tin'
#  "Wiser's Deluxe" 'Label 5' 'Smirnoff Pomegranate Martini'
#  "Burnett's Sugar Cookie" 'Grand Muriel Orange Liqueur' 'Old Overholt Rye'
#  'Bowmore 12 Yr Single Malt Scotch' '360 Huckleberry Mini'
#  'Calypso Coconut Rum' 'Ursus Blue Raspberry Vodka'
#  "Broker's London Dry Gin" 'Margaritaville Skinny Island Punch'
#  "Carolan's Irish Cream w/2 Bowls" 'Iowa Coffee Company Liqueur'
#  'Absolut Unique' '360 Georgia Peach Vodka Mini' 'Pinnacle Peach'
#  'Amarula Fruit Cream Liqueur' 'Van Gogh Dutch Caramel Vodka'
#  'Kahlua Midnight' 'Purple Passion 4 Pack'
#  'Russian Standard Original Vodka' 'Montego Bay Coconut Rum'
#  'Paramount Whipt Creme Vodka' 'Seagrams Sweet Tea'
#  'Malibu Cranberry Cherry Mini' 'Castillo Spiced Rum' 'Bols Triple Sec'
#  'Cedar Ridge Unaged Whiskey' '360 Red Raspberry Mini'
#  "Jack Daniel's SB Ducks Unlimited w/Btl Stopper"
#  'Phillips Root Beer Schnapps 100 Proof' 'Jeremiah Weed Cherry Mash'
#  'Bacardi Classic Cocktails Mojito'
#  'Sam Houston American Straight Whiskey' 'Pearl Vodka PET'
#  'Pucker Vodka Citrus Squeeze' 'Ole Smoky Cherry Moonshine'
#  'McCormick Gin' 'Skyy Infusions Blood Orange'
#  'Herradura Blanco Silver 80 Prf Tequila' '360 Georgia Peach Vodka'
#  'Rogue Dark Rum' "Burnett's Watermelon" 'Smirnoff Coconut' 'Avion Silver'
#  'Kah Reposado Mini' 'Kahlua Cinnamon Spice' 'Cabo Wabo Anejo'
#  "Dewar's White Label Scotch" 'Sharkwater DNO' '360 Glazed Donut Mini'
#  'Rebel Yell Bourbon' 'St. Germain .750ml' '360 Concord Grape Vodka'
#  'Pyrat Xo Reserve' 'Effen Cucumber' 'Appleton Special Jamaica Rum'
#  'Corazon de Agave Tequila Blanco' 'Tequila Rose w/2 Shot Glasses'
#  'Patron Reposado Citronage Summer Pack' 'Bushmills 10yr Malt Irish'
#  'Hardy VS Cognac' 'Sauza Blue Reposado' 'Barton Long Island Ice Tea'
#  'Mr. Boston Egg Nog' '360 Double Chocolate w/Gravity Unit'
#  'Old Forester Bourbon' 'Hawkeye Cherry' 'Seagrams Extra Dry Gin Pet'
#  'Evan Williams Kentucky Cider' 'E & J Chocolate Temptation'
#  'Absolut Kurant' "Burnett's Sugar Cookie Mini" 'Lady Bligh Mango Rum'
#  "Seagram's Pineapple Twisted" 'Shellback Spiced Mini'
#  'Pinnacle Pineapple' 'Pride of the Wapsi' "Burnett's Hot Cinnamon"
#  'Benedictine Liqueur Dom' 'Bushmills 16yr Malt Irish'
#  "Prichard's Sweet Lucy" 'Cedar Ridge Grappa'
#  'Leroux Jeznowka Polish Blackberry Brandy' 'Midleton Rare HA'
#  'Hennessy VS Artistry by KAWS' 'Aperol'
#  'Woodford Reserve Kentucky Derby 2015' "Mcmaster's Canadian"
#  'Luxardo Limoncello Frosted' 'Forty Creek Barrel Select' 'Citadelle Gin'
#  '360 Concord Grape Vodka Mini' '360 Red Raspberry'
#  'Absolut Zing Zang Bloody Mary Mix'
#  'Georgia Moon Corn Wsky Fruit Jar 80prf' 'Smirnoff Savannah Tea'
#  'Margaritaville Silver Tequila' 'Nut Chocolate' 'Glenrothes 1998'
#  'Irish Single Malt Whiskey' 'Sauza Tres Generaciones Plata'
#  'Marie Brizard Chocolat Royal' 'Wild Rose Liqueur' 'Sobieski w/Flask'
#  'Tres Leches Cream Liqueur' 'Southern Comfort Hurricane Rtp'
#  'Glenmorangie Original 10YR w/Glasses' 'Firefly Skinny Tea'
#  'Kahlua Gingerbread' "Maker's Mark Recipe and Glasses"
#  'Jose Cuervo Tradicional Silver' 'Becherovka Liqueur'
#  'Rogue Hazelnut Spice Rum' 'Three Olives Supercola Flavored Vodka'
#  'Dekuyper Peach Pucker Schnapps' 'Grappa Di Recioto Amarone'
#  'Ke Ke Beach Plastic' 'Clynelish Scotch DNO' 'English Harbour Rum 5yr'
#  'Sauza Blue Silver' 'Ole Smoky Original Corn Moonshine'
#  'Midnight Moon Cherry' 'Don Q Coconut Rum' 'Malibu Red PET Mini'
#  'Alize Gold' 'Hiram Walker Whipped Cream Mini'
#  'Patron XO Cafe w/ Dark Cocoa Tower' 'Canadian Mac Naughton Whiskey'
#  "Bailey's Hazelnut Irish Cream Mini" 'Pearl Plum Vodka'
#  'Jinro Classic Soju' 'Southern Comfort And Lime'
#  'Jameson Irish Whiskey Tin' 'Cedar Ridge Brandy' 'New Amsterdam Mini'
#  'Early Times Bourbon Square' 'Rondiaz Mini'
#  'Chambord Liqueur with 2 Ice Cream Bowls' 'Godiva Chocolate Vodka'
#  "Pernod D'absinthe" 'Iowa Shine' 'Corazon De Agave Anejo Tequila'
#  'Armagnac XO 10 YR' 'Tarantula Plata 100' 'Smirnoff Melon Vodka'
#  'Sabroso' 'Paramount Sour Apple Schnapps' 'Dekuyper Coffee Brandy'
#  'Evan Williams Peppermint Chocolate Egg Nog' 'Crown Royal Maple Mini'
#  "Burnett's Maple Syrup" 'Skinnygirl Margarita Mini'
#  'Windmill Rye Whiskey' 'Hiram Walker Triple Sec 30prf' 'Cruzan Orange'
#  'Woodford Reserve Double Oaked' 'Junior Johnson Cherry(do Not Use)'
#  'Italian Brandy' 'Kahlua Sampler Pack' 'Jim Beam White Triage'
#  'Cabana Bay Wild Cherry Rum' 'Spicebox Canadian Cinnamon Whisky'
#  'Schladerer Williams Birne' 'Canadian Regency Light'
#  'Remy Martin Vsop .100ml' 'Middle Sister Margarita' 'Luxardo Maraschino'
#  'Captain Morgan Spiced 100proof Minis' 'Reyka Vodka'
#  'Alize Red Passion  DNO' 'Rogue Single Malt Whiskey'
#  'Rogue Dead Guy Whiskey' "British Navy Pusser's Rum 84 Prf"
#  'Dry Fly Wheat Whiskey' 'Laphroaig' 'Howdys Apple Pie'
#  'Di Amore Quattro Orange' 'Midnight Moon Blueberry'
#  'Cedar Ridge Mangocella' 'Crown Royal Cask 16(DNO)' 'Nuvo Lemon Sorbet'
#  'Yahara Bay Gin' 'Irish Peated Single Malt Whiskey' 'Chopin Rye Vodka'
#  'Kammer Williams Pear Brandy W/pear' 'Hiram Walker Crm De Banana'
#  'J.w. Dant Scotch' '360 Madagascar Vanilla Vodka Mini'
#  'Glenmorangie Taster Pack' 'Old Rip Van Winkle 20yr(pappy) HA'
#  "Jefferson's Presidential Select 18yr" 'Toschi Lemoncello'
#  'Latte Machiatto' 'Adult Limeade' "Seagram's Distillers Reserve Gin"
#  'Fernet Branca' 'E.H. Taylor Jr. Straight Rye Whiskey'
#  'Knob Creek Bourbon' 'Stroh 160 Rum' "Jim Beam's Choice 5 Yr"
#  'Canadian Club Classic 12yr' 'Paddy Old Irish Whiskey'
#  'Hiram Walker Crm D Cacao White' 'Dubouchett Blackberry Brandy'
#  "Bartender's I'm Bananas Over U" 'Clontarf Classic Blend Irish'
#  'Smirnoff Twist Of Cranberry' 'Rokk Vodka' 'Hunters Herbal Liqueur'
#  'Armagnac XO 25yr' 'Auchentoshan Three Wood Sing Malt Scotch'
#  'Maestro Dobel Diamond Tequila(dno)' 'Junipero Gin'
#  'Knappogue Castle 12yr' 'Bols Apricot Brandy' 'Vat 69 Scotch'
#  'Square One Botanical' 'Edradour 10yr Sing Malt Scotch'
#  'Four Roses Small Batch' 'The Glenlivet Archive 21YR Sing Malt HA'
#  'Old Weller 107 Antique Bourbon 7yr HA' 'Don Eduardo Silver Tequila'
#  'Oban 18yo Scotch' 'Calvados' "Busnel Calvados Pays D'auge Vsop"
#  "Wiser's Deluxe Canadian" 'Trave Amaretto' 'Van Gogh Pineapple Vodka'
#  'Karimba Coffee Liqueur' 'Hudson Baby Bourbon' 'Malibu Winter Edition'
#  'Hiram Walker Pomegranate Schnapps' 'Zambello Red Sambuca'
#  'Kauai Dark Hawaiian Rum' 'Skyy Infusions Cherry'
#  'Glenmorangie Signet HA' 'UV Cake' 'Black Maple Hill Small Batch DNO'
#  'Ramazzotti Amaro' 'Finlandia Vodka 80 Proof' 'Alize Red Passion'
#  "Mc Master's Canadian Whiskey" 'Metaxa 7 Star' 'Kirsch Cherry Brandy'
#  '100 Anos Azul 100% Agave' 'Glengoyne 10yr Scotch'
#  "Ballantine's Scotch Finest" 'Caravella Orangecello' "Burnett's Pear"
#  'Hangar One Chipotle Vodka' "Two Jay's Grappa"
#  'DiSaronno Amaretto Glass Pack' 'Maraska Slivovitz'
#  'Limonce Lemon Liqueur' 'Leroux Blackberry Brandy'
#  'Hine Rare Vsop Cognac' 'Weller 12yr Bourbon HA'
#  'Slieve Foy Irish Whiskey' 'Stolichnaya Citros'
#  'Marie Brizard Watermelon' 'Crown Royal Tri Pack' 'Glengoyne'
#  'Hiram Walker Black Raspberry' 'Old Forester 4yr 86prf Bourbon'
#  'Stolichnaya Cranberi Vodka DNO' 'Rock Hill Farms Bourbon HA'
#  'Hennessy XO' 'Cruzan 151 Rum' 'Aberfeldy 12 Year Single Malt Scotch'
#  'El Tesoro Anejo Tequila' 'Catdaddy Carolina Moonshine'
#  'Yahara Bay Apple Crisp(Apple Pie)' 'Ardmore Scotch'
#  "Seagram's Distiller's Reserve Gin" 'Pinnacle Blueberry Vodka'
#  "St Brendan's Irish Cream" 'Boodles British Gin' 'Tarantula Azul Co Pack'
#  'Henry Mckenna Single Barrel 10YR 100prf' 'Glenmorangie 18yr HA'
#  'Ardbeg Corryvreckan' 'Tequila Avion Counter Unit'
#  'Hangar One Fraser River Raspberry Vodka' 'Bacardi Big Apple Rum'
#  'Jts Brown Bourbon' 'Pallini Lemoncello' "Wiser's 18 Year Old"
#  'Van Gogh Acai Blueberry Vodka' 'Grappa Moscato 200ml' 'Grappa Nebbiolo'
#  'Balvenie Portwood 21yr Scotch HA'
#  'Jose Cuervo Platino Reserva De La Familia' 'Smirnoff Citrus Twist'
#  'Glenfarclas 105 6pak Sing Malt Scotch'
#  'Breckenridge Bourbon(do Not Use)' 'Stirrings Peach Liqueur'
#  'Dekuyper Vanilla' 'Hiram Walker Crm De Menthe Green'
#  'Yahara Bay Apple Brandy' 'Teton Glacier Potato Vodka'
#  'Jinro Chamisul Soju' 'Larressingle Vsop Armagnac Vsop'
#  'Jose Cuervo Reserva De La Familia' 'Four Roses Yellow'
#  'Scapa 16yr Sing Malt Scotch' 'Margaritaville Island Lime'
#  'Fernandez Brandy de Jerez' 'Don Julio Reposado Mini'
#  'Macallan Cask Strength Scotch DNO' 'Smirnoff Raspberry'
#  'Shango Rum Liqueur' "Seagram's Lime Twisted Gin" 'Stolichnaya Vanil'
#  "Laird's Old Apple Brandy 7yr" 'Absolut Vodka Glimmer'
#  'Three Olives Watermelon Vodka' 'Pisco Porton'
#  'Hiram Walker Whipped Cream' 'Yahara Bay Lemoncello'
#  'Mr. Boston Light Rum' 'Three Olives Citrus' 'Cazadores Blanco'
#  'Millars Special Reserve' 'Mr Boston Sloe Gin'
#  'Evan Williams Honey Shotglass Mold' 'Concannon Irish Whiskey'
#  'Dekuyper Cranberry Schnapps' "O'dowd's Pumpkin Spice"
#  'Phillips Black 100 Herbal Schnapps' 'Thomas Handy Rye HA'
#  'Azunia Platinum(white)' 'J.w. Dant 100 Prf Bond Bourbon'
#  'Yahara Bay Apple Crisp(apple pie)' 'Pitu Cachaca' 'Don Eduardo Reposado'
#  'Ciroc' 'Trimbach Mirabelle Brandy' 'Tanqueray Sterling Vodka'
#  'Glenfarclas 21yr' 'Kah Extra Anejo' "Burnett's Orange Cream Vodka"
#  'Arrow Sloe Gin' 'Strega Liquore' "Burnett's Vanilla"
#  'Hangar One Kaffir Lime Vodka' 'Sambuca Di Amore' 'Plymouth Sloe Gin'
#  'Hudson Four Grain' 'One Barrel Rum' 'Malibu Tropical Banana Liqueur'
#  'Cynar 33prf' 'Bols Blue Curacao' 'Berentzen Pear Liqueur'
#  'Tia Maria Coffee Liqueur' 'Pearl Citrus Vodka'
#  "Seagram's Grape Twisted Gin" "Jack Daniel's Black Tin"
# ...
#  'Corazon De Agave Blanco' 'Corazon De Agave Reposado'
#  'Giffard Creme de Pamplemousse Rose Pink Grapefruit Liqueur'
#  'Giffard Creme De Violette Violet Liqueur' 'Kelt VSOP' 'Meukow Vs'
#  'Pinnacle Blackberry' 'Big Peach Liqueur' 'Queen Jennie Sorghum Whiskey'
#  'Highland Park Dark Origins' 'Ancnoc Blas Scotch' 'Siete Leguas Anejo'
#  'Helix Vodka' 'McCormick Apple Vodka' 'Firefly Peach Moonshine'
#  'Glenfarclas 25yr Sing Malt' 'HA Elijah Craig 18YR Single Barrel'
#  'McCormick Peach Vodka' 'HA Bernheim Original Wheat Whiskey'
#  'HA Johnnie Walker Odyssey'
#  'HA Johnnie Walker Private Collection 2014 Smoke'
#  'HA Highland Park Valkyrie' 'HA Rebel Yell 10YR Single Barrel'
#  'Tequila Rose Pet' 'Hennessy VSOP Privilege Flask'
#  'Charbay Green Tea Vodka' 'Piping Rock Peppermint Schnapps'
#  'Tarantula Azul' 'Hennessy VS Luminous' 'Dewars w/2 Glasses'
#  'Caliber Spiced Rum' 'Caliber Silver Rum' 'Holy Hell'
#  'Caliber Canadian Whiskey' 'Caliber Vodka'
#  'Plantation Rhum Grand Reserve 5 Year' 'Caliber Citrus Vodka'
#  'Calvados Morin "Selection"' 'Wild Turkey American Honey w/Pitcher'
#  'Caliber Triple Sec' 'Caliber Butterscotch' 'Caliber Peach Schnapps'
#  'Caliber Sour Apple Schnapps' 'Zyr Vodka' 'Weller Reserve Barrel Program'
#  'Jim Beam Vanilla Mini' 'HA Weller 12YR' 'HA Elmer T Lee Single Barrel'
#  'HA Stagg Jr' 'Metcalfes Vermont Maple Cream' 'Oxley Dry Gin'
#  'Single Malt OPX Single Barrel Barrel Program'
#  'St. George Green Chile Vodka' 'Corzo Silver Tequila'
#  'Bacardi Anejo Mex Rum' 'Bruichladdich PC Scottish Barley'
#  'Cruzan Guava Rum' 'Black Maple Hill Oregon Straight Bourbon'
#  'Copper Cross Hybrid Whiskey' 'Varan Coffee Mezcal Liqueur'
#  "Fleischmann's Gin Mini" 'Burnetts Coconut  Vodka'
#  'Hennessy VS JonOne LE' 'Bartenders Strawberry Tequila'
#  'Balvenie 15yr Sherry Cask' "Jefferson's The Manhattan Barrel Finish"
#  "Moletto Distillato D'uva Grappa" 'Phillips Butterscotch Schnapps'
#  'Duke Bourbon Whiskey' 'Giffard Lichi Li' 'Giffard Creme de Mure'
#  'JM VSOP' 'Dewars w/Glass & Ice Mold' 'Novo Fogo Silver Cacha�a'
#  'Gibson Finest 12YR' 'Pillar 136 Gin' 'SD Strong Vodka'
#  'Flor De Cana 12yr Centenario' 'Santo Puro Mezquila' 'Herradura Reposado'
#  'Old Camp Whiskey' 'Moonshine 200ml' 'Blueberry Valentino 200ml'
#  'Framboise (Raspberry Liqueur)' 'Moonshine 1 liter'
#  'Moonshine 750ml fenice' 'Moonshine 375ml Pilar' 'Moonshine 100ml'
#  'Moonshine 50ml' 'Amrita Indian Whiskey 1 Liter'
#  'Amrita Indian Whiskey 750ml Fenice' 'Amrita Indian Whiskey 375ml Pilar'
#  'Amrita Indian Whiskey 200ml' 'Amrita Indian Whiskey 100ml'
#  'Amrita Indian Whiskey 50ml' 'Old Forester 1920'
#  '360 Mandarin Orange Vodka' "Russell's Reserve 6 year Rye"
#  'Jose Cuervo Especial Silver/Flask' 'Jose Cuervo Especial Gold /Flask'
#  'Hangar One Mandarin Flavored Vodka' 'Solana Agave Blanco Tequila'
#  'Adelaides Caramel Mocha Mojo'
#  'Hyde 10YR Irish Whiskey Oloroso Sherry Finish'
#  'Hyde Irish Whiskey 6YR Bourbon Finish Cask' 'Ron Abuelo Anejo 7YR'
#  'Adelaides Caramel Mocha Mojo Mini' 'Adelaides Coconut Liqueur'
#  'Adelaides Coconut Liqueur Mini' 'FrappaChata Iced Coffee Blend'
#  'HA Glenfiddich Experiment 1 India Pale Ale Cask'
#  'Seagrams Extra Smooth Vodka Mini' 'Seagrams Juicy Watermelon Vodka Mini'
#  'Van Gogh Espresso Vodka' 'Hiram Walker Blue Curacao'
#  'Agwa Herbal Liqueur' 'Kavalan Concertmaster' 'Cruzan Single Barrel Rum'
#  'Bird Dog Kentucky Bourbon' 'Kauai Coconut Hawaiian Rum'
#  'Hennessy VS Flask' 'Admiral Nelson Pineapple' 'No. 3 London Dry Gin'
#  'Dr Grape Mini' 'Hiram Walker Creme De Menthe White'
#  'Kentucky Gentleman Bourbon' 'Ransom Old Tom Gin' 'John Barr Reserve'
#  'El Mayor Anejo Barrel Program' 'Jim Beam Red Stag Black Cherry'
#  'El Mayor Reposado Barrel Program' "Aberlour A''bunadh"
#  'Elijah Craig 9YR Barrel Program #5126005 -2561'
#  'Orphan Girl Bourbon Cream Liqueur' 'Pearl Blueberry Mini'
#  'Pearl Peach Mini' 'Mt Gay Silver Rum' 'Pinnacle Strawberry'
#  'Pinnacle Citrus' 'Pinnacle Cherry' "Charles Baur Fine d'Alsace"
#  'Kings County Distillery Straight Bourbon Whiskey'
#  'Aha Yeto Anejo Tequila' 'Mr Boston Five Star Brandy'
#  'El Mayor Extra Anejo 100% Agave' 'Ty Ku Citrus Premium Liqueur'
#  'DeKuyper Mixologist Blood Orange' 'RumHaven' 'Larceny' '99 Coconut Mini'
#  'Woodford Reserve Straight Bourbon' 'Giffard Vanille de Madagascar'
#  'Giffard Banane du Bresil' 'Kirkland Signature Tequila Anejo'
#  'Brokers Gin Mini' 'Trave Amaretto' 'Calico Jack Pineapple'
#  'Orange Liqueur' 'Three Olives Triple Shot Espresso'
#  'Revel Stoke Root Beer Mini' 'Sauza Tres Generaciones Plata'
#  'SKYY Infusions Pacific Blueberry' "Uncle Bob''s Root Beer Whiskey"
#  'Georgia Moon Peach Fruit Jar' 'Admiral Nelson Vanilla Rum'
#  'HA Grand Marnier Centenaire (100)'
#  'Seagrams Extra Smooth Vodka 1.75L w/Juicy Watermelon 50ml'
#  'Macchu Pisco' 'La Diablada Pisco' 'Admiral Nelson Vanilla'
#  'UV Blue Raspberry' 'New Amsterdam Lemon' 'New Amsterdam Raspberry'
#  'Smirnoff Sourced Watermelon Mini' 'Revel Stoke Spiced Whisky'
#  'Margaritaville Gold Tequila Mini' 'Admiral Nelson  101 Mini'
#  'High West The 36th Vote Barreled Manhattan' 'J.w. Dant Scotch'
#  'Smirnoff Sourced Watermelon' 'Sweet Carolina Sweet Tea Vodka'
#  'Roger Clynes Mexican Moonshine Anejo'
#  'Three Olives Mango Flavored Vodka DISCO' 'Ansac VSOP' 'Paul John Edited'
#  'Pere Magloire VSOP' 'Crown Royal Salted Caramel'
#  'Stoli Crushed Ruby Red Grapefruit Mini' 'Tamdhu 10YR'
#  'Corralejo Triple Distilled Reposado' 'Drumshanbo Gunpowder Irish Gin'
#  'Lord Calvert Spiced Peach Whisky Mini' "Buchanan's Master"
#  'Dr Peppermint' 'Seagrams 1.75L Retail Ready 3pk Shipper'
#  'Smirnoff 1.75L Retail Ready 3pk Shipper'
#  'Captain Morgan 1.75L Retail Ready 3pk Shipper'
#  'Crown Royal Northern Harvest Rye Mini'
#  'Bols Genever Gin - use code 964478'
#  'Rondiaz Rum Spiced Black Cherry Mini' 'Tequila Cimarron Reposado'
#  'Cimarron Tequila Blanco' "Fulton's Harvest Apple Pie Liqueur"
#  'Tattersall Distilling Amaro' 'Tattersall Distilling Blackstrap Rum'
#  'Tattersall Distilling Creme de Fleur'
#  'Tattersall Distilling Sour Cherry Liqueur' 'Bols Genever Barrel Aged'
#  'Clear Creek Grappa Muscat' 'Commanders Spiced Rum' 'Astral Tequila'
#  'Shackleton' "Nolet's Silver Gin" 'Clix Vodka' 'Bellringer Gin'
#  'Old Pulteney' 'Cazadores Blanco w/Shaker' 'Members Mark Egg Nog'
#  'Ciroc French Vanilla Mini' 'Johnnie Walker Red Scotch Minis'
#  'Southern Comfort 80pf' 'HA Corralejo 1821 Anejo Tequila'
#  'Deleon Reposado' 'Sauza Tres Generaciones Reposado'
#  'Pueblo Viejo Blanco Tequila' 'HA Talisker Malt Scotch 30YR'
#  'Prichards Sweet Lucy' 'Dr. McGillcuddys Wild Grape'
#  'Hornitos Cristalino' 'Hennessy VSOP w/Snifters'
#  'Ezra Brooks Bourbon Cream Mini' 'Svedka Mango Pineapple Vodka'
#  'Svedka Strawberry Lemonade Vodka' 'Glenfarclas Single Malt 105'
#  'Glenfarclas 12YR' 'Commanders Silver Aged 1YR'
#  'Pennsylvania Dutch Pumpkin Cream' 'St Brendans Irish Cream w/3-50mls'
#  'Glenfarclas 10YR Single Malt' 'Papas Pilar Blonde Rum'
#  '10th Mountain Bourbon' 'Uncle Vals Peppered Gin'
#  "Whaler's Rare Res Dark Rum" 'Flor Azul Silver Tequila'
#  'Flor Azul Reposado' 'TX Blended Whiskey'
#  'HA Glenmorangie Grand Vintage 1990' 'Commanders Long Island Ice Tea'
#  'Cody Road Bourbon Mini' 'Driftless Glen Bourbon'
#  'Driftless Glen Rye Whiskey' 'Skinnygirl Cucumber'
#  'Cody Road Bourbon w/Rocks Glass' 'Western Son Watermelon Vodka'
#  'Cruzan 9' 'Glenmorangie Original w/ Quinta Ruban & Lasanta'
#  'Cerises Rogue(cherry Liqueur)' 'Cerises Rogue(Cherry Liqueur)'
#  'Tequila Anejo 200ml' 'Tequila Anejo 375ml pilar'
#  'Tequila Anejo 750ml Fenice' 'Tequila Anejo 1 liter'
#  'Western Son Original Vodka Mini' 'Western Son Original Vodka'
#  'Western Son Prickly Pear Vodka Mini' 'Western Son Blueberry Vodka Mini'
#  'Western Son Watermelon Vodka Mini' 'Western Son Blueberry Vodka'
#  'Western Son Prickly Pear Vodka' "Moletto Grappa D'nebbiolo"
#  'Driftless Glen 5YR Reserve Brandy'
#  "Jack Daniel's Single Barrel Buy the Barrel"
#  'Wild Turkey Kentucky Spirit' 'Maya Horchata Liqueur'
#  'Rock Town Arkansas Bourbon Whiskey'
#  'Kirkland Signature Spiced Rum Egg Nog'
#  'Kirkland Signature 12YR Blended Scotch Whisky'
#  'SKYY Infusions Raspberry' 'Broken Bell Bourbon Whisky'
#  "Michter's US*1 SB Rye" "Michter's Us*1 American Whiskey"
#  'Crown Royal w/Tailgate Kansas City Chiefs Flask'
#  "Carolan's Irish Cream w/2 Glasses" 'Distillers Gin No. 6'
#  'HA Four Roses Al Youngs 50th Anniversary'
#  'Blue Chair Bay Banana Rum Cream Mini' "Bartender's Bananas Over U"
#  'DeKuyper Apricot Brandy' 'Grey Goose Original Flour Tin'
#  'Hennessy XO w/2 Glasses' 'Sailor Jerry Rum W/2 Oil Cans'
#  'Rumchata w/2 Shot Glasses' 'Sauza Cien Anos Anejo'
#  'Milagro Tequila Sbr Reposado' 'Bacardi 1873 Solera'
#  'Crown Royal w/2 Glasses' 'Disaronno Wears Missoni w/2 Glasses'
#  'HA 1792 Full Proof' 'Pinnacle Candy Cane Trial Pack'
#  'Disaronno Wears Missoni Mignon Counter Unit'
#  'Courvoisier VSOP w/Decanter' 'HA Old Forester Birthday Bourbon 2017'
#  'HA Lord Calvert Hunting Dog Decanter Series 2' 'Tessora Crema al Limone'
#  'Jagermeister w/Smartphone Lens Kit'
#  'Glen Moray Scotch Classic Port Cask w/2 Glasses'
#  'Revel Stoke Straight 750ml w/Apple, Pecan & Pineapple 50mls'
#  'Bombay Sapphire Gift Tin' 'Knob Creek w/Glasses'
#  'Pennsylvania Dutch Egg Nog' 'Barenjager Honey w/2 Rocks Glasses'
#  'Glenmorangie Original w/50ml Lasanta & Tumbler Cask'
#  'Very Cherry Cobbler Liqueur' 'Ole Smoky Tennessee Moonshine Blackberry'
#  'Absente w/Glass & Spoon Pack' 'Crown Royal Deluxe w/Ice Mold Tray Pack'
#  'Belvedere Pure w/Ice Bucket' 'Hpnotiq w/2 Trendy Rock Glasses'
#  'Ardbeg 10YR Warehouse Gift Box' 'Bacardi 8YR w/Glass & Ice Mold'
#  'UV Chocolate Cake DISCO' 'Casamigos Blanco Tequila w/Cradle'
#  'Casamigos Reposado Tequila w/Cradle'
#  'Revel Stoke Roasted Pecan Whisky Mini' 'One Barrel Rum'
#  'St. George All Purpose Vodka' 'Frida Kahlo Anejo Tequila' 'Bumbu Rum'
#  'Traverse City Whiskey Co. Barrel Proof Bourbon' 'El Dorado 8YR'
#  'Traverse City Whiskey Co. American Cherry Edition'
#  'Breckenridge Distillers High Proof Blend Bourbon'
#  'Jack Daniels Winter Jack' 'Jack Daniels w/Glass'
#  'Jack Daniels Tennessee Fire w/Shot Glass Mold'
#  'Christian Brothers Holiday Nog' 'Evan Williams Egg Nog'
#  'Crown Royal Deluxe w/Ice Mold' 'Baileys w/2 Dessert Bowls'
#  'Johnnie Walker Blue w/2 Glasses' 'HA Laphroaig 25YR Cask Strength'
#  'Ketel One w/Glasses' 'Aberfeldy 12YR' 'Grey Goose w/2 Martini Glasses'
#  'Elijah Craig 10YR Barrel Program #5005877 -2663'
#  'Glen Moray Elgin Classic Whiskey w/2 Glasses'
#  "Dr. McGillicuddy's Wild Grape" 'Patron Silver Version 3.0'
#  'Ron Abuelo 12YR' 'Ron Barcelo Imperial'
#  'McCormick Irish Cream w/2 Glasses' 'Tequila Rose w/2 Shot Glasses'
#  'Los Amantes Joven' 'Brokers Gin w/Stemless Martini Glass'
#  'Kerrygold Irish Cream Liqueur w/2 Glasses' 'Clyde Mays Dualpack'
#  'Stoli Elit' 'Don Ramon Tequila Reposado' 'Mr Boston 5 Star Brandy'
#  'Old Pulteney 12YR' "Hennessy Master Blender's Selection No.2"
#  'Martell VSSD' 'HA Glenmorangie Astar' 'HA Hudson Maple Cask'
#  'HA Basil Hayden Dark Rye'
#  'Johnnie Walker Blenders Batch Wine Cask Blend'
#  'Hiram Walker Caramel Apple' 'HA EH Taylor Jr Straight Rye'
#  'Arrow Ginger Brandy' 'Copper Cross Hybrid Whiskey Mini'
#  'Iowa Legendary Rye Vodka'
#  'Traverse City Whiskey Co. XXX Straight Bourbon'
#  'Traverse City Whiskey Co. North Coast Rye'
#  'Traverse City Whiskey Co. Port Barrel Finished Bourbon'
#  'Patron Guillermo Del Toro Extra Anejo & Orange DISCO'
#  'Martell Cordon Bleu Cognac' 'Hiram Walker Black Raspberry'
#  'The Famous Grouse Smoky Black' 'Brotherhood Bourbon'
#  'Appleton Estate Reserve' 'Minor Case Straight Rye'
#  'Templeton Rye w/2 Tumbler Glasses'
#  'Zaya Gran Reserva Rum w/2 Rocks Glasses'
#  'Jose Cuervo Silver w/1L Classic Margarita Mix'
#  '1800 Silver w/2 Metal Coasters' 'Corralejo Silver w/2 Sangrita Glasses'
#  'Southern Comfort w/2 Rock Glasses'
#  'Crystal Head Vodka w/2 Skull Glasses' 'Hornitos Plata w/Glasses'
#  'The Macallan Gold' 'Korbel Brandy XS' 'Woodford Reserve w/Glass'
#  'Sobieski w/2 Shot Glasses' 'Hornitos Reposado w/Glasses'
#  "Mc Master's Canadian Whiskey" 'Boodles Mulberry British Gin'
#  'Koenig Potato Vodka' 'Gran Centenario Rosangel' 'Mccormick Rum Silver'
#  'Johnnie Walker Black Glass Pack' 'Phillips Sno Shoe Grog'
#  'Leroux Jeznowka Polish Blackerry Brandy'
#  'Cedar Ridge Barrel Proof Bourbon'
#  'Cedar Ridge Private Cask Bourbon Double Oak Cask Finish'
#  'Bols Original Genever' 'Ketel One w/4 Glasses'
#  'Sugarlands Shine Peanut Butter & Jelly Moonshine'
#  'Sugarlands Shine Butterscotch Gold'
#  'Cedar Ridge Private Cask Iowa Bourbon Maple Cask Finish'
#  'Silver Cloud Tennessee Sour Mash' 'Kavalan ex-Bourbon Oak Single Malt'
#  'Kavalan King Car Conductor'
#  'Glen Moray Classic Chardonnay Cask Finish w/2 Glasses'
#  'Hennessy V.S.O.P Privilege w/2 Glasses' 'Bunnahabhain 18yr'
#  'Springbank 18YR' 'Wild Shot Reposado' 'Double Cross Vodka'
#  'Toki Suntory Japanese Whisky' 'Heaven Hill Whiskey In A Tube'
#  'Deep Eddy' 'Hennessy VS Eoy' 'Kinky Naughty & Nice Red Liqueur'
#  'Glenlivet Founders Reserve w/Stir Spoon & Bitters'
#  'Tequila Degollado A�ejo' 'McIvor Finest Blended Scotch Whisky'
#  'Platte Valley Moonshine Corn Jugs' 'Basil Hayden' 'Cruzan Guava'
#  'Absolut w/ P&M Ginger Beer' "Gordon's Gin Minis"
#  'Il Tramonto Limoncello w/2 Glasses' 'Courvoiser XO'
#  'Old Forester Statesman' 'Ole Smoky Mango Habanero Whiskey'
#  'Flor de Cana Anejo Oro 4YR' 'Absolut Black 100' 'Martell Blueswift'
#  'Ivy City Gin' 'Tomatin Single Malt Scotch 18yr'
#  'Lemon Hart 1804 Original' 'Lemon Hart 151' 'Rock Creek Bourbon'
#  'Rock Creek Rye Whiskey' 'Patron Gran Piedra'
#  'Godiva Chocolate Liqueur Mini']

# %% [markdown]
# ## Year 2012

# %%
y12.isna().sum()
# Out:
# Unnamed: 0                0
# Invoice/Item Number       0
# Date                      0
# Store Number              0
# Store Name                0
# Address                   0
# City                      0
# Zip Code                  0
# Store Location            0
# County Number             0
# County                    0
# Category                  0
# Category Name             0
# Vendor Number             0
# Vendor Name               0
# Item Number               0
# Item Description          0
# Pack                      0
# Bottle Volume (ml)        0
# State Bottle Cost        10
# State Bottle Retail      10
# Bottles Sold              0
# Sale (Dollars)           10
# Volume Sold (Liters)      0
# Volume Sold (Gallons)     0
# Year                      0
# dtype: int64

# %%
#A look at the State Bottle Cost, Retail, and Sale(Dollars) nan are all on the same 10 rows
y12[y12['State Bottle Cost'].isna()]
# Out:
#          Unnamed: 0 Invoice/Item Number        Date  Store Number  \
# 50476        199088        S03816000008  01/30/2012          3583
# 90574        356024        S03816800149  01/30/2012          2190
# 316371      1247099        S03842900093  01/31/2012          2614
# 331539      1306628        S03839800115  01/31/2012          2593
# 362712      1428507        S03825400160  01/31/2012          2616
# 481611      1896582        S03818000080  01/31/2012          4509
# 763284      3003583        S03842900089  01/31/2012          2614
# 1102887     4337985        S03841000063  01/31/2012          2549
# 1153506     4536650        S03831800099  01/31/2012          2629
# 1529456     6017165        S03814000102  01/30/2012          2623
#
#                                    Store Name                 Address  \
# 50476                 Mac's Liquor And Videos      220 EAST JEFFERSON
# 90574               Central City Liquor, Inc.            1460 2ND AVE
# 316371           Hy-Vee #3 Food and Drugstore      1823 E KIMBERLY RD
# 331539            Hy-Vee Food Store / Carroll  905 US HIGHWAY 30 WEST
# 362712         Hy-Vee Food and Drug / Clinton        901 SOUTH 4TH ST
# 481611                        A J'S LIQUOR II        2515 CHAMBERLAIN
# 763284           Hy-Vee #3 Food and Drugstore      1823 E KIMBERLY RD
# 1102887         Hy-Vee Food Store / Indianola         910 N JEFFERSON
# 1153506  Hy-Vee Food Store #2 / Council Bluff        1745 MADISON AVE
# 1529456     Hy-Vee Food Store #4 / Sioux City      2827 HAMILTON BLVD
#
#                    City Zip Code  \
# 50476           CORYDON    50060
# 90574        DES MOINES    50314
# 316371        DAVENPORT    52807
# 331539          CARROLL    51401
# 362712          CLINTON    52732
# 481611             AMES    50010
# 763284        DAVENPORT    52807
# 1102887       INDIANOLA    50125
# 1153506  COUNCIL BLUFFS    51503
# 1529456      SIOUX CITY    51104
#
#                                             Store Location  County Number  \
# 50476    220 EAST JEFFERSON\nCORYDON 50060\n(40.75718, ...           93.0
# 90574    1460 2ND AVE\nDES MOINES 50314\n(41.60566, -93...           77.0
# 316371   1823 E KIMBERLY RD\nDAVENPORT 52807\n(41.55678...           82.0
# 331539   905 US HIGHWAY 30 WEST\nCARROLL 51401\n(42.064...           14.0
# 362712   901 SOUTH 4TH ST\nCLINTON 52732\n(41.836268, -...           23.0
# 481611   2515 CHAMBERLAIN\nAMES 50010\n(42.02146, -93.6...           85.0
# 763284   1823 E KIMBERLY RD\nDAVENPORT 52807\n(41.55678...           82.0
# 1102887  910 N JEFFERSON\nINDIANOLA 50125\n(41.368503, ...           91.0
# 1153506  1745 MADISON AVE\nCOUNCIL BLUFFS 51503\n(41.24...           78.0
# 1529456  2827 HAMILTON BLVD\nSIOUX CITY 51104\n(42.5198...           97.0
#
#                 County   Category          Category Name  Vendor Number  \
# 50476            Wayne  1031080.0         VODKA 80 PROOF          301.0
# 90574             Polk  1031080.0         VODKA 80 PROOF          301.0
# 316371           Scott  1032200.0  IMPORTED VODKA - MISC          434.0
# 331539         Carroll  1032200.0  IMPORTED VODKA - MISC          434.0
# 362712         Clinton  1031080.0         VODKA 80 PROOF          301.0
# 481611           Story  1031080.0         VODKA 80 PROOF          301.0
# 763284           Scott  1031080.0         VODKA 80 PROOF          301.0
# 1102887         Warren  1032200.0  IMPORTED VODKA - MISC          434.0
# 1153506  Pottawattamie  1031080.0         VODKA 80 PROOF          301.0
# 1529456       Woodbury  1031080.0         VODKA 80 PROOF          301.0
#
#                    Vendor Name  Item Number               Item Description  \
# 50476    Fifth Generation Inc.        38180            Titos Handmade Mini
# 90574    Fifth Generation Inc.        38180            Titos Handmade Mini
# 316371          Luxco-St Louis        35920  Pearl Wedding Cake Vodka Mini
# 331539          Luxco-St Louis        35920  Pearl Wedding Cake Vodka Mini
# 362712   Fifth Generation Inc.        38180            Titos Handmade Mini
# 481611   Fifth Generation Inc.        38180            Titos Handmade Mini
# 763284   Fifth Generation Inc.        38180            Titos Handmade Mini
# 1102887         Luxco-St Louis        35920  Pearl Wedding Cake Vodka Mini
# 1153506  Fifth Generation Inc.        38180            Titos Handmade Mini
# 1529456  Fifth Generation Inc.        38180            Titos Handmade Mini
#
#          Pack  Bottle Volume (ml) State Bottle Cost State Bottle Retail  \
# 50476       5                 600               NaN                 NaN
# 90574       5                 600               NaN                 NaN
# 316371     12                 500               NaN                 NaN
# 331539     12                 500               NaN                 NaN
# 362712      5                 600               NaN                 NaN
# 481611      5                 600               NaN                 NaN
# 763284      5                 600               NaN                 NaN
# 1102887    12                 500               NaN                 NaN
# 1153506     5                 600               NaN                 NaN
# 1529456     5                 600               NaN                 NaN
#
#          Bottles Sold Sale (Dollars)  Volume Sold (Liters)  \
# 50476               1            NaN                   0.6
# 90574               1            NaN                   0.6
# 316371              1            NaN                   0.5
# 331539              2            NaN                   1.0
# 362712              3            NaN                   1.8
# 481611              1            NaN                   0.6
# 763284              2            NaN                   1.2
# 1102887             1            NaN                   0.5
# 1153506             3            NaN                   1.8
# 1529456             2            NaN                   1.2
#
#          Volume Sold (Gallons)  Year
# 50476                     0.16    12
# 90574                     0.16    12
# 316371                    0.13    12
# 331539                    0.26    12
# 362712                    0.48    12
# 481611                    0.16    12
# 763284                    0.32    12
# 1102887                   0.13    12
# 1153506                   0.48    12
# 1529456                   0.32    12

# %%
y12[y12['Item Description']=='Titos Handmade Mini']
# Out:
#          Unnamed: 0 Invoice/Item Number        Date  Store Number  \
# 12981         51330        S04109800047  02/15/2012          2543
# 50476        199088        S03816000008  01/30/2012          3583
# 68316        269125        S05068100052  04/16/2012          4219
# 79171        310645        S06245700003  06/27/2012          4112
# 88022        345620        S06417000051  07/05/2012          3762
# ...             ...                 ...         ...           ...
# 1988219     7827561        S04468100099  03/08/2012          3926
# 1999407     7871649        S05800900062  05/30/2012          2543
# 2018232     7946679        S04394400039  03/05/2012          4219
# 2045674     8054587        S04449100198  03/07/2012          2543
# 2080785     8192615        S03895300130  02/02/2012          2599
#
#                                    Store Name                Address  \
# 12981          Hy-Vee Food Store #1 / Ottumwa  1025 NORTH QUINCY AVE
# 50476                 Mac's Liquor And Videos     220 EAST JEFFERSON
# 68316           Lake Liquors Wine and Spirits         910 N 8TH ST W
# 79171                       Corridor Ventures           618 MEADE DR
# 88022                Wine and Spirits Gallery        7690 HICKMAN RD
# ...                                       ...                    ...
# 1988219           Liquor Downtown / Iowa City       315 S GILBERT ST
# 1999407        Hy-Vee Food Store #1 / Ottumwa  1025 NORTH QUINCY AVE
# 2018232         Lake Liquors Wine and Spirits         910 N 8TH ST W
# 2045674        Hy-Vee Food Store #1 / Ottumwa  1025 NORTH QUINCY AVE
# 2080785  Hy-Vee Wine and Spirits / Coralville        1914 8TH STREET
#
#                     City Zip Code  \
# 12981            OTTUWMA    52501
# 50476            CORYDON    50060
# 68316         CLEAR LAKE    50428
# 79171      NORTH LIBERTY    52317
# 88022    WINDSOR HEIGHTS    50322
# ...                  ...      ...
# 1988219        IOWA CITY    52240
# 1999407          OTTUWMA    52501
# 2018232       CLEAR LAKE    50428
# 2045674          OTTUWMA    52501
# 2080785       CORALVILLE    52241
#
#                                             Store Location  County Number  \
# 12981    1025 NORTH QUINCY AVE\nOTTUWMA 52501\n(41.0153...           90.0
# 50476    220 EAST JEFFERSON\nCORYDON 50060\n(40.75718, ...           93.0
# 68316    910 N 8TH ST W\nCLEAR LAKE 50428\n(43.142775, ...           17.0
# 79171    618 MEADE DR\nNORTH LIBERTY 52317\n(41.752451,...           52.0
# 88022    7690 HICKMAN RD\nWINDSOR HEIGHTS 50322\n(41.61...           77.0
# ...                                                    ...            ...
# 1988219  315 S GILBERT ST\nIOWA CITY 52240\n(41.657654,...           52.0
# 1999407  1025 NORTH QUINCY AVE\nOTTUWMA 52501\n(41.0153...           90.0
# 2018232  910 N 8TH ST W\nCLEAR LAKE 50428\n(43.142775, ...           17.0
# 2045674  1025 NORTH QUINCY AVE\nOTTUWMA 52501\n(41.0153...           90.0
# 2080785  1914 8TH STREET\nCORALVILLE 52241\n(41.682013,...           52.0
#
#               County   Category   Category Name  Vendor Number  \
# 12981        Wapello  1031080.0  VODKA 80 PROOF          301.0
# 50476          Wayne  1031080.0  VODKA 80 PROOF          301.0
# 68316    Cerro Gordo  1031080.0  VODKA 80 PROOF          301.0
# 79171        Johnson  1031080.0  VODKA 80 PROOF          301.0
# 88022           Polk  1031080.0  VODKA 80 PROOF          301.0
# ...              ...        ...             ...            ...
# 1988219      Johnson  1031080.0  VODKA 80 PROOF          301.0
# 1999407      Wapello  1031080.0  VODKA 80 PROOF          301.0
# 2018232  Cerro Gordo  1031080.0  VODKA 80 PROOF          301.0
# 2045674      Wapello  1031080.0  VODKA 80 PROOF          301.0
# 2080785      Johnson  1031080.0  VODKA 80 PROOF          301.0
#
#                    Vendor Name  Item Number     Item Description  Pack  \
# 12981    Fifth Generation Inc.        38180  Titos Handmade Mini     5
# 50476    Fifth Generation Inc.        38180  Titos Handmade Mini     5
# 68316    Fifth Generation Inc.        38180  Titos Handmade Mini     5
# 79171    Fifth Generation Inc.        38180  Titos Handmade Mini     5
# 88022    Fifth Generation Inc.        38180  Titos Handmade Mini     5
# ...                        ...          ...                  ...   ...
# 1988219  Fifth Generation Inc.        38180  Titos Handmade Mini     5
# 1999407  Fifth Generation Inc.        38180  Titos Handmade Mini     5
# 2018232  Fifth Generation Inc.        38180  Titos Handmade Mini     5
# 2045674  Fifth Generation Inc.        38180  Titos Handmade Mini     5
# 2080785  Fifth Generation Inc.        38180  Titos Handmade Mini     5
#
#          Bottle Volume (ml) State Bottle Cost State Bottle Retail  \
# 12981                   600            $10.03              $15.05
# 50476                   600               NaN                 NaN
# 68316                   600            $10.03              $15.05
# 79171                   600            $10.03              $15.05
# 88022                   600            $10.03              $15.05
# ...                     ...               ...                 ...
# 1988219                 600            $10.03              $15.05
# 1999407                 600            $10.03              $15.05
# 2018232                 600            $10.03              $15.05
# 2045674                 600            $10.03              $15.05
# 2080785                 600            $10.03              $15.05
#
#          Bottles Sold Sale (Dollars)  Volume Sold (Liters)  \
# 12981               2         $30.10                   1.2
# 50476               1            NaN                   0.6
# 68316               1         $15.05                   0.6
# 79171               5         $75.25                   3.0
# 88022               2         $30.10                   1.2
# ...               ...            ...                   ...
# 1988219             1         $15.05                   0.6
# 1999407             1         $15.05                   0.6
# 2018232             1         $15.05                   0.6
# 2045674             3         $45.15                   1.8
# 2080785             2         $30.10                   1.2
#
#          Volume Sold (Gallons)  Year
# 12981                     0.32    12
# 50476                     0.16    12
# 68316                     0.16    12
# 79171                     0.79    12
# 88022                     0.32    12
# ...                        ...   ...
# 1988219                   0.16    12
# 1999407                   0.16    12
# 2018232                   0.16    12
# 2045674                   0.48    12
# 2080785                   0.32    12
#
# [105 rows x 26 columns]

# %%
y12[y12['Item Description']=='Pearl Wedding Cake Vodka Mini']
# Out:
#          Unnamed: 0 Invoice/Item Number        Date  Store Number  \
# 12444         49098        S06022700051  06/12/2012          2607
# 17153         67868        S04235900166  02/23/2012          2647
# 17587         69590        S08633500145  10/29/2012          2500
# 20181         79760        S04773600001  03/28/2012          3569
# 22934         90506        S09658500044  12/26/2012          4857
# ...             ...                 ...         ...           ...
# 2054233     8088298        S04248500021  02/23/2012          2510
# 2060586     8113227        S08979100118  11/15/2012          2512
# 2067231     8139533        S08515100061  10/23/2012          2601
# 2075964     8173764        S09216900101  11/29/2012          2964
# 2079725     8188477        S09225000051  11/29/2012          2509
#
#                                    Store Name                   Address  \
# 12444    Hy-Vee Wine and Spirits / Shenandoah            520 SO FREMONT
# 17153                Hy-Vee #7 / Cedar Rapids          5050 EDGEWOOD RD
bottle Volume (ml) State Bottle Cost State Bottle Retail  \
# 12444                   500             $5.00               $7.50
# 17153                   500             $5.00               $7.50
# 17587                   500             $5.00               $7.50
# 20181                   500             $5.00               $7.50
# 22934                   500             $5.00               $7.50
# ...                     ...               ...                 ...
# 2054233                 500             $5.00               $7.50
# 2060586                 500             $5.00               $7.50
# 2067231                 500             $5.00               $7.50
# 2075964                 500             $5.00               $7.50
# 2079725                 500             $5.00               $7.50
#
#          Bottles Sold Sale (Dollars)  Volume Sold (Liters)  \
# 12444               4         $30.00                   2.0
# 17153               1          $7.50                   0.5
# 17587               1          $7.50                   0.5
# 20181              24        $180.00                  12.0
# 22934               1          $7.50                   0.5
# ...               ...            ...                   ...
# 2054233            12         $90.00                   6.0
# 2060586             1          $7.50                   0.5
# 2067231             1          $7.50                   0.5
# 2075964             1          $7.50                   0.5
# 2079725             2         $15.00                   1.0
#
#          Volume Sold (Gallons)  Year
# 12444                     0.53    12
# 17153                     0.13    12
# 17587                     0.13    12
# 20181                     3.17    12
# 22934                     0.13    12
# ...                        ...   ...
# 2054233                   1.59    12
# 2060586                   0.13    12
# 2067231                   0.13    12
# 2075964                   0.13    12
# 2079725                   0.26    12
#
# [346 rows x 26 columns]

# %% [markdown]
# # ***

# %%
#Titos Handmade Mini 'State Bottle Cost' is 10.03, 'State Bottle Retail' is $15.05
#A function multiplying retail to # sold needs to be applied for Sale (Dollars)

#Pearl Wedding Cake Vodka Mini 'State Bottle Cost' is $5.00, 'State Bottle Retail' is $7.50
#A function multiplying retail to # sold needs to be applied for Sale (Dollars)
def fix_bottle_cost(x,y):
    if (pd.isna(x)) and (y=='Pearl Wedding Cake Vodka Mini'):
        return '$5.00'
    elif(pd.isna(x)) and (y=='Titos Handmade Mini'):
        return '$10.03'
    else:
        return x
    
def fix_bottle_retail(x,y):
    if (pd.isna(x))&(y=='Pearl Wedding Cake Vodka Mini'):
        return '$7.50'
    elif(pd.isna(x))&(y=='Titos Handmade Mini'):
        return '$15.05'
    else:
        return x
    
def sale_dollars(x,y,a):
    if (pd.isna(x))&(y=='Pearl Wedding Cake Vodka Mini'):
        b=7.50*int(a)
        e=str(b)
        return '$'+e
    elif(pd.isna(x))&(y=='Titos Handmade Mini'):
        c=15.05*int(a)
        d=str(c)
        return '$'+d
    else:
        return x

# %%
#y12['State Bottle Cost']=list(map(fix_bottle_cost,y12['State Bottle Cost'],y12['Item Description']))
#y12['State Bottle Retail']=list(map(fix_bottle_retail,y12['State Bottle Retail'],y12['Item Description']))
y12['Sale (Dollars)']=list(map(sale_dollars,y12['Sale (Dollars)'],y12['Item Description'],y12['Bottles Sold']))

# %%
y12.isna().sum()
# Out:
# Unnamed: 0               0
# Invoice/Item Number      0
# Date                     0
# Store Number             0
# Store Name               0
# Address                  0
# City                     0
# Zip Code                 0
# Store Location           0
# County Number            0
# County                   0
# Category                 0
# Category Name            0
# Vendor Number            0
# Vendor Name              0
# Item Number              0
# Item Description         0
# Pack                     0
# Bottle Volume (ml)       0
# State Bottle Cost        0
# State Bottle Retail      0
# Bottles Sold             0
# Sale (Dollars)           0
# Volume Sold (Liters)     0
# Volume Sold (Gallons)    0
# Year                     0
# dtype: int64

# %%
y12.to_csv('clean_2012.csv')

# %% [markdown]
# ## Year 2013

# %%
y13.isna().sum()
# Out:
# Unnamed: 0               0
# Invoice/Item Number      0
# Date                     0
# Store Number             0
# Store Name               0
# Address                  0
# City                     0
# Zip Code                 0
# Store Location           0
# County Number            0
# County                   0
# Category                 0
# Category Name            0
# Vendor Number            0
# Vendor Name              0
# Item Number              0
# Item Description         0
# Pack                     0
# Bottle Volume (ml)       0
# State Bottle Cost        0
# State Bottle Retail      0
# Bottles Sold             0
# Sale (Dollars)           0
# Volume Sold (Liters)     0
# Volume Sold (Gallons)    0
# Year                     0
# dtype: int64

# %%
y13.to_csv('clean_2013.csv')

# %% [markdown]
# ## Year 2014

# %%
y14.isna().sum()
# Out:
# Unnamed: 0               0
# Invoice/Item Number      0
# Date                     0
# Store Number             0
# Store Name               0
# Address                  0
# City                     0
# Zip Code                 0
# Store Location           0
# County Number            0
# County                   0
# Category                 0
# Category Name            0
# Vendor Number            0
# Vendor Name              0
# Item Number              0
# Item Description         0
# Pack                     0
# Bottle Volume (ml)       0
# State Bottle Cost        0
# State Bottle Retail      0
# Bottles Sold             0
# Sale (Dollars)           0
# Volume Sold (Liters)     0
# Volume Sold (Gallons)    0
# Year                     0
# dtype: int64

# %%
y14.to_csv('clean_2014.csv')

# %% [markdown]
# ## Year 2015

# %%
y15.isna().sum()
# Out:
# Unnamed: 0                 0
# Invoice/Item Number        0
# Date                       0
# Store Number               0
# Store Name                 0
# Address                    0
# City                       0
# Zip Code                   0
# Store Location             0
# County Number              0
# County                     0
# Category                 174
# Category Name              0
# Vendor Number              0
# Vendor Name                0
# Item Number                0
# Item Description           0
# Pack                       0
# Bottle Volume (ml)         0
# State Bottle Cost          0
# State Bottle Retail        0
# Bottles Sold               0
# Sale (Dollars)             0
# Volume Sold (Liters)       0
# Volume Sold (Gallons)      0
# Year                       0
# dtype: int64

# %%
y15[y15['Category'].isna()].shape
# Out:
# (174, 26)

# %%
y15[y15['Category Name'].isna()].shape
# Out:
# (0, 26)

# %%
y15[y15['Category Name'].isna() & y15['Category'].notna()]['Category'].unique()
# Out:
# array([], dtype=float64)

# %%
listof6 = (1032100.0, 1091100.0, 1089290.0, 1052100.0, 1081100.0)
for i in listof6:
    print('For Category ',i,' the Category name(s) is/are: ',y15[y15['Category']== i]['Category Name'].unique())
# Out:
# For Category  1032100.0  the Category name(s) is/are:  ['NAN' 'IMPORTED VODKAS' 'IMPORTED VODKA']
# For Category  1091100.0  the Category name(s) is/are:  ['NAN']
# For Category  1089290.0  the Category name(s) is/are:  ['NAN']
# For Category  1052100.0  the Category name(s) is/are:  ['NAN']
# For Category  1081100.0  the Category name(s) is/are:  ['NAN']

# %%
y15[y15['Category']==1032100.0]['Category Name'].unique()
# Out:
# array(['nan', 'imported vodka'], dtype=object)

# %%
def vodka(a,b):
    if (pd.isna(a)) & (b == 1032100.0):
        return 'imported vodka'
    elif (a =='imported vodkas'):
        return 'imported vodka'
    else: 
        return a

# %%
y15['Category Name']=list(map(vodka,y15['Category Name'],y15['Category']))

# %%
#map function worked
listof6 = (1032100.0, 1091100.0, 1089290.0, 1052100.0, 1081100.0)
for i in listof6:
    print('For Category ',i,' the Category name(s) is/are: ',y15[y15['Category']== i]['Category Name'].unique())
# Out:
# For Category  1032100.0  the Category name(s) is/are:  ['nan' 'imported vodka']
# For Category  1091100.0  the Category name(s) is/are:  ['nan']
# For Category  1089290.0  the Category name(s) is/are:  ['nan']
# For Category  1052100.0  the Category name(s) is/are:  ['nan']
# For Category  1081100.0  the Category name(s) is/are:  ['nan']

# %%
y15['Category Name'].unique()
# Out:
# array(['HOLIDAY VAP', 'DECANTERS & SPECIALTY PACKAGES', 'NAN',
#        'CREAM LIQUEURS', 'PUERTO RICO & VIRGIN ISLANDS RUM',
#        'VODKA 80 PROOF', 'MISC. AMERICAN CORDIALS & LIQUEURS',
#        'BLENDED WHISKIES', 'WHISKEY LIQUEUR', 'STRAIGHT BOURBON WHISKIES',
#        'SINGLE MALT SCOTCH', 'PEPPERMINT SCHNAPPS', 'CANADIAN WHISKIES',
#        'SPICED RUM', 'TENNESSEE WHISKIES', 'SCOTCH WHISKIES',
#        'IMPORTED DRY GINS', 'IMPORTED VODKA', 'FLAVORED GINS',
#        'IMPORTED GRAPE BRANDIES', 'IMPORTED SCHNAPPS', '100 PROOF VODKA',
#        'AMERICAN AMARETTO', 'IRISH WHISKIES', 'TEQUILA', 'VODKA FLAVORED',
#        'STRAIGHT RYE WHISKIES', 'PEACH SCHNAPPS', 'IMPORTED VODKA - MISC',
#        'MISCELLANEOUS SCHNAPPS', 'IMPORTED AMARETTO',
#        'AMERICAN GRAPE BRANDIES', 'COFFEE LIQUEURS', 'FLAVORED RUM',
#        'AMERICAN DRY GINS', 'BLACKBERRY BRANDIES',
#        'BUTTERSCOTCH SCHNAPPS', 'AMERICAN COCKTAILS', 'TRIPLE SEC',
#        'STRAWBERRY SCHNAPPS', 'OTHER PROOF VODKA', 'CINNAMON SCHNAPPS',
#        'SINGLE BARREL BOURBON WHISKIES', 'RASPBERRY SCHNAPPS',
#        'MISCELLANEOUS  BRANDIES', 'CREME DE ALMOND',
#        'MISC. IMPORTED CORDIALS & LIQUEURS', 'APPLE SCHNAPPS',
#        'JAMAICA RUM', 'BARBADOS RUM', 'APRICOT BRANDIES',
#        'DISTILLED SPIRITS SPECIALTY', 'WATERMELON SCHNAPPS',
#        'AMERICAN ALCOHOL', 'GRAPE SCHNAPPS', 'BOTTLED IN BOND BOURBON',
#        'PEACH BRANDIES', 'CHERRY BRANDIES', 'ROOT BEER SCHNAPPS',
#        'TROPICAL FRUIT SCHNAPPS', 'AMERICAN SLOE GINS',
#        'GREEN CREME DE MENTHE', 'DARK CREME DE CACAO', 'ROCK & RYE',
#        'TEMPORARY & SPECIALTY PACKAGES', 'WHITE CREME DE CACAO',
#        '100% AGAVE TEQUILA', 'LOW PROOF VODKA', 'WHITE CREME DE MENTHE',
#        'SPEARMINT SCHNAPPS', 'ANISETTE', 'CORN WHISKIES',
#        'AMARETTO - IMPORTED', 'SPECIAL ORDER ITEMS',
#        'HIGH PROOF BEER - AMERICAN', 'IMPORTED CORDIALS & LIQUEURS',
#        'JAPANESE WHISKY', 'IMPORTED CORDIALS & LIQUEUR',
#        'SCHNAPPS - IMPORTED', 'IMPORTED VODKA - CHERRY'], dtype=object)

# %%
y15.to_csv('clean_2015.csv')

# %% [markdown]
# ## Year 2016

# %%
y16.isna().sum()
# Out:
# Unnamed: 0                 0
# Invoice/Item Number        0
# Date                       0
# Store Number               0
# Store Name                 0
# Address                    0
# City                       0
# Zip Code                   0
# Store Location             0
# County Number            797
# County                   797
# Category                   5
# Category Name              0
# Vendor Number              2
# Vendor Name                0
# Item Number                0
# Item Description           0
# Pack                       0
# Bottle Volume (ml)         0
# State Bottle Cost          0
# State Bottle Retail        0
# Bottles Sold               0
# Sale (Dollars)             0
# Volume Sold (Liters)       0
# Volume Sold (Gallons)      0
# Year                       0
# dtype: int64

# %%
y16[y16['County'].isna()]['City'].unique()
# Out:
# array(['MASON CITY', 'Mason City'], dtype=object)

# %%
y16['City']=list(map(lambda x: x.lower(),y16['City']))
y16['County']=list(map(lambda x: x.lower(),y16['County']))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8796/3123481710.py in <module>
#       1 y16['City']=list(map(lambda x: x.lower(),y16['City']))
# ----> 2 y16['County']=list(map(lambda x: x.lower(),y16['County']))
#
# ~\AppData\Local\Temp/ipykernel_8796/3123481710.py in <lambda>(x)
#       1 y16['City']=list(map(lambda x: x.lower(),y16['City']))
# ----> 2 y16['County']=list(map(lambda x: x.lower(),y16['County']))
#
# AttributeError: 'float' object has no attribute 'lower'

# %%
y16[y16['County'].isna()]['City'].unique()
# Out:
# array(['mason city'], dtype=object)

# %%
y16[y16['City']=='mason city']['County'].unique()
# Out:
# array(['Cerro Gordo', nan, 'CERRO GORD'], dtype=object)

# %%
def cg_county(a,b):
    if (pd.isna(a))&(b=='mason city'):
        return 'cerro gordo'
    else:
        return a
    
def cg_county_number(a,b):
    if(b=='mason city') & (pd.isna(a)):
        return 17.
    else:
        return a

# %%
y16['County']=list(map(cg_county,y16['County'],y16['City']))
y16['County Number']=list(map(cg_county_number,y16['County Number'],y16['City']))

# %%
#County Number for Mason City is 17
print(y16[y16['County']=='CERRO GORD']['County Number'].unique(),
y16[y16['County']=='Cerro Gordo']['County Number'].unique(),
y16[y16['County'].isna()]['County Number'].unique(),
y16[y16['County'].isna()]['City'].unique())
# Out:
# [17.] [17.] [nan] ['mason city']

# %%
y16[y16['Category'].isna()]
# Out:
#          Unnamed: 0 Invoice/Item Number        Date  Store Number  \
# 206415      8634516        S30603400001  02/08/2016          4604
# 655811      9083912        S31932100002  04/27/2016          4509
# 1530181     9958282     INV-00201700001  09/08/2016          5102
# 1630306    10058407     INV-00512000007  09/26/2016          3773
# 1630307    10058408     INV-00512000008  09/26/2016          3773
#
#                         Store Name           Address          City Zip Code  \
# 206415   Pit Stop Liquors / Newton   1324, 1st AVE E        newton    50208
# 655811             A J'S LIQUOR II  2515 CHAMBERLAIN          ames    50010
# 1530181             Wilkie Liquors   724 1st  St  SE  mount vernon  52314.0
# 1630306          Benz Distributing    501 7th Ave SE  cedar rapids    52401
# 1630307          Benz Distributing    501 7th Ave SE  cedar rapids    52401
#
#                                             Store Location  County Number  \
# 206415   1324, 1st AVE E\nNEWTON 50208\n(41.699173, -93...           50.0
# 655811   2515 CHAMBERLAIN\nAMES 50010\n(42.021461, -93....           85.0
# 1530181  724 1st St SE\nMount Vernon 52314\n(41.918452,...           57.0
# 1630306  501 7th Ave SE\nCedar Rapids 52401\n(41.975787...           57.0
# 1630307  501 7th Ave SE\nCedar Rapids 52401\n(41.975787...           57.0
#
#          County  Category Category Name  Vendor Number  \
# 206415   Jasper       NaN           nan           85.0
# 655811    Story       NaN           nan          469.0
# 1530181    LINN       NaN           nan          446.0
# 1630306    LINN       NaN           nan          477.0
# 1630307    LINN       NaN           nan          477.0
#
#                       Vendor Name  Item Number  \
# 206415   Brown-Forman Corporation          333
# 655811                 TY KU, LLC       929570
# 1530181  STEPHEN AUGUSTUS IMPORTS       984162
# 1630306              VINO COM LLC       942332
# 1630307              VINO COM LLC       942330
#
#                                           Item Description  Pack  \
# 206415   Jack Daniels TN Honey & Jack Daniels TN Fire 7...     4
# 655811                                       Ty Ku Coconut     6
# 1530181                       Calvados Morin Selection 3YR    12
# 1630306                                    Ron Abuelo 12YR    12
# 1630307                               Ron Abuelo Anejo 7YR    12
#
#          Bottle Volume (ml) State Bottle Cost State Bottle Retail  \
# 206415                 1500            $15.07              $22.61
# 655811                  750             $7.00              $10.50
# 1530181                 750            $13.84              $20.76
# 1630306                 750            $24.17              $36.26
# 1630307                 750            $15.84              $23.76
#
#          Bottles Sold Sale (Dollars)  Volume Sold (Liters)  \
# 206415              3         $67.83                  4.50
# 655811              6         $63.00                  4.50
# 1530181             1        $249.12                  0.75
# 1630306             1        $435.12                  0.75
# 1630307             2        $285.12                  1.50
#
#          Volume Sold (Gallons)  Year
# 206415                    1.19    16
# 655811                    1.19    16
# 1530181                   0.19    16
# 1630306                   0.19    16
# 1630307                   0.39    16

# %%
#searching for item with ellipses in previous cell
#found: 'Jack Daniels TN Honey & Jack Daniels TN Fire 750mls w/2Gls'
y16[y16['Vendor Name']=='Brown-Forman Corporation']['Item Description'].unique()
# Out:
# array(['Jack Daniels Tennessee Honey w/Glass',
#        'Gentleman Jack w/2 Glasses',
#        'Southern Comfort w/Shot Glass & Lanyard', 'Herradura Silver',
#        'Herradura Anejo', 'Herradura Gold Reposado 6pak',
#        'Canadian Mist Whisky', 'Canadian Mist Whiskey Pet',
#        'Canadian Mist', 'Old Forester Signature 100prf Bourbon',
#        'Early Times 36 Mo Ky Str Bourbon',
#        'Early Times 36 Mo Ky Str Bourbon Pet', 'Old Forester Bourbon',
#        'Woodford Reserve', 'Woodford Reserve Bourbon',
#        'Woodford Reserve Double Oaked', 'Gentleman Jack',
#        'Jack Daniels Old #7 Black Lbl Flat',
#        'Jack Daniels Old #7 Black Lbl Mini', 'Jack Daniels Black Label',
#        'Jack Daniels Old #7 Black Lbl',
#        'Jack Daniels Old #7 Black Lbl Square',
#        'Jack Daniels Single Barrel Why.', 'Korbel Brandy',
#        'Korbel Brandy Pet', 'Chambord Liqueur Royale De France',
#        'Jack Daniels Winter Jack', 'Tuaca Perfect Chill',
#        'Southern Comfort', "Jack Daniel's Tennessee Honey Mini",
#        "Jack Daniel's Tennessee Honey",
#        "Jack Daniel's Tennessee Fire Mini",
#        "Jack Daniel's Tennessee Fire", 'Southern Comfort Caramel',
#        'Southern Comfort Cherry', 'Southern Comfort Lime',
#        'Southern Comfort Mini', 'Southern Comfort Pet',
#        'Southern Comfort PET', 'Southern Comfort 100 Prf',
#        'El Jimador Silver Tequila', 'El Jimador Anejo Tequila',
#        'El Jimador Reposado Tequila', 'Pepe Lopez Gold',
#        "Jack Daniel's Single Barrel Barrel Proof",
#        'Chambord Liqueur Minis', 'Finlandia Mango Fusion',
#        "Jack Daniel's Sinatra Select Whiskey",
#        "Jack Daniel's Masters Distillers 3", 'Jack Daniels Single Barrel',
#        'Finlandia Vodka Raspberry',
#        'Jack Daniels TN Honey & Jack Daniels TN Fire 750mls w/2Gls',
#        "Jack Daniel's  4YR Rye Single Barrel", 'Finlandia Vodka 80 Proof',
#        'Old Forester 4yr 86prf Bourbon',
#        'Old Forester 1897 Whisky Row Series', "Jack Daniel's Winter Jack",
#        'Woodford Reserve Kentucky Derby 2016',
#        'Canadian Mist Canadian Why Pet', 'Korbel Brandy VSOP',
#        'Woodford Reserve Personal Selection Barrel',
#        'Old Forester 1870 Whisky Row Series'], dtype=object)

# %%
listid=('Jack Daniels TN Honey & Jack Daniels TN Fire 750mls w/2Gls','Ty Ku Coconut','Calvados Morin Selection 3YR',
        'Ron Abuelo 12YR','Ron Abuelo Anejo 7YR')
for i in listid:
    print(y16[y16['Item Description']==i]['Category Name'])
for i in listid:
    print(y16[y16['Item Description']==i]['Category'])
# Out:
# 206415    nan
# Name: Category Name, dtype: object
# 655811    nan
# Name: Category Name, dtype: object
# 1530181    nan
# Name: Category Name, dtype: object
# 1630306    nan
# Name: Category Name, dtype: object
# 1630307    nan
# Name: Category Name, dtype: object
# 206415   NaN
# Name: Category, dtype: float64
# 655811   NaN
# Name: Category, dtype: float64
# 1530181   NaN
# Name: Category, dtype: float64
# 1630306   NaN
# Name: Category, dtype: float64
# 1630307   NaN
# Name: Category, dtype: float64

# %%
#couldn't find name in '16, let's search entire dataset
#result: all nan values
listof6 = (y12,y13,y14,y15,y16,y17)
listid=('Jack Daniels TN Honey & Jack Daniels TN Fire 750mls w/2Gls','Ty Ku Coconut','Calvados Morin Selection 3YR',
        'Ron Abuelo 12YR','Ron Abuelo Anejo 7YR')
for j in listof6:
    for i in listid:
        print(j[j['Item Description']==i]['Category Name'])
        print(j[j['Item Description']==i]['Category'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16548/2551498214.py in <module>
#       1 #couldn't find name in '16, let's search entire dataset
#       2 #result: all nan values
# ----> 3 listof6 = (y12,y13,y14,y15,y16,y17)
#       4 listid=('Jack Daniels TN Honey & Jack Daniels TN Fire 750mls w/2Gls','Ty Ku Coconut','Calvados Morin Selection 3YR',
#       5         'Ron Abuelo 12YR','Ron Abuelo Anejo 7YR')
#
# NameError: name 'y12' is not defined

# %%
y16[y16['Vendor Number'].isna()]
# Out:
#          Unnamed: 0 Invoice/Item Number        Date  Store Number  \
# 1767189    10195290     INV-00993400006  10/17/2016          2190
# 1767190    10195291     INV-00993400007  10/17/2016          2190
#
#                         Store Name       Address        City Zip Code  \
# 1767189  Central City Liquor, Inc.  1460 2ND AVE  des moines  50314.0
# 1767190  Central City Liquor, Inc.  1460 2ND AVE  des moines  50314.0
#
#                                             Store Location  County Number  \
# 1767189  1460 2ND AVE\nDes Moines 50314\n(41.60566, -93...           77.0
# 1767190  1460 2ND AVE\nDes Moines 50314\n(41.60566, -93...           77.0
#
#         County   Category                        Category Name  Vendor Number  \
# 1767189   POLK  1011300.0       single barrel bourbon whiskies            NaN
# 1767190   POLK  1091100.0  american distilled spirit specialty            NaN
#
#                   Vendor Name  Item Number           Item Description  Pack  \
# 1767189  Reservoir Distillery       916456  Reservoir Bourbon Whiskey     6
# 1767190  Reservoir Distillery       927565    Reservoir Wheat Whiskey     6
#
#          Bottle Volume (ml) State Bottle Cost State Bottle Retail  \
# 1767189                 750            $45.00              $67.50
# 1767190                 750            $45.00              $67.50
#
#          Bottles Sold Sale (Dollars)  Volume Sold (Liters)  \
# 1767189             5        $405.00                  3.75
# 1767190             3        $405.00                  2.25
#
#          Volume Sold (Gallons)  Year
# 1767189                   0.99    16
# 1767190                   0.59    16

# %%
y16[y16['Vendor Name']=='Reservoir Distillery']['Vendor Number']
# Out:
# 1767189   NaN
# 1767190   NaN
# Name: Vendor Number, dtype: float64

# %%
#couldn't find name in '16, let's search entire dataset
#result: all nan values
listof6 = (y12,y13,y14,y15,y16,y17)
for i in listof6:
    print(i[i['Vendor Name']=='Reservoir Distillery']['Vendor Number'])
# Out:
# Series([], Name: Vendor Number, dtype: float64)
# Series([], Name: Vendor Number, dtype: float64)
# Series([], Name: Vendor Number, dtype: float64)
# Series([], Name: Vendor Number, dtype: float64)
# 1767189   NaN
# 1767190   NaN
# Name: Vendor Number, dtype: float64
# Series([], Name: Vendor Number, dtype: float64)

# %%
y16.to_csv('clean_2016.csv')

# %% [markdown]
# ## Year 2017

# %%
y17.isna().sum()
# Out:
# Unnamed: 0                 0
# Invoice/Item Number        0
# Date                       0
# Store Number               0
# Store Name                 0
# Address                    1
# City                       0
# Zip Code                   0
# Store Location             0
# County Number              0
# County                     0
# Category                 128
# Category Name              0
# Vendor Number              0
# Vendor Name                0
# Item Number                0
# Item Description           0
# Pack                       0
# Bottle Volume (ml)         0
# State Bottle Cost          0
# State Bottle Retail        0
# Bottles Sold               0
# Sale (Dollars)             0
# Volume Sold (Liters)       0
# Volume Sold (Gallons)      0
# Year                       0
# dtype: int64

# %% [markdown]
# #### Attempting to Clean Address

# %%
y17[y17['Address'].isna()]['Store Number']
# Out:
# 1050009    9932
# Name: Store Number, dtype: int64

# %%
#no full address in y17
y17[y17['Store Number']==9932]['Store Location']
# Out:
# 1050009    Dubuque 52002\n(42.516027, -90.766335)
# Name: Store Location, dtype: object

# %%
#Address column will be dropped later so nan is inconsequential,
#plus the row would also be dropped later anyways as the store is in Dubuque, not Des Moines
y17[y17['Store Number']==9932]
# Out:
#          Unnamed: 0 Invoice/Item Number        Date  Store Number  \
# 1050009    11757989     INV-05674000001  06/22/2017          9932
#
#                      Store Name Address     City  Zip Code  \
# 1050009  3-Oaks Distillery, LLC     NaN  Dubuque   52002.0
#
#                                  Store Location  County Number   County  \
# 1050009  Dubuque 52002\n(42.516027, -90.766335)           31.0  DUBUQUE
#
#           Category     Category Name  Vendor Number             Vendor Name  \
# 1050009  1011100.0  Blended Whiskies          215.0  3-Oaks Distillery, LLC
#
#          Item Number           Item Description  Pack  Bottle Volume (ml)  \
# 1050009        27890  3-Oaks Distillery Whiskey    12                 750
#
#         State Bottle Cost State Bottle Retail  Bottles Sold Sale (Dollars)  \
# 1050009            $21.60              $32.40             1        $388.80
#
#          Volume Sold (Liters)  Volume Sold (Gallons)  Year
# 1050009                  0.75                   0.19    17

# %%
#Though ultimately inconsequential, let's search entire dataset for more info since y17
#did not have the data I wanted
#result: no new information
listof6 = (y12,y13,y14,y15,y16,y17)
for i in listof6:
    print(i[i['Store Number']==9932]['Address'])
# Out:
# Series([], Name: Address, dtype: object)
# Series([], Name: Address, dtype: object)
# Series([], Name: Address, dtype: object)
# Series([], Name: Address, dtype: object)
# Series([], Name: Address, dtype: object)
# 1050009    NaN
# Name: Address, dtype: object

# %% [markdown]
# #### Attempting to Clean Category

# %%
#Category nans are associated with Category Name 'vodka flavored'
y17[y17['Category'].isna()]['Category Name'].unique()
# Out:
# array(['nan', 'vodka flavored'], dtype=object)

# %%
#The Category value for 'vodka flavored' is 1031200.
y17[y17['Category Name']=='vodka flavored']['Category'].unique()
# Out:
# array([1031200.,      nan])

# %%
#creating function to erase the nans for this Category Name pairing
def cnvodka17(a,b):
    if (pd.isna(a)) & (b == 1031200.):
        return 'vodka flavored'
    else: 
        return a
    
def cvodka17(a,b):
    if (pd.isna(a)) & (b == 'vodka flavored'):
        return 1031200.
    else: 
        return a

# %%
#applying the functions
y17['Category Name']=list(map(cnvodka17,y17['Category Name'],y17['Category']))
y17['Category']=list(map(cvodka17,y17['Category'],y17['Category Name']))

# %%
y17.isna().sum()
# Out:
# Unnamed: 0                 0
# Invoice/Item Number        0
# Date                       0
# Store Number               0
# Store Name                 0
# Address                    1
# City                       0
# Zip Code                   0
# Store Location             0
# County Number              0
# County                     0
# Category                 126
# Category Name              0
# Vendor Number              0
# Vendor Name                0
# Item Number                0
# Item Description           0
# Pack                       0
# Bottle Volume (ml)         0
# State Bottle Cost          0
# State Bottle Retail        0
# Bottles Sold               0
# Sale (Dollars)             0
# Volume Sold (Liters)       0
# Volume Sold (Gallons)      0
# Year                       0
# dtype: int64

# %%
y17[y17['Category'].isna()]['Category Name'].unique()
# Out:
# array(['nan'], dtype=object)

# %%
y17.to_csv('clean_2017.csv')

# %% [markdown]
# # Next Steps (new file?)

# %%
y12.columns
# Out:
# Index(['Unnamed: 0', 'Invoice/Item Number', 'Date', 'Store Number',
#        'Store Name', 'Address', 'City', 'Zip Code', 'Store Location',
#        'County Number', 'County', 'Category', 'Category Name', 'Vendor Number',
#        'Vendor Name', 'Item Number', 'Item Description', 'Pack',
#        'Bottle Volume (ml)', 'State Bottle Cost', 'State Bottle Retail',
#        'Bottles Sold', 'Sale (Dollars)', 'Volume Sold (Liters)',
#        'Volume Sold (Gallons)', 'Year'],
#       dtype='object')

# %%
listof6 = (y12,y13,y14,y15,y16,y17)
for i in listof6:
    print(i.dtypes)
# Out:
# Unnamed: 0                 int64
# Invoice/Item Number       object
# Date                      object
# Store Number               int64
# Store Name                object
# Address                   object
# City                      object
# Zip Code                  object
# Store Location            object
# County Number            float64
# County                    object
# Category                 float64
# Category Name             object
# Vendor Number            float64
# Vendor Name               object
# Item Number                int64
# Item Description          object
# Pack                       int64
# Bottle Volume (ml)         int64
# State Bottle Cost         object
# State Bottle Retail       object
# Bottles Sold               int64
# Sale (Dollars)            object
# Volume Sold (Liters)     float64
# Volume Sold (Gallons)    float64
# Year                       int64
# dtype: object
# Unnamed: 0                 int64
# Invoice/Item Number       object
# Date                      object
# Store Number               int64
# Store Name                object
# Address                   object
# City                      object
# Zip Code                  object
# Store Location            object
# County Number            float64
# County                    object
# Category                 float64
# Category Name             object
# Vendor Number            float64
# Vendor Name               object
# Item Number                int64
# Item Description          object
# Pack                       int64
# Bottle Volume (ml)         int64
# State Bottle Cost         object
# State Bottle Retail       object
# Bottles Sold               int64
# Sale (Dollars)            object
# Volume Sold (Liters)     float64
# Volume Sold (Gallons)    float64
# Year                       int64
# dtype: object
# Unnamed: 0                 int64
# Invoice/Item Number       object
# Date                      object
# Store Number               int64
# Store Name                object
# Address                   object
# City                      object
# Zip Code                  object
# Store Location            object
# County Number            float64
# County                    object
# Category                 float64
# Category Name             object
# Vendor Number            float64
# Vendor Name               object
# Item Number                int64
# Item Description          object
# Pack                       int64
# Bottle Volume (ml)         int64
# State Bottle Cost         object
# State Bottle Retail       object
# Bottles Sold               int64
# Sale (Dollars)            object
# Volume Sold (Liters)     float64
# Volume Sold (Gallons)    float64
# Year                       int64
# dtype: object
# Unnamed: 0                 int64
# Invoice/Item Number       object
# Date                      object
# Store Number               int64
# Store Name                object
# Address                   object
# City                      object
# Zip Code                  object
# Store Location            object
# County Number            float64
# County                    object
# Category                 float64
# Category Name             object
# Vendor Number            float64
# Vendor Name               object
# Item Number                int64
# Item Description          object
# Pack                       int64
# Bottle Volume (ml)         int64
# State Bottle Cost         object
# State Bottle Retail       object
# Bottles Sold               int64
# Sale (Dollars)            object
# Volume Sold (Liters)     float64
# Volume Sold (Gallons)    float64
# Year                       int64
# dtype: object
# Unnamed: 0                 int64
# Invoice/Item Number       object
# Date                      object
# Store Number               int64
# Store Name                object
# Address                   object
# City                      object
# Zip Code                  object
# Store Location            object
# County Number            float64
# County                    object
# Category                 float64
# Category Name             object
# Vendor Number            float64
# Vendor Name               object
# Item Number                int64
# Item Description          object
# Pack                       int64
# Bottle Volume (ml)         int64
# State Bottle Cost         object
# State Bottle Retail       object
# Bottles Sold               int64
# Sale (Dollars)            object
# Volume Sold (Liters)     float64
# Volume Sold (Gallons)    float64
# Year                       int64
# dtype: object
# Unnamed: 0                 int64
# Invoice/Item Number       object
# Date                      object
# Store Number               int64
# Store Name                object
# Address                   object
# City                      object
# Zip Code                 float64
# Store Location            object
# County Number            float64
# County                    object
# Category                 float64
# Category Name             object
# Vendor Number            float64
# Vendor Name               object
# Item Number                int64
# Item Description          object
# Pack                       int64
# Bottle Volume (ml)         int64
# State Bottle Cost         object
# State Bottle Retail       object
# Bottles Sold               int64
# Sale (Dollars)            object
# Volume Sold (Liters)     float64
# Volume Sold (Gallons)    float64
# Year                       int64
# dtype: object

# %% [markdown]
# # ***

# %%
listof6 = (y12,y13,y14,y15,y16,y17)
counter = 12
for i in listof6:
    print(counter)
    counter+=1
    i['Date']=pd.to_datetime(i['Date'])
    i['Store Number']=i['Store Number'].astype(str)
    i['Zip Code']=i['Zip Code'].astype(str)
    i['County Number']=i['County Number'].astype(str)
    i['Category']=i['Category'].astype(str)
    i['Vendor Number']=i['Vendor Number'].astype(str)
    i['Item Number']=i['Item Number'].astype(str)
    i['State Bottle Cost']=list(map(lambda x:x[1:],i['State Bottle Cost']))
    i['State Bottle Cost']=pd.to_numeric(i['State Bottle Cost'])
    i['State Bottle Retail']=list(map(lambda x:x[1:],i['State Bottle Retail']))
    i['State Bottle Retail']=pd.to_numeric(i['State Bottle Retail'])
    i['Sale (Dollars)']=list(map(lambda x:x[1:],i['Sale (Dollars)']))
    i['Sale (Dollars)']=pd.to_numeric(i['Sale (Dollars)'])

# %%
y12.columns

# %%
c12=c12.drop(['Unnamed: 0','Unnamed: 0.1','Invoice/Item Number','Store Name','Address','City','Zip Code', 'Store Location','County Number','County','Category','Vendor Name','Volume Sold (Gallons)','Year'] ,axis=1)
