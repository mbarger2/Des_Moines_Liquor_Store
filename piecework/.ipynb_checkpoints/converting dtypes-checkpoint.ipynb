# %%
import pandas as pd
import numpy as np
from datetime import datetime
import seaborn as sb
import matplotlib as plt
import math

# %%
y12=pd.read_csv('C://Users//admin//documents//git//final//Iowa_sales//year2012.csv')

# %%
y12.head(3)
# Out:
#    Unnamed: 0 Invoice/Item Number        Date  Store Number  \
# 0         102        S08792800017  11/06/2012          2459
# 1         103        S04854100048  04/03/2012          2487
# 2         106        S08900500035  11/13/2012          4509
#
#              Store Name              Address            City Zip Code  \
# 0        Reinhart Foods  200 STATE PO BOX 98  GUTHRIE CENTER    50115
# 1  Anamosa Family Foods        402 EAST MAIN         ANAMOSA    52205
# 2       A J'S LIQUOR II     2515 CHAMBERLAIN            AMES    50010
#
#                                       Store Location  County Number  ...  \
# 0        200 STATE PO BOX 98\nGUTHRIE CENTER 50115\n           39.0  ...
# 1  402 EAST MAIN\nANAMOSA 52205\n(42.108289, -91....           53.0  ...
# 2  2515 CHAMBERLAIN\nAMES 50010\n(42.02146, -93.6...           85.0  ...
#
#             Item Description  Pack Bottle Volume (ml)  State Bottle Cost  \
# ...

# %%
#convert y12['Date'] to datetime
np.dtype(y12['Date'])
# Out:
# dtype('O')

# %%
y12['Date'][0]
# Out:
# '11/06/2012'

# %%
list(map(lambda: datetime.strptime(x,'%MM/%DD/%YYYY'),y12['Date']))

# %%
date_time_str = y12['Date'][0]
date_time_obj = datetime.strptime(date_time_str, '%m/%d/%Y').date()
print ("The type of the date is now", date_time_obj)
# Out:
# The type of the date is now 2012-11-06

# %%
def convert_date(x):
    date_time_str = x
    date_time_obj = datetime.strptime(date_time_str, '%m/%d/%Y').date()

# %%
y12['Date']=list(map(lambda x: convert_date(x),y12['Date']))

# %%
np.dtype(y12['Date'])
# Out:
# dtype('O')

# %%
y12['Date'][0]

# %%
y12.columns
# Out:
# Index(['Unnamed: 0', 'Invoice/Item Number', 'Date', 'Store Number',
#        'Store Name', 'Address', 'City', 'Zip Code', 'Store Location',
#        'County Number', 'County', 'Category', 'Category Name', 'Vendor Number',
#        'Vendor Name', 'Item Number', 'Item Description', 'Pack',
#        'Bottle Volume (ml)', 'State Bottle Cost', 'State Bottle Retail',
#        'Bottles Sold', 'Sale (Dollars)', 'Volume Sold (Liters)',
#        'Volume Sold (Gallons)', 'Year'],
#       dtype='object')

# %%
y12.head(3)
# Out:
#    Unnamed: 0 Invoice/Item Number  Date  Store Number            Store Name  \
# 0         102        S08792800017  None          2459        Reinhart Foods
# 1         103        S04854100048  None          2487  Anamosa Family Foods
# 2         106        S08900500035  None          4509       A J'S LIQUOR II
#
#                Address            City Zip Code  \
# 0  200 STATE PO BOX 98  GUTHRIE CENTER    50115
# 1        402 EAST MAIN         ANAMOSA    52205
# 2     2515 CHAMBERLAIN            AMES    50010
#
#                                       Store Location  County Number  ...  \
# 0        200 STATE PO BOX 98\nGUTHRIE CENTER 50115\n           39.0  ...
# 1  402 EAST MAIN\nANAMOSA 52205\n(42.108289, -91....           53.0  ...
# 2  2515 CHAMBERLAIN\nAMES 50010\n(42.02146, -93.6...           85.0  ...
#
#             Item Description  Pack Bottle Volume (ml)  State Bottle Cost  \
# 0           Cruzan Mango Rum    12                750              $6.82
# ...

# %%
y12['Date'][0]
# Out:
# '11/06/2012'

# %%
y12['Date']=pd.to_datetime(y12['Date'],format='%m/%d/%Y')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4976/1276426168.py in <module>
# ----> 1 y12['Date']=pd.to_datetime(y12['Date'],format='%m/%d/%Y').date()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'date'

# %%
y12['Date'][0]
# Out:
# Timestamp('2012-11-06 00:00:00')

# %%
y12.dtypes
# Out:
# Unnamed: 0                        int64
# Invoice/Item Number              object
# Date                     datetime64[ns]
# Store Number                      int64
# Store Name                       object
# Address                          object
# City                             object
# Zip Code                         object
# Store Location                   object
# County Number                   float64
# County                           object
# Category                        float64
# Category Name                    object
# Vendor Number                   float64
# Vendor Name                      object
# Item Number                       int64
# Item Description                 object
# Pack                              int64
# Bottle Volume (ml)                int64
# State Bottle Cost                object
# State Bottle Retail              object
# Bottles Sold                      int64
# Sale (Dollars)                   object
# ...

# %% [markdown]
# # convert zip code, state bottle cost, state bottle retail, sale(dollars)
# # research county number

# %%
print(y12['County Number'])

# %%
y12.head(2)
# Out:
#    Unnamed: 0 Invoice/Item Number       Date  Store Number  \
# 0         102        S08792800017 2012-11-06          2459
# 1         103        S04854100048 2012-04-03          2487
#
#              Store Name              Address            City Zip Code  \
# 0        Reinhart Foods  200 STATE PO BOX 98  GUTHRIE CENTER    50115
# 1  Anamosa Family Foods        402 EAST MAIN         ANAMOSA    52205
#
#                                       Store Location  County Number  ...  \
# 0        200 STATE PO BOX 98\nGUTHRIE CENTER 50115\n           39.0  ...
# 1  402 EAST MAIN\nANAMOSA 52205\n(42.108289, -91....           53.0  ...
#
#             Item Description  Pack Bottle Volume (ml)  State Bottle Cost  \
# 0           Cruzan Mango Rum    12                750              $6.82
# 1  Arrow Peppermint Schnapps     6               1750              $7.04
#
#   State Bottle Retail  Bottles Sold Sale (Dollars)  Volume Sold (Liters)  \
# ...

# %%
y12.sort_values('Date')
#df.sort_values(by=['col1', 'col2'])
# Out:
#          Unnamed: 0 Invoice/Item Number       Date  Store Number  \
# 1988127     7827232        S03390300045 2012-01-03          3728
# 1745699     6870657        S03405800008 2012-01-03          3761
# 353147      1391185        S03412100200 2012-01-03          2603
# 816416      3212199        S03396600132 2012-01-03          3456
# 9017          35755        S03398800048 2012-01-03          2636
# ...             ...                 ...        ...           ...
# 1050381     4130563        S09791300153 2012-12-31          2616
# 314064      1237821        S09787800007 2012-12-31          3934
# 2068208     8143366        S09804500026 2012-12-31          3725
# 1596260     6282206        S09809300181 2012-12-31          2593
# 1169709     4600584        S09791700022 2012-12-31          4649
#
#                                    Store Name                 Address  \
# 1988127                    Brewski's Beverage           726 CREEK TOP
# ...

# %% [markdown]
# ## Clean columns to be correct dtype

# %%
y12.isna().sum()
# Out:
# Unnamed: 0                  0
# Invoice/Item Number         0
# Date                        0
# Store Number                0
# Store Name                  0
# Address                     0
# City                        0
# Zip Code                    0
# Store Location              0
# County Number            3599
# County                   3599
# Category                  284
# Category Name             822
# Vendor Number               0
# Vendor Name                 0
# Item Number                 0
# Item Description            0
# Pack                        0
# Bottle Volume (ml)          0
# State Bottle Cost          10
# State Bottle Retail        10
# Bottles Sold                0
# Sale (Dollars)             10
# Volume Sold (Liters)        0
# Volume Sold (Gallons)       0
# Year                        0
# dtype: int64

# %%
y12.isnull().sum()
# Out:
# Unnamed: 0                  0
# Invoice/Item Number         0
# Date                        0
# Store Number                0
# Store Name                  0
# Address                     0
# City                        0
# Zip Code                    0
# Store Location              0
# County Number            3599
# County                   3599
# Category                  284
# Category Name             822
# Vendor Number               0
# Vendor Name                 0
# Item Number                 0
# Item Description            0
# Pack                        0
# Bottle Volume (ml)          0
# State Bottle Cost          10
# State Bottle Retail        10
# Bottles Sold                0
# Sale (Dollars)             10
# Volume Sold (Liters)        0
# Volume Sold (Gallons)       0
# Year                        0
# dtype: int64

# %%
pd.set_option('display.max_rows',1000)
y12['Zip Code'].value_counts()
# Out:
# 52240    53976
# 52402    49129
# 50010    43012
# 50314    42156
# 50317    37004
# 51501    36016
# 52807    35604
# 50613    33026
# 52001    32894
# 50265    32573
# 52404    29635
# 52501    28921
# 52804    27917
# 50401    27668
# 52241    27519
# 52722    27114
# 52601    26844
# 52761    25713
# 50501    25603
# 51503    25113
# 50322    23194
# 52405    23166
# 50703    22894
# 50315    22688
# 50320    22022
# 52732    21815
# 50702    21633
# 50266    21600
# 50701    20949
# 50021    20132
# 50158    19061
# 52302    18991
# 50310    18795
# 52806    18668
# 50131    17601
# 50588    17591
# 50428    17141
# 50311    17111
# 50208    16700
# 50009    15832
# 51301    15118
# 51401    14806
# 51106    14090
# 50125    13642
# 51360    13239
# 52314    12676
# 52577    12528
# 52403    12340
# 52632    12069
# 50111    12064
# 50316    12007
# 50112    11763
# 52627    11597
# 52060    11205
# 50138    11164
# 50677    11140
# 52101    10871
# 50595    10787
# ...

# %%
#convert sale dollars to numeric
y12['Sale (Dollars)test']=list(map(lambda x: x[1:],y12['Sale (Dollars)']))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4976/1366354674.py in <module>
#       1 #convert sale dollars to numeric
# ----> 2 y12['Sale (Dollars)test']=list(map(lambda x: x[1:],y12['Sale (Dollars)']))
#
# ~\AppData\Local\Temp/ipykernel_4976/1366354674.py in <lambda>(x)
#       1 #convert sale dollars to numeric
# ----> 2 y12['Sale (Dollars)test']=list(map(lambda x: x[1:],y12['Sale (Dollars)']))
#
# TypeError: 'float' object is not subscriptable

# %%
y12['Sale (Dollars)']=pd.to_numeric(y12['Sale (Dollars)'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\_libs\lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "$30.72"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4976/3891803284.py in <module>
# ----> 1 y12['Sale (Dollars)']=pd.to_numeric(y12['Sale (Dollars)'])
#
# ~\anaconda3\lib\site-packages\pandas\core\tools\numeric.py in to_numeric(arg, errors, downcast)
#     181         coerce_numeric = errors not in ("ignore", "raise")
#     182         try:
# --> 183             values, _ = lib.maybe_convert_numeric(
#     184                 values, set(), coerce_numeric=coerce_numeric
#     185             )
#
# ...

# %%
y12['Zip Code']=pd.to_numeric(y12['Zip Code'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\_libs\lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "712-2"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4976/3428413284.py in <module>
# ----> 1 y12['Zip Code']=pd.to_numeric(y12['Zip Code'])
#
# ~\anaconda3\lib\site-packages\pandas\core\tools\numeric.py in to_numeric(arg, errors, downcast)
#     181         coerce_numeric = errors not in ("ignore", "raise")
#     182         try:
# --> 183             values, _ = lib.maybe_convert_numeric(
#     184                 values, set(), coerce_numeric=coerce_numeric
#     185             )
#
# ...

# %%
y12['Zip Code'][1624]
# Out:
# '712-2'

# %%
ax2 = y12.plot.scatter(x='Date',y='Sale (Dollars)')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4976/3452729838.py in <module>
# ----> 1 ax2 = y12.plot.scatter(x='Date',y=round('Sale (Dollars)',0))
#
# TypeError: type str doesn't define __round__ method
