# %%
import pandas as pd
import numpy as np
import chunk
import re
from datetime import datetime

# %%
y12=pd.read_csv('C://Users//Matthew//DA//Activities//Final_Project//Final Cuts//year2012.csv')

# %%
y12=pd.read_csv('C://Users//admin//Documents//git//Final//Iowa_sales//year2012.csv')

# %%
ytest=y12

# %%
y12['Date']=pd.to_datetime(y12['Date'])

# %%
# Work on 9932 zip via its 'store location', and zip code 712-2 via ['Store Location'].unique()

# %%
y17[y17['Store Number']==9932]['Store Location'].unique()

# %%
def clean_sn9932(x,y):
    if x==9932 & pd.isna(y):
        return _____
    else:
        return x

# %%
#check all columns that are na for 9932
y['Address']==list(map(clean_sn9932,y['Store Number'],y['Address']))

# %%
y17[y17['Zip Code']==712-2]['Store Location'].unique()

# %%
y17[y17['Zip Code'].str.contains('712-2')]['Store Location'].unique()

# %%
def clean_zip(x):
    if x==712-2:
        return _____
    else:
        return x

# %%
y['Zip Code']==list(map(clean_zip,y['Zip Code']))

# %%
#zip (x), county (x), county num (x), city (x), address (x), Category Name (x), Category (x)

# %%
dictname={}
for i in df['Store Number']:
    dictname[i]=df[df['Store Number']==i]['Address'].values[0]

# %%
def get_address(x,y):
    storelist=list(dictname.keys())
    if (pd.isna(x)) and (y in storelist):
        return dictname[y]
    else:
        return x

# %%
countydict={}
for i in county_na['Store Number']:
    countydict[i]=county_na[county_na['Store Number']==i]['County'].values[0]

# %%
def get_county(x,y):
    storelist=list(dictname.keys())
    if (pd.isna(x)) and (y in storelist):
        return dictname[y]
    else:
        return x

# %%
y['County']=list(map(get_county,y['County'],y['Store Number']))

# %%
countynumdict={}
for i in countynumna['Store Number']:
    countynumdict[i]=countynumna[countynumna['Store Number']==i]['County Number'].values[0]

# %%
def get_county_num(x,y):
    storelist=list(dictname.keys())
    if (pd.isna(x)) and (y in storelist):
        return dictname[y]
    else:
        return x

# %%
y['County Number']=list(map(get_county_num,y['County Number'],y['Store Number']))

# %%
zipdict={}
for i in zipna['Store Number']:
    zipdict[i]=zipna[zipna['Store Number']==i]['Zip Code'].values[0]

# %%
def get_zip(x,y):
    storelist=list(dictname.keys())
    if (pd.isna(x)) and (y in storelist):
        return zipdict[y]
    else:
        return x

# %%
y['Zip Code']=list(map(get_zip,y['Zip Code'],y['Store Number']))

# %%
citydict={}
for i in cityna['Store Number']:
    citydict[i]=cityna[zipna['Store Number']==i]['City'].values[0]

# %%
def get_city(x,y):
    storelist=list(citydict.keys())
    if (pd.isna(x)) and (y in storelist):
        return citydict[y]
    else:
        return x

# %%
y['City']=list(map(get_city,y['City'],y['Store Number']))

# %%
#concat Category na list

# %%
ycat=concat(y12[['Store Number','Category']],y13[['Store Number','Category']],y14[['Store Number','Category']],y15[['Store Number','Category']],y16[['Store Number','Category']],y17[['Store Number','Category']])

# %%
ycat=ycat[ycat['Category'].notna()]

# %%
ycat.drop_duplicates(subset=['Item Description'],inplace = True)

# %%
catdict={}
for i in catna['Store Number']:
    catdict[i]=catna[zipna['Store Number']==i]['Category'].values[0]

# %%
def get_category(x,y):
    storelist=list(catdict.keys())
    if (pd.isna(x)) and (y in storelist):
        return catdict[y]
    else:
        return x

# %%
y['Category']=list(map(get_category,y['Category'],y['Store Number']))

# %%
ycatname=concat(y12[['Store Number','Category Name']],y13[['Store Number','Category Name']],y14[['Store Number','Category Name']],y15[['Store Number','Category Name']],y16[['Store Number','Category Name']],y17[['Store Number','Category Name']])

# %%
ycatname=ycatname[ycatname['Category Name'].notna()]

# %%
ycatname.drop_duplicates(subset=['Item Description'],inplace =True)

# %%
catnamedict={}
for i in ycatname['Store Number']:
    catnamedict[i]=ycatname[zipna['Store Number']==i]['Category Name'].values[0]

# %%
def get_category_name(x,y):
    storelist=list(catdict.keys())
    if (pd.isna(x)) and (y in storelist):
        return catnamedict[y]
    else:
        return x

# %%
y['Category Name']=list(map(get_category_name,y['Category Name'],y['Store Number']))

# %%
def county_name(x,y):
    if (pd.isna(x)) and (y=='GUTTENBERG'):
        return 'Clayton'
    elif (pd.isna(x)) and (y=='BELMOND'):
        return 'Wright'
    else:
        return x
    
def county_number(x,y):
    if (pd.isna(x)) and (y=='GUTTENBERG'):
        return '22.'
    elif (pd.isna(x)) and (y=='BELMOND'):
        return '99.'
    else:
        return x
    
def fix_bottle_cost(x,y):
    if (pd.isna(x)) and (y=='Pearl Wedding Cake Vodka Mini'):
        return '$5.00'
    elif(pd.isna(x)) and (y=='Titos Handmade Mini'):
        return '$10.03'
    else:
        return x
    
def fix_bottle_retail(x,y):
    if (pd.isna(x))&(y=='Pearl Wedding Cake Vodka Mini'):
        return '$7.50'
    elif(pd.isna(x))&(y=='Titos Handmade Mini'):
        return '$15.05'
    else:
        return x
    
def sale_dollars(x,y,a):
    if (pd.isna(x))&(y=='Pearl Wedding Cake Vodka Mini'):
        b=7.50*int(a)
        return '$'+str(b)
    elif(pd.isna(x))&(y=='Titos Handmade Mini'):
        c=15.05*int(a)
        return '$'+str(c)
    else:
        return x

# %%
y12['County']=list(map(county_name,y12['County'],y12['City']))
y12['County Number']=list(map(county_name,y12['County Number'],y12['City']))
y12['State Bottle Cost']=list(map(fix_bottle_cost,y12['State Bottle Cost'],y12['Item Description']))
y12['State Bottle Retail']=list(map(fix_bottle_retail,y12['State Bottle Retail'],y12['Item Description']))
y12['Sale (Dollars)']=list(map(sale_dollars,y12['Sale (Dollars)'],y12['Item Description'],y12['Bottles Sold']))

# %%
y12.dtypes
# Out:
# Unnamed: 0                        int64
# Invoice/Item Number              object
# Date                     datetime64[ns]
# Store Number                      int64
# Store Name                       object
# Address                          object
# City                             object
# Zip Code                         object
# Store Location                   object
# County Number                    object
# County                           object
# Category                        float64
# Category Name                    object
# Vendor Number                   float64
# Vendor Name                      object
# Item Number                       int64
# Item Description                 object
# Pack                              int64
# Bottle Volume (ml)                int64
# State Bottle Cost                object
# State Bottle Retail              object
# Bottles Sold                      int64
# Sale (Dollars)                   object
# ...

# %%
y12.isna().sum()
# Out:
# Unnamed: 0                 0
# Invoice/Item Number        0
# Date                       0
# Store Number               0
# Store Name                 0
# Address                    0
# City                       0
# Zip Code                   0
# Store Location             0
# County Number              0
# County                     0
# Category                 284
# Category Name            822
# Vendor Number              0
# Vendor Name                0
# Item Number                0
# Item Description           0
# Pack                       0
# Bottle Volume (ml)         0
# State Bottle Cost          0
# State Bottle Retail        0
# Bottles Sold               0
# Sale (Dollars)             0
# Volume Sold (Liters)       0
# Volume Sold (Gallons)      0
# Year                       0
# dtype: int64

# %% [markdown]
# # YTEST simulations

# %%
pd.set_option('display.max_rows',1000)
pd.set_option('display.max_columns',1000)

# %%
#the same 10 rows have the 10 Nan values for State Bottle Cost, State Bottle Retail, and Sale (Dollars) each
y12[y12['State Bottle Cost'].isna()]
# Out:
#          Unnamed: 0 Invoice/Item Number       Date  Store Number  \
# 50476        199088        S03816000008 2012-01-30          3583
# 90574        356024        S03816800149 2012-01-30          2190
# 316371      1247099        S03842900093 2012-01-31          2614
# 331539      1306628        S03839800115 2012-01-31          2593
# 362712      1428507        S03825400160 2012-01-31          2616
# 481611      1896582        S03818000080 2012-01-31          4509
# 763284      3003583        S03842900089 2012-01-31          2614
# 1102887     4337985        S03841000063 2012-01-31          2549
# 1153506     4536650        S03831800099 2012-01-31          2629
# 1529456     6017165        S03814000102 2012-01-30          2623
#
#                                    Store Name                 Address  \
# 50476                 Mac's Liquor And Videos      220 EAST JEFFERSON
# 90574               Central City Liquor, Inc.            1460 2ND AVE
# ...

# %%
len(ytest[(ytest['Vendor Name']=='Fifth Generation Inc.') & (ytest['Item Description']=='Titos Handmade Mini')])
# Out:
# 105

# %%
len(ytest[(ytest['Item Description']=='Titos Handmade Mini')])
# Out:
# 105

# %%
ytest[(ytest['Item Description']=='Titos Handmade Mini')]
# Out:
#          Unnamed: 0 Invoice/Item Number       Date  Store Number  \
# 12981         51330        S04109800047 2012-02-15          2543
# 50476        199088        S03816000008 2012-01-30          3583
# 68316        269125        S05068100052 2012-04-16          4219
# 79171        310645        S06245700003 2012-06-27          4112
# 88022        345620        S06417000051 2012-07-05          3762
# 90574        356024        S03816800149 2012-01-30          2190
# 112304       441262        S04195400035 2012-02-21          2651
# 117652       462199        S03994400035 2012-02-08          4307
# 135135       531809        S04426800075 2012-03-06          2619
# 139027       546997        S05575000062 2012-05-16          2543
# 168048       662169        S05351600050 2012-05-02          2611
# 175877       693040        S06055600051 2012-06-13          3762
# 180418       710658        S03887600010 2012-02-02          4071
# ...

# %%
len(ytest[(ytest['Vendor Name']=='Luxco-St Louis') & (ytest['Item Description']=='Pearl Wedding Cake Vodka Mini')])
# Out:
# 346

# %%
ytest[ (ytest['Item Description']=='Pearl Wedding Cake Vodka Mini')]
# Out:
#          Unnamed: 0 Invoice/Item Number       Date  Store Number  \
# 12444         49098        S06022700051 2012-06-12          2607
# 17153         67868        S04235900166 2012-02-23          2647
# 17587         69590        S08633500145 2012-10-29          2500
# 20181         79760        S04773600001 2012-03-28          3569
# 22934         90506        S09658500044 2012-12-26          4857
# 23055         91016        S05444100043 2012-05-09          2661
# 31045        122258        S08612400031 2012-10-29          2539
# 44943        177248        S05752400011 2012-05-29          2601
# 50853        200506        S04184700003 2012-02-21          2641
# 51083        201398        S04550300024 2012-03-15          4196
# 51883        204509        S07188800063 2012-08-20          2539
# 53467        210755        S05020400093 2012-04-12          2512
# 57523        226735        S05524100001 2012-05-14          2638
# ...

# %%
def county_name(x,y):
    if (pd.isna(x)) and (y=='GUTTENBERG'):
        return 'Clayton'
    elif (pd.isna(x)) and (y=='BELMOND'):
        return 'Wright'
    else:
        return x

# %%
ytest['County']=list(map(county_name,ytest['County'],y12['City']))

# %%
def fix_bottle_cost(x,y):
    if (pd.isna(x)) and (y=='Pearl Wedding Cake Vodka Mini'):
        return '$5.00'
    elif(pd.isna(x)) and (y=='Titos Handmade Mini'):
        return '$10.03'
    else:
        return x

# %%
ytest['State Bottle Cost'].isna().sum()
# Out:
# 10

# %%
ytest['State Bottle Cost']=list(map(fix_bottle_cost,ytest['State Bottle Cost'],ytest['Item Description']))

# %%
ytest['State Bottle Cost'].isna().sum()
# Out:
# 0

# %%
len(ytest[ (ytest['Item Description']=='Pearl Wedding Cake Vodka Mini')])
# Out:
# 346

# %%
def fix_bottle_retail(x,y):
    if (pd.isna(x))&(y=='Pearl Wedding Cake Vodka Mini'):
        return '$7.50'
    elif(pd.isna(x))&(y=='Titos Handmade Mini'):
        return '$15.05'
    else:
        return x

# %%
ytest['State Bottle Retail'].isna().sum()
# Out:
# 10

# %%
ytest['State Bottle Retail']=list(map(fix_bottle_retail,ytest['State Bottle Retail'],ytest['Item Description']))

# %%
ytest['State Bottle Retail'].isna().sum()
# Out:
# 0

# %%
ytest[ (ytest['Item Description']=='Pearl Wedding Cake Vodka Mini')]
# Out:
#          Unnamed: 0 Invoice/Item Number        Date  Store Number  \
# 12444         49098        S06022700051  06/12/2012          2607
# 17153         67868        S04235900166  02/23/2012          2647
# 17587         69590        S08633500145  10/29/2012          2500
# 20181         79760        S04773600001  03/28/2012          3569
# 22934         90506        S09658500044  12/26/2012          4857
# 23055         91016        S05444100043  05/09/2012          2661
# 31045        122258        S08612400031  10/29/2012          2539
# 44943        177248        S05752400011  05/29/2012          2601
# 50853        200506        S04184700003  02/21/2012          2641
# 51083        201398        S04550300024  03/15/2012          4196
# 51883        204509        S07188800063  08/20/2012          2539
# 53467        210755        S05020400093  04/12/2012          2512
# 57523        226735        S05524100001  05/14/2012          2638
# ...

# %%
def sale_dollars(x,y,a):
    if (pd.isna(x))&(y=='Pearl Wedding Cake Vodka Mini'):
        b=7.50*int(a)
        return '$'+str(b)
    elif(pd.isna(x))&(y=='Titos Handmade Mini'):
        c=15.05*int(a)
        return '$'+str(c)
    else:
        return x

# %%
ytest['Sale (Dollars)'].isna().sum()
# Out:
# 10

# %%
ytest['Sale (Dollars)']=list(map(sale_dollars,ytest['Sale (Dollars)'],ytest['Item Description'],ytest['Bottles Sold']))

# %%
ytest['Sale (Dollars)'].isna().sum()
# Out:
# 0

# %%
ytest[ (ytest['Item Description']=='Pearl Wedding Cake Vodka Mini')]
# Out:
#          Unnamed: 0 Invoice/Item Number        Date  Store Number  \
# 12444         49098        S06022700051  06/12/2012          2607
# 17153         67868        S04235900166  02/23/2012          2647
# 17587         69590        S08633500145  10/29/2012          2500
# 20181         79760        S04773600001  03/28/2012          3569
# 22934         90506        S09658500044  12/26/2012          4857
# 23055         91016        S05444100043  05/09/2012          2661
# 31045        122258        S08612400031  10/29/2012          2539
# 44943        177248        S05752400011  05/29/2012          2601
# 50853        200506        S04184700003  02/21/2012          2641
# 51083        201398        S04550300024  03/15/2012          4196
# 51883        204509        S07188800063  08/20/2012          2539
# 53467        210755        S05020400093  04/12/2012          2512
# 57523        226735        S05524100001  05/14/2012          2638
# ...

# %%
#Per Google, Guttenberg is in Clayton County, Belmond is in Wright
counties=pd.DataFrame(y12[y12['County'].isna()])
counties['City'].unique()
# Out:
# array(['GUTTENBERG', 'BELMOND'], dtype=object)

# %%
y12[(y12['City']=='GUTTENBERG')]['County Number'].unique()
# Out:
# array([nan, 22.])

# %%
y12[(y12['City']=='BELMOND')]['County Number'].unique()
# Out:
# array([99., nan])

# %%
ytest=y12

# %%
ytest['County'].isna().sum()
# Out:
# 0

# %%
len(ytest[ytest['County']=='Wright'])
# Out:
# 8735

# %%
len(y12[y12['County']=='Wright'])
# Out:
# 7046

# %%
len(ytest[ytest['County']=='Clayton'])
# Out:
# 11164

# %%
len(y12[y12['County']=='Clayton'])
# Out:
# 9254

# %%
y12['County'].isna().sum()
# Out:
# 3599

# %%
ytest['County'].isna().sum()
# Out:
# 0

# %%
ytest['County Number'].notna().sum()
# Out:
# 2078460

# %%
ytest[ytest['County']=='Guttenberg' and ytest['County Number'].notna()]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-264-daa445277368> in <module>
# ----> 1 ytest[ytest['County']=='Guttenberg' and ytest['County Number'].notna()]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1440     @final
#    1441     def __nonzero__(self):
# -> 1442         raise ValueError(
#    1443             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1444             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
y12['County'].isna().sum()
# Out:
# 0

# %%
y12=y12.reset_index(drop=True)

# %%
len(y12)
# Out:
# 3599

# %%
y12.drop('level_0',axis=1)
# Out:
#         index  Unnamed: 0 Invoice/Item Number        Date  Store Number  \
# 0         143         692        S09377500017  12/10/2012          3782
# 1        1736        7072        S07061900003  08/13/2012          3782
# 2        3279       13146        S09257900003  12/03/2012          3782
# 3        4108       16482        S04829500028  04/02/2012          3782
# 4        4147       16635        S07879000006  09/24/2012          3782
# ...       ...         ...                 ...         ...           ...
# 3594  2076344     8175219        S04299800019  02/28/2012          4247
# 3595  2079198     8186457        S09490500034  12/17/2012          4247
# 3596  2080178     8190238        S09369700018  12/10/2012          4247
# 3597  2080180     8190243        S06692900022  07/23/2012          4247
# 3598  2080440     8191172        S03712400018  01/24/2012          4247
#
#                          Store Name             Address        City Zip Code  \
# ...

# %%
y12['Sale (Dollars)'].isna().sum()
# Out:
# 10

# %%
y12['Sale (Dollars)']=y12['Sale (Dollars)'].fillna('$0')

# %%
y12['Sale (Dollars)'].isna().sum()
# Out:
# 0

# %%
y12['Sale (Dollars)']=list(map(lambda x:x[1:],y12['Sale (Dollars)']))

# %%
y12['Sale (Dollars)'].dtype
# Out:
# dtype('O')

# %%
y12['Sale (Dollars)']=pd.to_numeric(y12['Sale (Dollars)'])

# %%
y12['Sale (Dollars)'].dtype
# Out:
# dtype('float64')

# %%
a='asbsc'
a.split('s')[0]
# Out:
# 'a'

# %%
len(y12['County'].unique())
# Out:
# 100

# %%
y12['County'].value_counts()
# Out:
# Polk             361591
# Linn             171137
# Scott            134984
# Black Hawk       106857
# Johnson          104458
# Pottawattamie     70206
# Story             66459
# Dubuque           63073
# Woodbury          57709
# Cerro Gordo       47145
# Des Moines        33113
# Muscatine         31624
# Wapello           30751
# Dickinson         25703
# Clinton           25655
# Webster           25449
# Lee               25270
# Jasper            21196
# Marshall          21030
# Marion            20755
# Iowa              19953
# Buena Vista       19344
# Warren            17756
# Bremer            17228
# Carroll           16887
# Jones             16866
# Poweshiek         15885
# Clay              15213
# O'Brien           14196
# Jackson           13868
# Dallas            13711
# Kossuth           13565
# Winneshiek        13368
# Hardin            13290
# Buchanan          13275
# Plymouth          13017
# Hamilton          12443
# Sioux             12314
# ...

# %%
y12['Zip Code'].sort_values().unique()
# Out:
# array(['50002', '50003', '50006', '50009', '50010', '50014', '50015',
#        '50020', '50021', '50022', '50023', '50025', '50028', '50033',
#        '50035', '50036', '50044', '50046', '50048', '50049', '50054',
#        '50056', '50058', '50060', '50069', '50071', '50075', '50076',
#        '50107', '50111', '50112', '50115', '50122', '50124', '50125',
#        '50126', '50129', '50130', '50131', '50136', '50138', '50140',
#        '50142', '50144', '50150', '50156', '50158', '50161', '50162',
#        '50163', '50170', '50171', '50174', '50201', '50208', '50210',
#        '50211', '50212', '50213', '50216', '50219', '50220', '50225',
#        '50226', '50228', '50244', '50247', '50248', '50249', '50250',
#        '50251', '50261', '50263', '50265', '50266', '50273', '50276',
#        '50300', '50309', '50310', '50311', '50312', '50313', '50314',
#        '50315', '50316', '50317', '50320', '50321', '50322', '50323',
# ...

# %%
# https://worldpopulationreview.com/zips/iowa
zips=pd.read_csv('C://Users//Matthew//DA//Activities//Final_Project//Final Cuts//csvData.csv')

# %%
zips.head()
# Out:
#      zip      city    county   pop
# 0  50001  Ackworth    Warren   932
# 1  50002     Adair     Adair  1417
# 2  50003      Adel    Dallas  7714
# 3  50005    Albion  Marshall  1057
# 4  50006     Alden    Hardin  1715

# %%
zips['zip'].sort_values().unique()
# Out:
# array([50001, 50002, 50003, 50005, 50006, 50007, 50008, 50009, 50010,
#        50011, 50012, 50014, 50020, 50021, 50022, 50025, 50026, 50027,
#        50028, 50029, 50032, 50033, 50034, 50035, 50036, 50038, 50039,
#        50041, 50042, 50044, 50046, 50047, 50048, 50049, 50050, 50051,
#        50052, 50054, 50055, 50056, 50057, 50058, 50060, 50061, 50062,
#        50063, 50064, 50065, 50066, 50067, 50068, 50069, 50070, 50071,
#        50072, 50073, 50074, 50075, 50076, 50078, 50101, 50102, 50103,
#        50104, 50105, 50106, 50107, 50108, 50109, 50111, 50112, 50115,
#        50116, 50117, 50118, 50119, 50120, 50122, 50123, 50124, 50125,
#        50126, 50127, 50128, 50129, 50130, 50131, 50132, 50133, 50134,
#        50135, 50136, 50138, 50139, 50140, 50141, 50142, 50143, 50144,
#        50146, 50147, 50148, 50149, 50150, 50151, 50153, 50154, 50155,
#        50156, 50157, 50158, 50160, 50161, 50162, 50163, 50164, 50165,
# ...

# %%
uzips=uzips.drop(['0'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-77-f815a3eb37fd> in <module>
# ----> 1 uzips=uzips.drop(['0'])
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# ...

# %%
zipcomp=pd.concat((zips['zip'],zips['county'],zips['city'],y12['Zip Code'],y12['County'],y12['City']),axis=1)

# %%
pd.set_option('display.max_rows',1000)

# %%
zipcomp.head(2)
# Out:
#        zip  county      city Zip Code   County            City
# 0  50001.0  Warren  Ackworth    50115  Guthrie  GUTHRIE CENTER
# 1  50002.0   Adair     Adair    52205    Jones         ANAMOSA

# %%
vendorlist=list(ytest[ytest['Category Name'].isna()]['Vendor Name'].unique())
vendordict={}
for i in vendorlist:
    count=ytest[ytest['Vendor Name']==i].value_counts().sum()
    vendor=i
    vendordict[vendor] = {'count':count}

# %%
vlist=pd.DataFrame(vendordict).T.reset_index()
vlist.columns=['Vendor Name','Instances']
vlist
# Out:
#                   Vendor Name  Instances
# 0    Brown-Forman Corporation      95106
# 1          Heaven Hill Brands      76388
# 2               Campari(skyy)      29727
# 3      Rogue Ales and Spirits         27
# 4  The Patron Spirits Company      14685

# %%
# for only the 5 most active counties in alcohol purchases, 
# create a DF for the cat/catname na values
catnamena=ytest[(ytest['Category Name'].isna()) & 
            (ytest['County'].isin(['Polk','Scott','Black Hawk','Johnson','Linn']))]

# %%
len(catnamena)
# Out:
# 448

# %%
len(catnamena[catnamena['Category'].isna()])
# Out:
# 93

# %%
# looking for the columns most likely to be correlated with the category/category name na values
for i in catnamena.columns:
    print('column ',i,'has values',catnamena[i].value_counts())
    #print('yitems has value counts', ytest[i].value_counts())
# Out:
# column  Unnamed: 0 has values 1385473    1
# 5269513    1
# 5437127    1
# 4431558    1
# 1249983    1
# 6725926    1
# 2704821    1
# 5272248    1
# 5626551    1
# 4637366    1
# 5745330    1
# 7870567    1
# 212655     1
# 6143663    1
# 3630766    1
# 1682142    1
# 1653418    1
# 6520489    1
# 1898151    1
# 4900517    1
# 1240739    1
# 670370     1
# 831477     1
# 7859696    1
# 7270033    1
# 5464314    1
# 5007000    1
# 2273994    1
# 6887098    1
# 4993743    1
# 3932904    1
# 4385535    1
# 3972862    1
# 7179004    1
# 3441399    1
# 1042166    1
# 7369083    1
# 2474739    1
# 3594994    1
# 5641964    1
# 4720360    1
# 93929      1
# 2671334    1
# 3785426    1
# 6443749    1
# 7025379    1
# 2822880    1
# 3657918    1
# 236757     1
# 2465498    1
# 8060420    1
# 6243031    1
# 4693718    1
# 4879061    1
# 14036      1
# 4523671    1
# 3329686    1
# 6405781    1
# 710197     1
# 1974862    1
# 3571272    1
# 4571718    1
# 5299158    1
# 1928772    1
# ...

# %%
# per previous cell, these are the the top candidates
print(catnamena['Category'].unique(),len(ytest['Category'].unique()))
print(catnamena['Vendor Name'].unique(),len(ytest['Vendor Name'].unique()))
# Out:
# [     nan 1022200. 1062250. 1032100.] 76
# ['Heaven Hill Brands' 'Brown-Forman Corporation' 'Rogue Ales and Spirits'
#  'The Patron Spirits Company' 'Campari(skyy)'] 120

# %%
# following up on the 'vendor name' possibility
catnamena[catnamena['Category'].isna()]['Vendor Name'].value_counts()
# Out:
# Campari(skyy)               45
# Heaven Hill Brands          34
# Brown-Forman Corporation    14
# Name: Vendor Name, dtype: int64

# %%
# Looking for trend in full data pool:
# its not 'vendor name': too many differenct categories associated with 1 vendor
ytest[ytest['Vendor Name']=='Campari(skyy)']['Category'].value_counts()
# Out:
# 1011200.0    12120
# 1031080.0     5530
# 1082900.0     3671
# 1081200.0     2734
# 1022100.0     1719
# 1062100.0     1520
# 1031200.0     1391
# 1012100.0      448
# 1012210.0      247
# 1011500.0      194
# 1701100.0      141
# 1011250.0        7
# 1042100.0        4
# 1032080.0        1
# Name: Category, dtype: int64

# %%
catna=catna[catna['Category'].isna()]
len(catna)
# Out:
# 93

# %%
# narrowing search for Category na values, since there are fewer of them than Category Names
for i in catna.columns:
    print('column ',i,'has values',catna[i].value_counts())
    #print('yitems has value counts', ytest[i].value_counts())
# Out:
# column  Unnamed: 0 has values 7918047    1
# 5888211    1
# 2134495    1
# 1682142    1
# 8015167    1
# 3249755    1
# 6476122    1
# 6833753    1
# 4795233    1
# 1412821    1
# 14036      1
# 5537165    1
# 4730686    1
# 4993743    1
# 3315790    1
# 4775373    1
# 8154666    1
# 2859337    1
# 5172040    1
# 3183814    1
# 921668     1
# 4082702    1
# 4121953    1
# 6553756    1
# 2202084    1
# 6443749    1
# 2656638    1
# 7859696    1
# 6292855    1
# 7369083    1
# 2042874    1
# 7327865    1
# 4431558    1
# 7976450    1
# 831477     1
# 5736692    1
# 3022833    1
# 6514544    1
# 6987158    1
# 4937198    1
# 5271069    1
# 6549141    1
# 4552937    1
# 7045352    1
# 7854311    1
# 7381454    1
# 5197119    1
# 4336641    1
# 6815871    1
# 1851678    1
# 1444637    1
# 1514268    1
# 7391258    1
# 2289433    1
# 3986200    1
# 3475300    1
# 3329686    1
# 6323093    1
# 7829137    1
# 2937406    1
# 5683855    1
# 3797065    1
# 5436045    1
# 4518028    1
# ...

# %%
# Item Description looking sus, maybe Pack?
susitems=list(catna[catna['Category'].isna()]['Item Description'].unique())
susitems
# Out:
# ['Evan Williams Egg Nog',
#  'Wild Turkey American Honey Shot Tap',
#  "Carolan's Irish Cream w/2 Bowls",
#  'Chambord Liqueur w/2 Glasses']

# %%
sumsus=0
for i in susitems:
    sumsus+=ytest[(ytest['Item Description']==i)]['Category'].isna().sum()
sumsus
#ytest[ytest['Item Description']=='Evan Williams Egg Nog']['Category'].value_counts()
# Out:
# 284

# %%
ytest['Category'].isna().sum()
# Out:
# 284

# %%
# Found it: 'Evan Williams Egg Nog', 'Wild Turkey American Honey Shot Tap',
# "Carolan's Irish Cream w/2 Bowls", and'Chambord Liqueur w/2 Glasses'
# are all missing categorical assignments, creating nan values


# Can I find out how to assign a category to these values?

# %%
#How useful/different from item desc. are the category and category name columns?
print(len(ytest['Item Description'].unique()), len(ytest['Category'].unique()),
      len(ytest['Category Name'].unique()))
# ... very
# also appears that category name label should be available for the 4 items
# Out:
# 2334 76 72

# %%
for i in susitems:
    print(i, ytest[(ytest['Item Description']==i)]['Category Name'].unique())
# Out:
# Evan Williams Egg Nog [nan]
# Wild Turkey American Honey Shot Tap [nan]
# Carolan's Irish Cream w/2 Bowls [nan]
# Chambord Liqueur w/2 Glasses [nan]

# %%
for i in susitems:
    print(i, ytest[(ytest['Item Description']==i)]['Category'].unique())
# Out:
# Evan Williams Egg Nog [nan]
# Wild Turkey American Honey Shot Tap [nan]
# Carolan's Irish Cream w/2 Bowls [nan]
# Chambord Liqueur w/2 Glasses [nan]

# %%
catsus=list(ytest[ytest['Category Name'].isna()]['Item Description'].unique())

# %%
catsuscat={}
for i in catsus:
    truecat=ytest[ytest['Item Description']==i]['Category'].unique()
    truecatname=ytest[ytest['Item Description']==i]['Category Name'].unique()
    catsuscat[i]={'Category':truecat,'Category Name':truecatname}

# %%
cleancats=pd.DataFrame(catsuscat).T
cleancats
# Out:
#                                         Category Category Name
# Herradura Gold Reposado 6pak         [1022200.0]         [nan]
# Evan Williams Egg Nog                      [nan]         [nan]
# Carolan's Irish Cream w/2 Bowls            [nan]         [nan]
# Rogue Dark Rum                       [1062250.0]         [nan]
# Wild Turkey American Honey Shot Tap        [nan]         [nan]
# Ultimat Vodka                        [1032100.0]         [nan]
# Herradura Anejo Tequila              [1022200.0]         [nan]
# Whaler's Original Dark Rum           [1062250.0]         [nan]
# Chambord Liqueur w/2 Glasses               [nan]         [nan]

# %%
for i in cleancats:
    print(i)
# Out:
# Herradura Gold Reposado 6pak
# Evan Williams Egg Nog
# Carolan's Irish Cream w/2 Bowls
# Rogue Dark Rum
# Wild Turkey American Honey Shot Tap
# Ultimat Vodka
# Herradura Anejo Tequila
# Whaler's Original Dark Rum
# Chambord Liqueur w/2 Glasses

# %%
print(cleancats.index[0])
# Out:
# Herradura Gold Reposado 6pak

# %%
cleancats=cleancats.reset_index()

# %%
cleancats
# Out:
#                                  index     Category Category Name
# 0         Herradura Gold Reposado 6pak  [1022200.0]         [nan]
# 1                Evan Williams Egg Nog        [nan]         [nan]
# 2      Carolan's Irish Cream w/2 Bowls        [nan]         [nan]
# 3                       Rogue Dark Rum  [1062250.0]         [nan]
# 4  Wild Turkey American Honey Shot Tap        [nan]         [nan]
# 5                        Ultimat Vodka  [1032100.0]         [nan]
# 6              Herradura Anejo Tequila  [1022200.0]         [nan]
# 7           Whaler's Original Dark Rum  [1062250.0]         [nan]
# 8         Chambord Liqueur w/2 Glasses        [nan]         [nan]

# %%
for i in range(len(cleancats)):
    if (pd.isna(cleancats['Category'][i][0])) & (cleancats['index'][i]==x):
        #return cleancats['index'][i]
        print(cleancats['index'][i])
# Out:
# Evan Williams Egg Nog
# Carolan's Irish Cream w/2 Bowls
# Wild Turkey American Honey Shot Tap
# Chambord Liqueur w/2 Glasses

# %%
cct=cleancats.T
cct
# Out:
#                                           0                      1  \
# index          Herradura Gold Reposado 6pak  Evan Williams Egg Nog
# Category                        [1022200.0]                  [nan]
# Category Name                         [nan]                  [nan]
#
#                                              2               3  \
# index          Carolan's Irish Cream w/2 Bowls  Rogue Dark Rum
# Category                                 [nan]     [1062250.0]
# Category Name                            [nan]           [nan]
#
#                                                  4              5  \
# index          Wild Turkey American Honey Shot Tap  Ultimat Vodka
# Category                                     [nan]    [1032100.0]
# Category Name                                [nan]          [nan]
#
#                                      6                           7  \
# index          Herradura Anejo Tequila  Whaler's Original Dark Rum
# ...

# %%
cleancats=cleancats.drop('level_0',axis=1)

# %%
for i in cleancats.T:
    if cleancats[i][]
# Out:
#                                  index     Category Category Name
# 0         Herradura Gold Reposado 6pak  [1022200.0]         [nan]
# 1                Evan Williams Egg Nog        [nan]         [nan]
# 2      Carolan's Irish Cream w/2 Bowls        [nan]         [nan]
# 3                       Rogue Dark Rum  [1062250.0]         [nan]
# 4  Wild Turkey American Honey Shot Tap        [nan]         [nan]
# 5                        Ultimat Vodka  [1032100.0]         [nan]
# 6              Herradura Anejo Tequila  [1022200.0]         [nan]
# 7           Whaler's Original Dark Rum  [1062250.0]         [nan]
# 8         Chambord Liqueur w/2 Glasses        [nan]         [nan]

# %%
for i in cleancats['Category']:
    if pd.notna(i[0]):
        print(i[0])
    else: 
        print('cool')
# Out:
# 1022200.0
# cool
# cool
# 1062250.0
# cool
# 1032100.0
# 1022200.0
# 1062250.0
# cool

# %%
type(cleancat['Category'][1][0])
# Out:
# numpy.float64

# %%
def partial_clean_cat(x,y):
        if (pd.isna(x)) :
            for i in range(len(cleancats)):
                if (y==cleancats['index'][i]) & (pd.notna(cleancats['Category'][i][0])):
                    return cleancats['Category'][i][0]
                else:
                    return x
        else:
            return x

# %%
type(cleancats['index'][5])
# Out:
# str

# %%
ytest['Category']=list(map(partial_clean_cat,ytest['Category'],ytest['Item Description']))

# %%
ytest.isna().sum()
# Out:
# Unnamed: 0                 0
# Invoice/Item Number        0
# Date                       0
# Store Number               0
# Store Name                 0
# Address                    0
# City                       0
# Zip Code                   0
# Store Location             0
# County Number              0
# County                     0
# Category                 284
# Category Name            822
# Vendor Number              0
# Vendor Name                0
# Item Number                0
# Item Description           0
# Pack                       0
# Bottle Volume (ml)         0
# State Bottle Cost          0
# State Bottle Retail        0
# Bottles Sold               0
# Sale (Dollars)             0
# Volume Sold (Liters)       0
# Volume Sold (Gallons)      0
# Year                       0
# dtype: int64

# %%
cleancats
# Out:
#                                  index     Category Category Name
# 0         Herradura Gold Reposado 6pak  [1022200.0]         [nan]
# 1                Evan Williams Egg Nog        [nan]         [nan]
# 2      Carolan's Irish Cream w/2 Bowls        [nan]         [nan]
# 3                       Rogue Dark Rum  [1062250.0]         [nan]
# 4  Wild Turkey American Honey Shot Tap        [nan]         [nan]
# 5                        Ultimat Vodka  [1032100.0]         [nan]
# 6              Herradura Anejo Tequila  [1022200.0]         [nan]
# 7           Whaler's Original Dark Rum  [1062250.0]         [nan]
# 8         Chambord Liqueur w/2 Glasses        [nan]         [nan]

# %%
print(ytest[ytest['Category']==1022200.0]['Category Name'].isna().sum(),
pd.notna(ytest[ytest['Category']==1022200.0]['Category Name']).sum())
# Out:
# 511 0

# %%
print(ytest[ytest['Category']==1032100.0]['Category Name'].isna().sum(),
pd.notna(ytest[ytest['Category']==1032100.0]['Category Name']).sum())
# Out:
# 22 0

# %%
print(ytest[ytest['Category']==1062250.0]['Category Name'].isna().sum(),
pd.notna(ytest[ytest['Category']==1062250.0]['Category Name']).sum())
# Out:
# 5 0

# %%
ytest['Category Name'].isna().sum()
# Out:
# 822

# %%
ytest['Category'].isna().sum()
# Out:
# 284

# %%
print(ytest[ytest['Category Name'].isna()]['Item Description'].value_counts(),ytest[ytest['Category Name'].isna()]['Item Description'].value_counts().sum())
# Out:
# Herradura Gold Reposado 6pak           503
# Evan Williams Egg Nog                  106
# Wild Turkey American Honey Shot Tap     74
# Carolan's Irish Cream w/2 Bowls         63
# Chambord Liqueur w/2 Glasses            41
# Ultimat Vodka                           22
# Herradura Anejo Tequila                  8
# Rogue Dark Rum                           3
# Whaler's Original Dark Rum               2
# Name: Item Description, dtype: int64 822

# %%
print(ytest[ytest['Item Description']=='Herradura Gold Reposado 6pak'].shape)
# Out:
# (503, 26)

# %%
print(ytest[ytest['Item Description']=='Evan Williams Egg Nog'].shape)
# Out:
# (106, 26)

# %%
print(ytest[ytest['Item Description']=='Wild Turkey American Honey Shot Tap'].shape)
# Out:
# (74, 26)

# %%
print(ytest[ytest['Item Description']=="Carolan's Irish Cream w/2 Bowls"].shape)
# Out:
# (63, 26)

# %%
print(ytest[ytest['Item Description']=='Chambord Liqueur w/2 Glasses'].shape)
# Out:
# (41, 26)

# %%
print(ytest[ytest['Item Description']=='Ultimat Vodka'].shape)
# Out:
# (22, 26)

# %%
print(ytest[ytest['Item Description']=='Herradura Anejo Tequila'].shape)
# Out:
# (8, 26)

# %%
print(ytest[ytest['Item Description']=='Rogue Dark Rum'].shape)
# Out:
# (3, 26)

# %%
print(ytest[ytest['Item Description']=="Whaler's Original Dark Rum"].shape)
# Out:
# (2, 26)

# %% [markdown]
# # Now we have learned there is no indescretion between having a label and a NaN value in 'Category' and 'Category Name'
# # for all 8 items that have NaN values: meaning you either have a NaN value for all instances or not at all

# %%
for j in cleancats['Category']:
    print(j[0])
# Out:
# 1022200.0
# nan
# nan
# 1062250.0
# nan
# 1032100.0
# 1022200.0
# 1062250.0
# nan

# %%
ytest[ytest['Item Description']==catsus[0]]['Category'].unique()
# Out:
# array([1022200.])

# %%
ytest['Category'].isna().sum()
# Out:
# 284

# %%
ytest['Category Name'].isna().sum()
# Out:
# 822
